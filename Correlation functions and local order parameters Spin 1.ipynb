# %% [markdown]
# In this notebook, we want to check if there is any local order parameter for us to define the phase transition in our Kitaev ladder.

# %%
# import the model file we designed
"""
    Here we want to clarify that the 'kitaev_ladder_snake1.py' file
    is different from the 'kitaev_ladder_snake.py' in that the *1 file 
    uses the original representation of xyz,
    i.e. Jz stands for the sigmazsigmaz interactions which starts from
    the first pair of neighbors; Jx being the second pair; and Jy being
    the third-nearest-neighbors.
    
    The purpose of designing so many different 1D correspondences is 
    to serve for different phases.
    For example, when the Jx interaction is very weak, the optimal 
    choice is to make Jx as the third-nearest neighbors; when Jy is 
    weak the similar case holds.
"""
from kitaev_ladder_snake1 import run_atomic, save_after_run, finite_scaling, load_data, fDMRG_KL

# the folder name for storing data
folder_prefix = 'snake/'

# generate the function for running and storing the data in the folder we want
run_save = save_after_run(run_atomic, folder_prefix=folder_prefix)

# %%
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
from scipy import optimize

import scipy.sparse as sparse

# %%
# naming function for the png of finite scaling
def naming(Jx, Jy, Jz, L):
    return f"_Jx_{Jx}_Jy_{Jy}_Jz_{Jz}_L_{L}.png"

# %% [markdown]
# The spectra of two candidates can be given by
#
# $$\epsilon(k) = \pm\sqrt{(J_z + (J_x + D J_y)\cos k)^2 + (J_x - D J_y)^2\sin^2k}.$$

# %% [markdown]
# ## True Energy

# %%
import scipy.integrate as integrate

def e_k_sorted(k, Jx, Jy, Jz, D):
    Jp = Jx + D*Jy
    J2 = Jx**2 + Jy**2 + Jz**2 # J square
    return np.sqrt(J2 + 2 * Jz * Jp * np.cos(k) + 2 * D * Jx * Jy * np.cos(2*k))

def E_sorted(Jx, Jy, Jz, D):
    assert D==1 or D==-1
    e_k_D_sorted_func = lambda k:e_k_sorted(k, Jx, Jy, Jz, D)
    return integrate.quad(e_k_D_sorted_func, -np.pi, np.pi)[0] * -1 / (16*np.pi)

def E_true(Jx, Jy, Jz):
    D_true = 1 if Jy*Jx < 0 else -1
    E_true = E_sorted(Jx, Jy, Jz, D_true)
    return E_true

def E_false(Jx, Jy, Jz):
    D_true = -1 if Jy*Jx < 0 else 1
    E_true = E_sorted(Jx, Jy, Jz, D_true)
    return E_true

# %% [markdown]
# # Correlation Function

# %% [markdown]
# ## X Region

# %% [markdown]
# We choose a typical gapped point living in the $X$ region, i.e.
# $$ J_x - J_y > |{J_z}|$$

# %%
# set the region to be the circle `r = x**2 + y**2 = 2, z=.5`

r = 2
theta = np.pi * 9 / 90
Jx = 2
Jy = 1
Jz = 1

S=1

chi_list = [2**k for k in range(3, 8)]

initial_psi = None

for chi in chi_list:
    
    result = run_atomic(Jx=Jx, Jy=Jy, Jz=Jz, L=4, S=S, chi=chi, initial_psi=initial_psi, bc='periodic', bc_MPS='infinite')
    psi = result['psi']
    initial_psi = psi.copy()
# Out:
# Reading 'L'=4 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=1 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=2 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=1 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=1 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  8
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 408
# Energy = -1.0634033415215871, S = nan, norm_err = 1.5e-06
# Current memory usage 162.4 MB, time elapsed: 6.9 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.9458e-05, max_E_trunc = 8.0967e-05
# MPS bond dimensions: [8, 8, 8, 8, 8, 8, 8, 8]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 648
# Energy = -1.0634050736099461, S = nan, norm_err = 2.4e-07
# Current memory usage 162.4 MB, time elapsed: 9.8 s
# Delta E = -1.7321e-07, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.4475e-05, max_E_trunc = 6.0950e-05
# MPS bond dimensions: [8, 8, 8, 8, 8, 8, 8, 8]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 888
# Energy = -1.0634050817695027, S = 0.2168500233280421, norm_err = 4.6e-15
# Current memory usage 162.4 MB, time elapsed: 11.3 s
# Delta E = -8.1596e-10, Delta S = nan (per sweep)
# max_trunc_err = 7.2268e-06, max_E_trunc = 6.0986e-05
# MPS bond dimensions: [8, 8, 8, 8, 8, 8, 8, 8]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1128
# Energy = -1.0634051562170299, S = 0.2160097710509440, norm_err = 4.9e-15
# Current memory usage 162.4 MB, time elapsed: 12.9 s
# Delta E = -7.4448e-09, Delta S = -8.4025e-05 (per sweep)
# max_trunc_err = 7.1435e-06, max_E_trunc = 6.0217e-05
# MPS bond dimensions: [8, 8, 8, 8, 8, 8, 8, 8]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 1128, maximum chi = 8
# ================================================================================
# Before the canonicalization:
# Bond dim =  [8, 8, 8, 8, 8, 8, 8, 8]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000016-2.858622714296264e-17j)
# After the canonicalization:
# Bond dim =  [8, 8, 8, 8, 8, 8, 8, 8]
# Computing properties
# Optimizing
# Loop for chi=8 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
# Reading 'L'=4 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=1 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=2 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=1 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=1 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  16
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 408
# Energy = -1.0634637969390361, S = nan, norm_err = 1.5e-06
# Current memory usage 163.5 MB, time elapsed: 8.8 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.6547e-06, max_E_trunc = 7.8974e-06
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 648
# Energy = -1.0634638457487000, S = nan, norm_err = 2.5e-07
# Current memory usage 163.5 MB, time elapsed: 12.8 s
# Delta E = -4.8810e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.5756e-06, max_E_trunc = 7.8495e-06
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 888
# Energy = -1.0634638470423994, S = 0.5210738455767900, norm_err = 7.8e-15
# Current memory usage 163.5 MB, time elapsed: 15.2 s
# Delta E = -1.2937e-10, Delta S = nan (per sweep)
# max_trunc_err = 1.2812e-06, max_E_trunc = 7.8495e-06
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1128
# Energy = -1.0634638496352835, S = 0.5210723739238392, norm_err = 7.6e-15
# Current memory usage 163.5 MB, time elapsed: 17.6 s
# Delta E = -2.5929e-10, Delta S = -1.4717e-07 (per sweep)
# max_trunc_err = 1.2812e-06, max_E_trunc = 7.8496e-06
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 1128, maximum chi = 16
# ================================================================================
# Before the canonicalization:
# Bond dim =  [16, 16, 16, 16, 16, 16, 16, 16]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000042-1.3383878492805312e-17j)
# After the canonicalization:
# Bond dim =  [16, 16, 16, 16, 16, 16, 16, 16]
# Computing properties
# Optimizing
# Loop for chi=16 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
# Reading 'L'=4 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=1 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=2 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=1 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=1 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  32
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 408
# Energy = -1.0634684003578023, S = nan, norm_err = 8.7e-09
# Current memory usage 167.2 MB, time elapsed: 10.9 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.7694e-09, max_E_trunc = 1.3805e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 648
# Energy = -1.0634684019685778, S = nan, norm_err = 1.0e-08
# Current memory usage 167.2 MB, time elapsed: 15.8 s
# Delta E = -1.6108e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.4951e-09, max_E_trunc = 1.2850e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 888
# Energy = -1.0634684031611670, S = 0.5212381827457457, norm_err = 2.8e-15
# Current memory usage 167.2 MB, time elapsed: 18.7 s
# Delta E = -1.1926e-10, Delta S = nan (per sweep)
# max_trunc_err = 1.2114e-09, max_E_trunc = 1.2673e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1128
# Energy = -1.0634684031612238, S = 0.5212381827451245, norm_err = 3.5e-15
# Current memory usage 167.2 MB, time elapsed: 21.6 s
# Delta E = -5.6843e-15, Delta S = -6.2128e-14 (per sweep)
# max_trunc_err = 1.2114e-09, max_E_trunc = 1.2674e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 1128, maximum chi = 32
# ================================================================================
# Before the canonicalization:
# Bond dim =  [32, 32, 32, 32, 32, 32, 32, 32]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000062-1.6780187305680405e-16j)
# After the canonicalization:
# Bond dim =  [32, 32, 32, 32, 32, 32, 32, 32]
# Computing properties
# Optimizing
# Loop for chi=32 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
# Reading 'L'=4 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=1 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=2 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=1 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=1 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  64
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 408
# Energy = -1.0634684098259584, S = nan, norm_err = 3.1e-11
# Current memory usage 191.0 MB, time elapsed: 11.8 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 5.9167e-12, max_E_trunc = 3.6721e-11
# MPS bond dimensions: [64, 64, 64, 64, 64, 64, 64, 64]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 648
# Energy = -1.0634684098321756, S = nan, norm_err = 4.5e-11
# Current memory usage 191.0 MB, time elapsed: 21.3 s
# Delta E = -6.2172e-13, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.6166e-12, max_E_trunc = 2.5238e-11
# MPS bond dimensions: [64, 64, 64, 64, 64, 64, 64, 64]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 888
# Energy = -1.0634684098434448, S = 0.5212386575155956, norm_err = 2.9e-15
# Current memory usage 191.0 MB, time elapsed: 27.1 s
# Delta E = -1.1269e-12, Delta S = nan (per sweep)
# max_trunc_err = 1.6452e-12, max_E_trunc = 1.8076e-11
# MPS bond dimensions: [64, 64, 64, 64, 64, 64, 64, 64]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1128
# Energy = -1.0634684098433382, S = 0.5212386575517973, norm_err = 3.0e-15
# Current memory usage 191.0 MB, time elapsed: 32.7 s
# Delta E = 1.0658e-14, Delta S = 3.6202e-12 (per sweep)
# max_trunc_err = 1.6397e-12, max_E_trunc = 1.7053e-11
# MPS bond dimensions: [64, 64, 64, 64, 64, 64, 64, 64]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 1128, maximum chi = 64
# ================================================================================
# Before the canonicalization:
# Bond dim =  [64, 64, 64, 64, 64, 64, 64, 64]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000067-3.389414795090785e-16j)
# After the canonicalization:
# Bond dim =  [64, 64, 64, 64, 64, 64, 64, 64]
# Computing properties
# Optimizing
# Loop for chi=64 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
# Reading 'L'=4 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=1 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=2 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=1 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=1 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 408
# Energy = -1.0634684098526286, S = nan, norm_err = 1.0e-12
# Current memory usage 285.7 MB, time elapsed: 43.0 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.9361e-15, max_E_trunc = 6.2528e-13
# MPS bond dimensions: [128, 128, 102, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 648
# Energy = -1.0634684098528027, S = nan, norm_err = 5.3e-13
# Current memory usage 285.7 MB, time elapsed: 83.3 s
# Delta E = -1.7408e-14, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 3.8685e-15, max_E_trunc = 2.2737e-12
# MPS bond dimensions: [128, 128, 104, 128, 128, 128, 128, 128]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 888
# Energy = -1.0634684098529306, S = 0.5212386622159153, norm_err = 3.1e-15
# Current memory usage 286.5 MB, time elapsed: 115.6 s
# Delta E = -1.2790e-14, Delta S = nan (per sweep)
# max_trunc_err = 1.0151e-15, max_E_trunc = 2.1600e-12
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1128
# Energy = -1.0634684098533000, S = 0.5212386622158638, norm_err = 3.8e-15
# Current memory usage 286.5 MB, time elapsed: 137.6 s
# Delta E = -3.6948e-14, Delta S = -5.1514e-15 (per sweep)
# max_trunc_err = 1.0414e-15, max_E_trunc = 3.8654e-12
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 1128, maximum chi = 128
# ================================================================================
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2275: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2296: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# Before the canonicalization:
# Bond dim =  [87, 113, 87, 116, 86, 113, 87, 114]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (0.9999999999999974+1.423080558537314e-16j)
# After the canonicalization:
# Bond dim =  [87, 113, 87, 116, 86, 113, 87, 114]
# Computing properties
# Optimizing
# Loop for chi=128 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================

# %% [markdown]
# ## Validation of the Ground State

# %% [markdown]
# ### Test with our theoretical energy
#
# Currently not applicable

# %%
# assert np.abs(result['energy'] - E_true(Jx, Jy, Jz)) < 1e-10

# %% [markdown]
# ### Test with our local symmetries
#
# Need to find the correct expression

# %%
psi = result['psi']
# k=0
# print("Norm: <psi|psi> = %.1f" % psi.norm)
# for k in range(20):
#     if k % 2 == 0:
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sx', k), ('Sy', k+1), ('Sy', k+2), ('Sx', k+3)])))
# #

# %% [markdown]
# ## Local Operators

# %%
ops = ['Sx', 'Sy', 'Sz']

# %%
site_left = [0]
site_right = 1000
xticks=range(site_right)
for op in ops:
    cf_list = psi.correlation_function(op, op, site_left, site_right, opstr=op)[0, :]
    plt.plot(xticks, np.abs(cf_list), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

site_left = [1]
site_right = 1000
xticks=range(site_right)
for op in ops:
    cf_list = psi.correlation_function(op, op, site_left, site_right, opstr=op)[0, :]
    plt.plot(xticks, np.abs(cf_list), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

# %% [markdown]
# Q: solvability?

# %% [markdown]
# ## Double Local Operators

# %% [markdown]
# Now let's try the 'double local operators'.
#
# That is, we used two local, neighboring operators combined together as our observed quantity.

# %%
def double_local_op(psi, op='Sx', i0=1, d=1):
    return psi.expectation_value_term(term=[(op, i0), (op, i0+1), (op, i0+d*2), (op, i0+d*2+1)])
def double_local_op_corr_func(psi, op='Sx', i0=1, dN=9):
    return [double_local_op(psi, op=op, i0=i0, d=d) for d in range(dN)]

# %%
ops = ['Sx', 'Sy', 'Sz']
N=20

xticks=range(1, 2*N, 2)
for op in ops:
    plt.plot(xticks, double_local_op_corr_func(psi, op=op, i0=1, dN=N), label=op)
print(double_local_op_corr_func(psi, op='Sx', i0=1, dN=N))
plt.legend()
plt.xticks(xticks)
plt.show()

xticks=range(0, 2*N, 2)
for op in ops:
    plt.plot(xticks, double_local_op_corr_func(psi, op=op, i0=0, dN=N), label=op)
plt.legend()
plt.xticks(xticks)
plt.show()
# Out:
# [array(0.93575986), array(0.88838897), array(0.88919384), array(0.87236514), array(0.87340896), array(0.87272787), array(0.87281417), array(0.87276246), array(0.87276942), array(0.87276391), array(0.87276419), array(0.87276481), array(0.87276481), array(0.87276401), array(0.87276373), array(0.87276481), array(0.87276476), array(0.87276401), array(0.87276373), array(0.87276481)]

# %%
Jp = Jx + Jy
Jm = Jx - Jy
ratio = Jp / Jm
Delta = np.sqrt(ratio) * (1 - (Jz / Jm)**2)**(1/4) / (2 * (1 + ratio))
print(Delta)
# Out:
# 0.22691338311389625

# %%
def double_local_op(psi, op='Sx', i0=1, d=1):
    return psi.expectation_value_term(term=[(op, i0), (op, i0+1), (op, i0+d*2), (op, i0+d*2+1)])*16
def double_local_op_corr_func(psi, op='Sx', i0=1, dN=9):
    return [double_local_op(psi, op=op, i0=i0, d=d) for d in range(dN)]

# %% [markdown]
# ## Non-local operators

# %%
def nonlocal_op(psi, op='Sx', i0=1, end=11):
    if end==i0:
        return 1.0
    return psi.expectation_value_term(term=[(op, i) for i in range(i0, end)])
def nonlocal_op_corr_func(psi, op='Sx', i0=1, N=20):
    return [nonlocal_op(psi, op=op, i0=i0, end=i0+2*d) for d in range(N)]

# %%
ops = ['Sx', 'Sy', 'Sz']
N=200

xticks=range(1, 2*N, 2)
for op in ops:
    plt.plot(xticks, np.abs(nonlocal_op_corr_func(psi, op=op, i0=1, N=N)), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.ylim(top=1.1)
plt.show()

xticks=range(0, 2*N, 2)
for op in ops:
    plt.plot(xticks, np.abs(nonlocal_op_corr_func(psi, op=op, i0=0, N=N)), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.ylim(top=1.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-035807a22178> in <module>
#       4 xticks=range(1, 2*N, 2)
#       5 for op in ops:
# ----> 6     plt.plot(xticks, np.abs(nonlocal_op_corr_func(psi, op=op, i0=1, N=N)), '-', label=op)
#       7 plt.legend()
#       8 plt.xticks(xticks)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Double Local Operators

# %% [markdown]
# Now let's try other sort of 'double local operators'.
#
# That is, we used two local, neighboring operators combined together as our |

# %%
def double_local_op_diff(psi, op1='Sx', op2='Sz', i0=1, d0=1, d=1):
    return psi.expectation_value_term(term=[(op1, i0), (op2, i0+d0), (op1, i0+d*2), (op2, i0+d0+d*2)])*16
def double_local_op_diff_corr_func(psi, op1='Sx', op2='Sz', i0=1, d0=1, dN=9):
    return [double_local_op_diff(psi, op1=op1, op2=op2, i0=i0, d0=d0, d=d) for d in range(dN)]

# %%
ops1 = [
    'Sx', 
    'Sy', 
    'Sz',
       ]
ops2 = [
    'Sx', 
    'Sy', 
    'Sz',
]
i0_list = [0, 1]
d0_list = [1, 2, 3]


N = 20

for op1 in ops1:
    for op2 in ops2:
        for i0 in i0_list:
            for d0 in d0_list:
                xticks=range(i0, 2*N, 2)
                plt.plot(
                    xticks, 
                    double_local_op_diff_corr_func(
                        psi, 
                        op1=op1, op2=op2, i0=i0, d0=d0, dN=N), 
                    label=op1+op2+f' i0={i0}, d0={d0}')
                
plt.legend()
plt.show()

# %%
Jp = Jx + Jy
Jm = Jx - Jy
ratio = Jp / Jm
Delta = np.sqrt(ratio) * (1 - (Jz / Jm)**2)**(1/4) / (2 * (1 + ratio))
print(Delta)
# Out:
# 0.22691338311389625

# %% [markdown]
# ## Triple Local Operators

# %%
from itertools import permutations, product
print(list(permutations(ops)))
i0s = [0, 1, 2, 3]
print(list(permutations(i0s, 3)))
# Out:
# [('Sx', 'Sy', 'Sz'), ('Sx', 'Sz', 'Sy'), ('Sy', 'Sx', 'Sz'), ('Sy', 'Sz', 'Sx'), ('Sz', 'Sx', 'Sy'), ('Sz', 'Sy', 'Sx')]
# [(0, 1, 2), (0, 1, 3), (0, 2, 1), (0, 2, 3), (0, 3, 1), (0, 3, 2), (1, 0, 2), (1, 0, 3), (1, 2, 0), (1, 2, 3), (1, 3, 0), (1, 3, 2), (2, 0, 1), (2, 0, 3), (2, 1, 0), (2, 1, 3), (2, 3, 0), (2, 3, 1), (3, 0, 1), (3, 0, 2), (3, 1, 0), (3, 1, 2), (3, 2, 0), (3, 2, 1)]

# %%
def multiple_local_op_diff(psi, ops=['Sx', 'Sy', 'Sz'], i0s=[0, 1, 2], d=1):
    return psi.expectation_value_term(term=[(op, i0) for op, i0 in zip(ops, i0s)] + [(op, i0+d) for op, i0 in zip(ops, i0s)])*(2**(2*len(ops)))
def multiple_local_op_diff_corr_func(psi, ops=['Sx', 'Sy', 'Sz'], i0s=[0, 1, 2], dN=20):
    return [multiple_local_op_diff(psi, ops=ops, i0s=i0s, d=d) for d in range(dN)]

# %%
for ops_input in list(product(ops, ops, ops)):
    for i0s_input in list(permutations(i0s, 3)):
        plt.plot(multiple_local_op_diff_corr_func(psi, ops=ops_input, i0s=i0s_input))

# %% [markdown]
# ## Quartic

# %%
for ops_input in list(product(ops, ops, ops, ops)):
    corr_values = multiple_local_op_diff_corr_func(psi, ops=ops_input, i0s=i0s)
    plt.plot(corr_values,label=f'{ops_input}')
    if np.average(corr_values) > .25:
        print(ops_input)
plt.legend()
# Out:
# ('Sx', 'Sy', 'Sy', 'Sx')
# ('Sx', 'Sz', 'Sz', 'Sx')

# %%
for ops_input in list(product(ops, ops, ops, ops)):
    corr_values = multiple_local_op_diff_corr_func(psi, ops=ops_input, i0s=i0s)
    if np.average(corr_values) > .25:
        print(ops_input)
        plt.plot(corr_values,label=f'{ops_input}')

plt.legend()
# Out:
# ('Sx', 'Sy', 'Sy', 'Sx')
# ('Sx', 'Sz', 'Sz', 'Sx')

# %% [markdown]
# Hmmm, XZZX? Interesting. It is indeed not commutable with the Hamiltonian, but still commutable with the global symmetries.

# %% [markdown]
# ## Z region

# %% [markdown]
# We choose a typical gapped point living in the central region, i.e.
# $$ -|{J_z}| < J_x - J_y < |{J_z}|$$

# %%
# set the region to be the circle `r = x**2 + y**2 = 2, z=.5`

Jx = 1
Jy = 1
Jz = 1

result = run_atomic(Jx=Jx, Jy=Jy, Jz=Jz, L=8, chi=128, bc='periodic', bc_MPS='infinite')
# Out:
# Reading 'L'=8 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=1 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=1 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=1 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 816
# Energy = -0.2097012464827843, S = nan, norm_err = 9.5e-13
# Current memory usage 522.9 MB, time elapsed: 30.6 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 7.1491e-18, max_E_trunc = 1.4211e-13
# MPS bond dimensions: [98, 112, 66, 124, 124, 128, 123, 128, 123, 128, 120, 128, 121, 128, 124, 123]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 1296
# Energy = -0.2097012464828101, S = nan, norm_err = 7.8e-13
# Current memory usage 522.9 MB, time elapsed: 69.4 s
# Delta E = -2.5757e-15, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.0512e-18, max_E_trunc = 2.8422e-13
# MPS bond dimensions: [92, 105, 67, 121, 128, 126, 124, 128, 124, 128, 121, 128, 125, 128, 122, 116]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 1776
# Energy = -0.2097012464828083, S = 1.2232332305847287, norm_err = 9.0e-15
# Current memory usage 522.9 MB, time elapsed: 86.1 s
# Delta E = 1.7764e-16, Delta S = nan (per sweep)
# max_trunc_err = 3.9042e-19, max_E_trunc = 4.5475e-13
# MPS bond dimensions: [96, 128, 96, 128, 96, 128, 96, 128, 96, 128, 96, 128, 96, 128, 96, 128]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 2256
# Energy = -0.2097012464827568, S = 1.2232332305847415, norm_err = 6.3e-15
# Current memory usage 522.9 MB, time elapsed: 102.2 s
# Delta E = 5.1514e-15, Delta S = 1.2879e-15 (per sweep)
# max_trunc_err = 4.3602e-19, max_E_trunc = 6.8212e-13
# MPS bond dimensions: [96, 128, 96, 128, 96, 128, 96, 128, 96, 128, 96, 128, 96, 128, 96, 128]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 2256, maximum chi = 128
# ================================================================================
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2119: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   self.canonical_form_infinite(renormalize)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2269: UserWarning: Although we renormalized the TransferMatrix, the largest eigenvalue is not 1
#   warnings.warn("Although we renormalized the TransferMatrix, "
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2275: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2119: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   self.canonical_form_infinite(renormalize)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2296: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# Before the canonicalization:
# Bond dim =  [28, 46, 48, 76, 48, 76, 48, 76, 49, 76, 48, 76, 48, 76, 48, 46]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000016+2.1528189387415297e-17j)
# After the canonicalization:
# Bond dim =  [28, 46, 48, 76, 48, 76, 48, 76, 49, 76, 48, 76, 48, 76, 48, 46]
# Computing properties
# Optimizing
# Loop for chi=128 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================

# %%
psi = result['psi']

# %% [markdown]
# ## Validation of the Ground State

# %% [markdown]
# ### Test with our theoretical energy

# %%
assert np.abs(result['energy'] - E_true(Jx, Jy, Jz)) < 1e-10

# %% [markdown]
# ### Test with our local symmetries

# %%
k=0
print("Norm: <psi|psi> = %.1f" % psi.norm)
for k in range(20):
    if k % 2 == 0:
        print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sx', k), ('Sy', k+1), ('Sy', k+2), ('Sx', k+3)])))
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sy', k), ('Sx', k+1), ('Sx', k+2), ('Sy', k+3)])))
#
# Out:
# Norm: <psi|psi> = 1.0
# Local Symmetry: W0 = 1.0
# Local Symmetry: W1 = 1.0
# Local Symmetry: W2 = 1.0
# Local Symmetry: W3 = 1.0
# Local Symmetry: W4 = 1.0
# Local Symmetry: W5 = 1.0
# Local Symmetry: W6 = 1.0
# Local Symmetry: W7 = 0.0
# Local Symmetry: W8 = 1.0
# Local Symmetry: W9 = 1.0

# %% [markdown]
# ## Local Operators

# %%
ops = ['Sx', 'Sy', 'Sz']

# %%
site_left = [0]
site_right = 20
xticks=range(site_right)
for op in ops:
    cf_list = 4*psi.correlation_function(op, op, site_left, site_right, opstr=op)[0, :]
    plt.plot(xticks, np.abs(cf_list), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

site_left = [1]
site_right = 20
xticks=range(site_right)
for op in ops:
    cf_list = 4*psi.correlation_function(op, op, site_left, site_right, opstr=op)[0, :]
    plt.plot(xticks, np.abs(cf_list), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

# %% [markdown]
# ## Double Local Operators

# %% [markdown]
# Now let's try the 'double local operators'.
#
# That is, we used two local, neighboring operators combined together as our |

# %%
def double_local_op(psi, op='Sx', i0=1, d=1):
    return psi.expectation_value_term(term=[(op, i0), (op, i0+1), (op, i0+d*2), (op, i0+d*2+1)])*16
def double_local_op_corr_func(psi, op='Sx', i0=1, dN=9):
    return [double_local_op(psi, op=op, i0=i0, d=d) for d in range(dN)]

# %%
ops = ['Sx', 'Sy', 'Sz']
N=20

xticks=range(1, 2*N, 2)
for op in ops:
    plt.plot(xticks, double_local_op_corr_func(psi, op=op, i0=1, dN=N), label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

xticks=range(0, 2*N, 2)
for op in ops:
    plt.plot(xticks, double_local_op_corr_func(psi, op=op, i0=0, dN=N), label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

# %% [markdown]
# ## Non-local operators

# %%
def nonlocal_op(psi, op='Sx', i0=1, end=11):
    if end==i0:
        return 1.0
    return psi.expectation_value_term(term=[(op, i) for i in range(i0, end)])*(2**(end-i0))
def nonlocal_op_corr_func(psi, op='Sx', i0=1, N=20):
    return [nonlocal_op(psi, op=op, i0=i0, end=i0+2*d) for d in range(N)]

# %%
ops = ['Sx', 'Sy', 'Sz']
N=20

xticks=range(1, 2*N, 2)
for op in ops:
    plt.plot(xticks, np.abs(nonlocal_op_corr_func(psi, op=op, i0=1, N=N)), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.ylim(top=1.1)
plt.show()

xticks=range(0, 2*N, 2)
for op in ops:
    plt.plot(xticks, np.abs(nonlocal_op_corr_func(psi, op=op, i0=0, N=N)), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.ylim(top=1.1)
plt.show()

# %% [markdown]
# ## Large Z

# %% [markdown]
# We choose a typical gapped point living in the large $Z$ limit, e.g.
# $$ J_x^2 + J_y^2 = 0.1$$

# %%
# set the region to be the circle `r = x**2 + y**2 = 2, z=.5`
r = 0.1
theta = .1
Jx = r * np.cos(theta)
Jy = r * np.sin(theta)
Jz = 1

result = run_atomic(Jx=Jx, Jy=Jy, Jz=Jz, L=8, chi=128, bc='periodic', bc_MPS='infinite')
# Out:
# Reading 'L'=8 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=0.09950041652780259 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=0.009983341664682815 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=1 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 816
# Energy = 0.1371278591078502, S = nan, norm_err = 1.5e-01
# Current memory usage 522.9 MB, time elapsed: 68.3 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.8341e-10, max_E_trunc = -9.5213e-13
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 1296
# Energy = 0.3198556878029666, S = nan, norm_err = 2.2e-01
# Current memory usage 522.9 MB, time elapsed: 147.9 s
# Delta E = 1.8273e-02, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 3.5508e-10, max_E_trunc = -8.3276e-12
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 1776
# Energy = -0.0983175582116784, S = 1.2202778202775277, norm_err = 2.2e-02
# Current memory usage 522.9 MB, time elapsed: 215.5 s
# Delta E = -4.1817e-02, Delta S = nan (per sweep)
# max_trunc_err = 1.6588e-10, max_E_trunc = -2.1316e-11
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 2256
# Energy = 0.2440959195914099, S = 3.5115369335485473, norm_err = 1.1e-01
# Current memory usage 522.9 MB, time elapsed: 283.8 s
# Delta E = 3.4241e-02, Delta S = 2.2913e-01 (per sweep)
# max_trunc_err = 2.3030e-10, max_E_trunc = -6.7644e-12
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 2736
# Energy = 0.0894229989191295, S = 1.8230668976189277, norm_err = 1.5e-01
# Current memory usage 522.9 MB, time elapsed: 350.2 s
# Delta E = -1.5467e-02, Delta S = -1.6885e-01 (per sweep)
# max_trunc_err = 1.1270e-10, max_E_trunc = -2.6773e-11
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 3216
# Energy = -0.0622001516426884, S = 1.2535168294326415, norm_err = 4.9e-02
# Current memory usage 522.9 MB, time elapsed: 416.6 s
# Delta E = -1.5162e-02, Delta S = -5.6955e-02 (per sweep)
# max_trunc_err = 7.8563e-11, max_E_trunc = -1.2506e-11
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 3696
# Energy = -0.1253563752516325, S = 0.9723681281294451, norm_err = 4.2e-07
# Current memory usage 522.9 MB, time elapsed: 482.9 s
# Delta E = -6.3156e-03, Delta S = -2.8115e-02 (per sweep)
# max_trunc_err = 3.6215e-11, max_E_trunc = -5.6843e-13
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 4176
# Energy = -0.1253601626208720, S = 0.9706681695530515, norm_err = 4.4e-06
# Current memory usage 522.9 MB, time elapsed: 549.3 s
# Delta E = -3.7874e-07, Delta S = -1.7000e-04 (per sweep)
# max_trunc_err = 8.8354e-11, max_E_trunc = -2.0862e-11
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 4656
# Energy = -0.1253733035710027, S = 1.0382774933755339, norm_err = 3.0e-08
# Current memory usage 522.9 MB, time elapsed: 615.7 s
# Delta E = -1.3141e-06, Delta S = 6.7609e-03 (per sweep)
# max_trunc_err = 8.0390e-11, max_E_trunc = -2.7285e-12
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 5136
# Energy = -0.1253730443813659, S = 1.0375279816913725, norm_err = 1.5e-08
# Current memory usage 522.9 MB, time elapsed: 684.4 s
# Delta E = 2.5919e-08, Delta S = -7.4951e-05 (per sweep)
# max_trunc_err = 2.4158e-11, max_E_trunc = 1.1369e-12
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# ================================================================================
# DMRG finished after 100 sweeps.
# total size = 5136, maximum chi = 128
# ================================================================================
# Before the canonicalization:
# Bond dim =  [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000167+6.319709941973472e-16j)
# After the canonicalization:
# Bond dim =  [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Computing properties
# Optimizing
# Loop for chi=128 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================

# %%
psi = result['psi']

# %% [markdown]
# ## Validation of the Ground State

# %% [markdown]
# ### Test with our theoretical energy

# %%
np.abs(result['energy'] - E_true(Jx, Jy, Jz))
# Out:
# 1.4487843093269337e-06

# %% [markdown]
# ### Test with our local symmetries

# %%
k=0
print("Norm: <psi|psi> = %.1f" % psi.norm)
for k in range(20):
    if k % 2 == 0:
        print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sx', k), ('Sy', k+1), ('Sy', k+2), ('Sx', k+3)])))
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sy', k), ('Sx', k+1), ('Sx', k+2), ('Sy', k+3)])))
#
# Out:
# Norm: <psi|psi> = 1.0
# Local Symmetry: W0 = 1.0
# Local Symmetry: W1 = 1.0
# Local Symmetry: W2 = 1.0
# Local Symmetry: W3 = 1.0
# Local Symmetry: W4 = 1.0
# Local Symmetry: W5 = 1.0
# Local Symmetry: W6 = 1.0
# Local Symmetry: W7 = 1.0
# Local Symmetry: W8 = 1.0
# Local Symmetry: W9 = 1.0

# %% [markdown]
# ## Local Operators

# %%
ops = ['Sx', 'Sy', 'Sz']

# %%
site_left = [0]
site_right = 20
xticks=range(site_right)
for op in ops:
    cf_list = 4*psi.correlation_function(op, op, site_left, site_right, opstr=op)[0, :]
    plt.plot(xticks, np.abs(cf_list), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

site_left = [1]
site_right = 20
xticks=range(site_right)
for op in ops:
    cf_list = 4*psi.correlation_function(op, op, site_left, site_right, opstr=op)[0, :]
    plt.plot(xticks, np.abs(cf_list), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

# %% [markdown]
# ## Double Local Operators

# %% [markdown]
# Now let's try the 'double local operators'.
#
# That is, we used two local, neighboring operators combined together as our |

# %%
def double_local_op(psi, op='Sx', i0=1, d=1):
    return psi.expectation_value_term(term=[(op, i0), (op, i0+1), (op, i0+d*2), (op, i0+d*2+1)])*16
def double_local_op_corr_func(psi, op='Sx', i0=1, dN=9):
    return [double_local_op(psi, op=op, i0=i0, d=d) for d in range(dN)]

# %%
ops = ['Sx', 'Sy', 'Sz']
N=20

xticks=range(1, 2*N, 2)
for op in ops:
    plt.plot(xticks, double_local_op_corr_func(psi, op=op, i0=1, dN=N), label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

xticks=range(0, 2*N, 2)
for op in ops:
    plt.plot(xticks, double_local_op_corr_func(psi, op=op, i0=0, dN=N), label=op)
plt.legend()
plt.xticks(xticks)
plt.show()

# %% [markdown]
# ## Non-local operators

# %%
def nonlocal_op(psi, op='Sx', i0=1, end=11):
    if end==i0:
        return 1.0
    return psi.expectation_value_term(term=[(op, i) for i in range(i0, end)])*(2**(end-i0))
def nonlocal_op_corr_func(psi, op='Sx', i0=1, N=20):
    return [nonlocal_op(psi, op=op, i0=i0, end=i0+2*d) for d in range(N)]

# %%
ops = ['Sx', 'Sy', 'Sz']
N=20

xticks=range(1, 2*N, 2)
for op in ops:
    plt.plot(xticks, np.abs(nonlocal_op_corr_func(psi, op=op, i0=1, N=N)), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.ylim(top=1.1)
plt.show()

xticks=range(0, 2*N, 2)
for op in ops:
    plt.plot(xticks, np.abs(nonlocal_op_corr_func(psi, op=op, i0=0, N=N)), '-', label=op)
plt.legend()
plt.xticks(xticks)
plt.ylim(top=1.1)
plt.show()

# %%
# set the region to be the circle `r = x**2 + y**2 = 2, z=.5`

r = 2
theta = np.pi * 9 / 90
Jx = -r*np.cos(theta)
Jy = r*np.sin(theta)
Jz = .5

result = run_atomic(Jx=Jx, Jy=Jy, Jz=Jz, L=8, chi=128, bc='periodic', bc_MPS='infinite')
# Out:
# Reading 'L'=8 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=-1.902113032590307 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=0.6180339887498948 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=0.5 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 816
# Energy = -0.2472012973842528, S = nan, norm_err = 9.1e-04
# Current memory usage 522.9 MB, time elapsed: 69.6 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.4074e-11, max_E_trunc = 1.1369e-13
# MPS bond dimensions: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 1296
# Energy = -0.2490400578897169, S = nan, norm_err = 2.1e-11
# Current memory usage 522.9 MB, time elapsed: 136.1 s
# Delta E = -1.8388e-04, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 8.0555e-16, max_E_trunc = 3.4106e-13
# MPS bond dimensions: [68, 75, 51, 95, 126, 128, 124, 126, 125, 127, 128, 128, 128, 126, 125, 92]
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 1776
# Energy = -0.2490400578927900, S = nan, norm_err = 7.0e-13
# Current memory usage 522.9 MB, time elapsed: 164.8 s
# Delta E = -3.0731e-13, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.4040e-19, max_E_trunc = 5.6843e-13
# MPS bond dimensions: [58, 70, 47, 82, 98, 125, 108, 124, 114, 126, 108, 128, 108, 125, 98, 78]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 2256
# Energy = -0.2490400578927563, S = 0.7784899589503622, norm_err = 5.5e-15
# Current memory usage 522.9 MB, time elapsed: 177.2 s
# Delta E = 3.3751e-15, Delta S = nan (per sweep)
# max_trunc_err = 4.5755e-20, max_E_trunc = 1.3642e-12
# MPS bond dimensions: [66, 90, 66, 90, 66, 90, 66, 90, 66, 90, 66, 90, 66, 90, 66, 90]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 2736
# Energy = -0.2490400578927066, S = 0.7784899589503850, norm_err = 8.4e-15
# Current memory usage 522.9 MB, time elapsed: 186.9 s
# Delta E = 4.9738e-15, Delta S = 2.2760e-15 (per sweep)
# max_trunc_err = 4.6617e-20, max_E_trunc = 1.7053e-12
# MPS bond dimensions: [66, 90, 66, 90, 66, 90, 66, 90, 66, 90, 66, 90, 66, 90, 66, 90]
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 2736, maximum chi = 90
# ================================================================================
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2275: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2119: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   self.canonical_form_infinite(renormalize)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2296: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# Before the canonicalization:
# Bond dim =  [38, 49, 38, 48, 38, 48, 38, 48, 38, 48, 38, 48, 38, 48, 38, 48]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000147-1.3576921704955207e-16j)
# After the canonicalization:
# Bond dim =  [38, 49, 38, 48, 38, 48, 38, 48, 38, 48, 38, 48, 38, 48, 38, 48]
# Computing properties
# Optimizing
# Loop for chi=128 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================

# %% [markdown]
# ## Validation of the Ground State

# %% [markdown]
# ### Test with our theoretical energy

# %%
psi = result['psi']
np.abs(result['energy'] - E_true(Jx, Jy, Jz))
# Out:
# 7.130407375655068e-14

# %%
print(E_true(Jx, Jy, Jz))
print(E_false(Jx, Jy, Jz))
# Out:
# -0.24904005789277786
# -0.2476191661911536

# %% [markdown]
# ### Test with our local symmetries

# %%
psi = result['psi']
print("Norm: <psi|psi> = %.1f" % psi.norm)
for k in range(20):
    if k % 2 == 0:
        print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sx', k), ('Sy', k+1), ('Sy', k+2), ('Sx', k+3)])))
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sx', k), ('Sz', k+1), ('Sz', k+2), ('Sx', k+3)])))
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sz', k), ('Sy', k+1), ('Sy', k+2), ('Sz', k+3)])))
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sy', k), ('Sx', k+1), ('Sx', k+2), ('Sy', k+3)])))
# Out:
# Norm: <psi|psi> = 1.0
# Local Symmetry: W0 = -1.0
# Local Symmetry: W1 = -1.0
# Local Symmetry: W2 = -1.0
# Local Symmetry: W3 = -1.0
# Local Symmetry: W4 = -1.0
# Local Symmetry: W5 = -1.0
# Local Symmetry: W6 = -1.0
# Local Symmetry: W7 = -1.0
# Local Symmetry: W8 = -1.0
# Local Symmetry: W9 = -1.0

# %%
# set the region to be the circle `r = x**2 + y**2 = 2, z=.5`

r = 2
theta = np.pi * 9 / 90
Jx = -r*np.cos(theta)
Jy = r*np.sin(theta)
Jz = .5

result = run_atomic(Jx=Jx, Jy=Jy, Jz=Jz, L=8, chi=128, bc='periodic', bc_MPS='finite')
# Out:
# Reading 'L'=8 for config KitaevLadderSnakeCompactModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactModel
# Reading 'bc_MPS'='finite' for config KitaevLadderSnakeCompactModel
# Reading 'Jx'=-1.902113032590307 for config KitaevLadderSnakeCompactModel
# Reading 'Jy'=0.6180339887498948 for config KitaevLadderSnakeCompactModel
# Reading 'Jz'=0.5 for config KitaevLadderSnakeCompactModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# ================================================================================
# sweep 10, age = 16
# Energy = -3.9926303769879272, S = nan, norm_err = 1.2e-09
# Current memory usage 522.9 MB, time elapsed: 6.1 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 5.6183e-20, max_E_trunc = 7.9936e-15
# MPS bond dimensions: [2, 4, 8, 12, 22, 36, 47, 50, 39, 26, 21, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 16
# Energy = -3.9926303769879183, S = nan, norm_err = 4.9e-13
# Current memory usage 522.9 MB, time elapsed: 11.1 s
# Delta E = 8.8818e-16, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 5.2717e-20, max_E_trunc = 8.4377e-15
# MPS bond dimensions: [2, 4, 8, 13, 22, 28, 40, 48, 38, 23, 19, 11, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 16
# Energy = -3.9926303769879183, S = 1.3761035672628337, norm_err = 2.7e-13
# Current memory usage 522.9 MB, time elapsed: 13.8 s
# Delta E = 0.0000e+00, Delta S = nan (per sweep)
# max_trunc_err = 2.9468e-28, max_E_trunc = 8.8818e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 32, 32, 32, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 16
# Energy = -3.9926303769879290, S = 1.3761035672628339, norm_err = 1.8e-12
# Current memory usage 522.9 MB, time elapsed: 17.1 s
# Delta E = -1.0658e-15, Delta S = 2.2204e-17 (per sweep)
# max_trunc_err = 4.8261e-28, max_E_trunc = 9.3259e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 32, 32, 32, 16, 16, 8, 8, 4, 2]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 16, maximum chi = 32
# ================================================================================
# Before the canonicalization:
# Bond dim =  [2, 4, 8, 8, 16, 16, 32, 32, 32, 16, 16, 8, 8, 4, 2]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000007+0j)
# After the canonicalization:
# Bond dim =  [2, 4, 8, 8, 16, 16, 32, 32, 32, 16, 16, 8, 8, 4, 2]
# Computing properties
# Optimizing
# Loop for chi=128 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/tools/params.py:225: UserWarning: unused option ['start_env'] for config TwoSiteDMRGEngine
#
#   warnings.warn(msg.format(keys=sorted(unused), name=self.name))

# %%
psi = result['psi']
print("Norm: <psi|psi> = %.1f" % psi.norm)
for k in range(14):
    if k % 2 == 0:
        print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sx', k), ('Sy', k+1), ('Sy', k+2), ('Sx', k+3)])))
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sx', k), ('Sz', k+1), ('Sz', k+2), ('Sx', k+3)])))
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sz', k), ('Sy', k+1), ('Sy', k+2), ('Sz', k+3)])))
#         print(r"Local Symmetry: W%d = %.1f" % (k//2, 16*psi.expectation_value_term(term=[('Sy', k), ('Sx', k+1), ('Sx', k+2), ('Sy', k+3)])))
# Out:
# Norm: <psi|psi> = 1.0
# Local Symmetry: W0 = -1.0
# Local Symmetry: W1 = -1.0
# Local Symmetry: W2 = -1.0
# Local Symmetry: W3 = -1.0
# Local Symmetry: W4 = -1.0
# Local Symmetry: W5 = -1.0
# Local Symmetry: W6 = -1.0

# %% [markdown]
# # Summary & Plotting
#
# In this section we will summarize over the previous conclusions and then implement some with plotting

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Test
#
# In this subsection we want to test the usage of plt: how to plot the lattice with matplotlib.pyplot and highlight part of the points to indicate our local operators

# %%
# First part: plot the lattice one by one

# create the list to store all the coordinates of lattice points
point_list = [(x, y) for x in range(1, 13) for y in [1, 2]]

# plot all the points one by one
for x, y in point_list:
    plt.plot(x, y, '.', c='black')
    pass

plt.axis('scaled')
plt.ylim((.5,2.5))
plt.box(False)
plt.xticks([])
plt.yticks([])

c1 = plt.Circle((1,1), .2, color='b', fill=False)
plt.gcf().gca().add_artist(c1)

# %% [markdown]
# ## Perturbation

# %% [markdown]
# What kinds of perturbation:
# 1. pure `Jz`: spin pairs (dimers) up or down
#     consider the interactions between the pairs.
#
# Corr. len.
