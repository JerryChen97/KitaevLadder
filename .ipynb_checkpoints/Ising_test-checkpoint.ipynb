# %%
import numpy as np
import itertools
import warnings
import matplotlib.pyplot as plt

import tenpy

from tenpy.networks.site import Site, SpinHalfFermionSite, SpinHalfSite, GroupedSite, SpinSite
from tenpy.tools.misc import to_iterable, to_iterable_of_len, inverse_permutation
from tenpy.networks.mps import MPS  # only to check boundary conditions

from tenpy.models.lattice import Lattice, _parse_sites
from tenpy.models.model import CouplingMPOModel, NearestNeighborModel
from tenpy.models.tf_ising import TFIChain
from tenpy.tools.params import get_parameter


from tenpy.algorithms import dmrg

# statistics
from scipy.optimize import curve_fit
from scipy import stats

__all__ = ['KitaevLadder', 'Ising1D']

# %%
class KitaevLadder(Lattice):    
    """ A ladder coupling two chains of the Kitaev form
    .. image :: /images/lattices/Ladder.*
    Parameters
    ----------
    L : int
        The length of each chain, we have 2*L sites in total.
    sites : (list of) :class:`~tenpy.networks.site.Site`
        The two local lattice sites making the `unit_cell` of the :class:`Lattice`.
        If only a single :class:`~tenpy.networks.site.Site` is given, it is used for both chains.
    **kwargs :
        Additional keyword arguments given to the :class:`Lattice`.
        `basis`, `pos` and `pairs` are set accordingly.
    """
    dim = 1

    def __init__(self, L, sites, **kwargs):
        sites = _parse_sites(sites, 4)
        basis = np.array([[2., 0.]])
        pos = np.array([[0., 0.], [0., 1.], [1., 0.], [1., 1.]])
        kwargs.setdefault('basis', basis)
        kwargs.setdefault('positions', pos)
        kwargs.setdefault('bc', 'periodic')
        kwargs.setdefault('bc_MPS', 'infinite')
        
        NNz = [(0, 1, np.array([0])), (2, 3, np.array([0]))]
        NNx = [(1, 3, np.array([0])), (2, 0, np.array([1]))]
        NNy = [(0, 2, np.array([0])), (3, 1, np.array([1]))]
        nNNa = [(1, 2, np.array([0])), (3, 0, np.array([1]))]
        nNNb = [(0, 3, np.array([0])), (2, 1, np.array([1]))]
        
        kwargs.setdefault('pairs', {})
        kwargs['pairs'].setdefault('nearest_neighbors_x', NNx)
        kwargs['pairs'].setdefault('nearest_neighbors_y', NNy)
        kwargs['pairs'].setdefault('nearest_neighbors_z', NNz)
        kwargs['pairs'].setdefault('next_nearest_neighbors_a', nNNa)
        kwargs['pairs'].setdefault('next_nearest_neighbors_b', nNNb)
        
        Lattice.__init__(self, [L], sites, **kwargs)
        

class Ising1D(CouplingMPOModel):
    def __init__(self, model_params):
        CouplingMPOModel.__init__(self, model_params)

    def init_sites(self, model_params):
        conserve = get_parameter(model_params, 'conserve', 'parity', self.name)
        fs = SpinHalfSite(conserve=conserve)
        return [fs, fs, fs, fs]

    def init_lattice(self, model_params):
        L = get_parameter(model_params, 'L', 3, self.name)
        gs = self.init_sites(model_params)
        model_params.pop("L")
        lat = KitaevLadder(L, gs)
        return lat

    def init_terms(self, model_params):
        Jx = get_parameter(model_params, 'Jx', 0., self.name, True)
        Jy = get_parameter(model_params, 'Jy', 0., self.name, True)
        Jz = get_parameter(model_params, 'Jz', 1., self.name, True)
        g = get_parameter(model_params, 'g', 1., self.name, True)
        
        # onsite terms
        for u in range(len(self.lat.unit_cell)):
            self.add_onsite(-g, u, 'Sigmaz')

        # coupling terms
        for u1, u2, dx in self.lat.pairs['nearest_neighbors_z']:
            self.add_coupling(-Jz, u1, 'Sx', u2, 'Sx', dx)
        for u1, u2, dx in self.lat.pairs['nearest_neighbors_x']:
            self.add_coupling(-Jx, u1, 'Sz', u2, 'Sz', dx)
        for u1, u2, dx in self.lat.pairs['nearest_neighbors_y']:
            self.add_coupling(-Jy, u1, 'Sy', u2, 'Sy', dx)
        for u1, u2, dx in self.lat.pairs['next_nearest_neighbors_a']:
            self.add_coupling(-Jz, u1, 'Sx', u2, 'Sx', dx)
    pass

        
def plot_lattice():
    fig, ax = plt.subplots()
    lat = KitaevLadder(5, None, bc='periodic')
    links_name = 'nearest_neighbors_z'
    lat.plot_coupling(ax, lat.pairs[links_name], linewidth=5.)
    lat.plot_coupling(ax, lat.pairs['next_nearest_neighbors_a'], linewidth=5.)
    # print(lat.pairs['nearest_neighbors'])
    print(lat.unit_cell)
    lat.plot_order(ax=ax, linestyle='--')
    lat.plot_sites(ax)
    # lat.plot_basis(ax, color='g', linewidth=3.)
    ax.set_aspect('equal')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.axis('off')
    # plt.title(links_name)
    plt.show()

# %%
plot_lattice()
# Out:
# [None, None, None, None]

# %%
def run(calc_correlation=True):

    model_params = dict(Jz=1., L=1, verbose=1)
    prod_state = ["up", "down"] * (2 * model_params['L'])
    M = Ising1D(model_params)
    psi = MPS.from_product_state(
        M.lat.mps_sites(), 
        prod_state, 
        bc=M.lat.bc_MPS,
    )

    dmrg_params = {
        'start_env': 10,
#         'mixer': False,  # setting this to True helps to escape local minima
        'mixer': True,
        'mixer_params': {
            'amplitude': 1.e-5,
            'decay': 1.2,
            'disable_after': 30
        },
        'trunc_params': {
            'chi_max': 4,
            'svd_min': 1.e-10,
        },
        'max_E_err': 1.e-10,
        'max_S_err': 1.e-8,
        'max_sweeps': 1000,
        'verbose': 1.,
    }
    
    
#     eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
    
    # we will return this data dictionary in the end, for the further investigation
    data = dict(
        chi_list=[],
        energy_list=[], 
        entropy_list=[], 
        correlation_list=[],
    )
    
#     chi_list = np.arange(4, 129)
    chi_list = [int(2**i) for i in np.arange(4, 7, 0.5)]
    data['chi_list'] = chi_list
    for chi in chi_list:
        
        print("\n")
        print("=" * 80)
        print("="*30 + "START" + "="*30)
        print("=" * 80)
        print("Chi = ", chi, '\n')
        
        eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
        eng.reset_stats()
        eng.trunc_params['chi_max'] = chi
        info = eng.run()
#         print("INFO: \n", info)

        print("Before the canonicalization:")
        print("Bond dim = ", psi.chi)
        
        print("Canonicalizing...")
        psi_before = psi.copy()
        psi.canonical_form()
        ov = psi.overlap(psi_before, charge_sector=0)
        print("The norm is: ",psi.norm)
        print("The overlap is: ", ov)
        print("After the canonicalization:")
        print("Bond dim = ", psi.chi)
        
        print("Computing properties")
        
        energy=info[0]
        data['energy_list'].append(energy)
        
        entropy = np.mean(psi.entanglement_entropy())
        data['entropy_list'].append(entropy)
        
        if calc_correlation:
            correlation = psi.correlation_length()
            data['correlation_list'].append(correlation)
        
        print("Optimizing")
        tenpy.tools.optimization.optimize(3)
        print("Loop for chi=%d done." % chi)
        print("=" * 80)
        print("="*30 + " END " + "="*30)
        print("=" * 80)
        pass
        
    return data

# %%
def run_TFI(calc_correlation=True):

    model_params = dict(
        L=2, 
        J=1., 
        g=1., 
        bc_MPS='infinite', 
        conserve='best',
        verbose=0,
        )
    prod_state = ["up"] * model_params['L']
    M = TFIChain(model_params)
    psi = MPS.from_product_state(
        M.lat.mps_sites(), 
        prod_state, 
        bc=M.lat.bc_MPS,
    )

    dmrg_params = {
        'start_env': 10,
#         'mixer': False,  # setting this to True helps to escape local minima
        'mixer': True,
        'mixer_params': {
            'amplitude': 1.e-5,
            'decay': 1.2,
            'disable_after': 30
        },
        'trunc_params': {
            'chi_max': 4,
            'svd_min': 1.e-10,
        },
        'max_E_err': 1.e-10,
        'max_S_err': 1.e-8,
        'max_sweeps': 1000,
        'verbose': 1.,
    }
    
    
#     eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
    
    # we will return this data dictionary in the end, for the further investigation
    data = dict(
        chi_list=[],
        energy_list=[], 
        entropy_list=[], 
        correlation_list=[],
    )
    
#     chi_list = np.arange(4, 129)
    chi_list = [int(2**i) for i in np.arange(4, 7, 0.5)]
    data['chi_list'] = chi_list
    for chi in chi_list:
        
        print("\n")
        print("=" * 80)
        print("="*30 + "START" + "="*30)
        print("=" * 80)
        print("Chi = ", chi, '\n')
        
        eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
        eng.reset_stats()
        eng.trunc_params['chi_max'] = chi
        info = eng.run()
#         print("INFO: \n", info)

        print("Before the canonicalization:")
        print("Bond dim = ", psi.chi)
        
        print("Canonicalizing...")
        psi_before = psi.copy()
        psi.canonical_form()
        ov = psi.overlap(psi_before, charge_sector=0)
        print("The norm is: ",psi.norm)
        print("The overlap is: ", ov)
        print("After the canonicalization:")
        print("Bond dim = ", psi.chi)
        
        print("Computing properties")
        
        energy=info[0]
        data['energy_list'].append(energy)
        
        entropy = np.mean(psi.entanglement_entropy())
        data['entropy_list'].append(entropy)
        
        if calc_correlation:
            correlation = psi.correlation_length()
            data['correlation_list'].append(correlation)
        
        print("Optimizing")
        tenpy.tools.optimization.optimize(3)
        print("Loop for chi=%d done." % chi)
        print("=" * 80)
        print("="*30 + " END " + "="*30)
        print("=" * 80)
        pass
        
    return data

# %%
def plot_results(data):

    chi_list = data['chi_list']
    energy_list = data['energy_list']
    entropy_list = data['entropy_list']
    correlation_list = data['correlation_list']
    
    plt.plot(chi_list, energy_list, '-o')
    plt.xlabel(r"Bond dimension $\chi$")
    plt.ylabel(r"Ground Energy $E$")
    plt.show()
    
    plt.plot(chi_list, entropy_list, '-o')
    plt.xlabel(r"Bond dimension $\chi$")
    plt.ylabel(r"Entanglement Entropy $S$")
    plt.show()
    
    plt.plot(chi_list, correlation_list, '-o')
    plt.xlabel(r"Bond dimension $\chi$")
    plt.ylabel(r"Correlation Length $\xi$")
    plt.show()
    
    plt.plot(np.log(correlation_list), entropy_list, '-o')
    plt.xlabel(r"log Correlation Length $\xi$")
    plt.ylabel(r"Entanglement Entropy $S$")
    plt.show()

# %%
data = run()
# Out:
# parameter 'verbose'=1 for Ising1D
# parameter 'L'=1 for Ising1D
# parameter 'Jz'=1.0 for Ising1D
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  16
#
# parameter 'verbose'=1.0 for Sweep
# parameter 'trunc_params'={'chi_max': 4, 'svd_min': 1e-10} for Sweep
# Initial sweeps...
# parameter 'start_env'=10 for Sweep
# Updating environment
# ..........
# parameter 'max_sweeps'=1000 for DMRG
# parameter 'max_E_err'=1e-10 for DMRG
# parameter 'max_S_err'=1e-08 for DMRG
# parameter 'mixer'=True for Sweep
# parameter 'mixer_params'={'amplitude': 1e-05, 'decay': 1.2, 'disable_after': 30} for Sweep
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 204
# Energy = 0.3723283380650440, S = nan, norm_err = 3.1e-03
# Current memory usage 189.0 MB, time elapsed: 3.5 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.2751e-11, max_E_trunc = -1.5348e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 324
# Energy = -1.0156911417612697, S = nan, norm_err = 4.5e-02
# Current memory usage 189.0 MB, time elapsed: 7.2 s
# Delta E = -1.3880e-01, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.7505e-12, max_E_trunc = -5.9401e-12
# MPS bond dimensions: [16, 16, 16, 16]
# disable mixer after 30 sweeps, final amplitude 4.21e-08
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 444
# Energy = -1.0156878326894372, S = 0.7179376530312862, norm_err = 2.2e-02
# Current memory usage 189.0 MB, time elapsed: 10.7 s
# Delta E = 3.3091e-07, Delta S = nan (per sweep)
# max_trunc_err = 5.2985e-13, max_E_trunc = -5.6843e-14
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 564
# Energy = -1.0156872616238246, S = 0.7172555883227528, norm_err = 1.5e-02
# Current memory usage 189.0 MB, time elapsed: 13.8 s
# Delta E = 5.7107e-08, Delta S = -6.8206e-05 (per sweep)
# max_trunc_err = 2.7933e-14, max_E_trunc = -2.2737e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 684
# Energy = -0.6656491866815628, S = 0.8028152810542597, norm_err = 6.7e-02
# Current memory usage 189.0 MB, time elapsed: 16.8 s
# Delta E = 3.5004e-02, Delta S = 8.5560e-03 (per sweep)
# max_trunc_err = 2.4372e-14, max_E_trunc = 1.1369e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 804
# Energy = -1.0156871073584171, S = 0.7162120753393678, norm_err = 8.9e-03
# Current memory usage 189.0 MB, time elapsed: 19.7 s
# Delta E = -3.5004e-02, Delta S = -8.6603e-03 (per sweep)
# max_trunc_err = 5.8897e-15, max_E_trunc = 2.2737e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 924
# Energy = -1.0156870742707582, S = 0.7124014674897792, norm_err = 7.1e-03
# Current memory usage 189.0 MB, time elapsed: 22.6 s
# Delta E = 3.3088e-09, Delta S = -3.8106e-04 (per sweep)
# max_trunc_err = 8.3827e-15, max_E_trunc = 4.5475e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 1044
# Energy = -1.0156870562161515, S = 0.7157245183702786, norm_err = 6.2e-03
# Current memory usage 189.0 MB, time elapsed: 25.6 s
# Delta E = 1.8055e-09, Delta S = 3.3231e-04 (per sweep)
# max_trunc_err = 3.9225e-15, max_E_trunc = 1.0232e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 1164
# Energy = -1.0156870450069562, S = 0.7191506472976839, norm_err = 5.9e-03
# Current memory usage 189.0 MB, time elapsed: 28.5 s
# Delta E = 1.1209e-09, Delta S = 3.4261e-04 (per sweep)
# max_trunc_err = 7.8317e-16, max_E_trunc = 1.1369e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 1284
# Energy = -1.0156870370898332, S = 0.7156860306796528, norm_err = 5.5e-03
# Current memory usage 189.0 MB, time elapsed: 31.4 s
# Delta E = 7.9171e-10, Delta S = -3.4646e-04 (per sweep)
# max_trunc_err = 6.0010e-16, max_E_trunc = 1.5916e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 110, age = 1404
# Energy = -1.0156870316198194, S = 0.7074341028547972, norm_err = 4.6e-03
# Current memory usage 189.0 MB, time elapsed: 34.6 s
# Delta E = 5.4700e-10, Delta S = -8.2519e-04 (per sweep)
# max_trunc_err = 8.5852e-16, max_E_trunc = 1.1369e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 120, age = 1524
# Energy = -1.0156870278051429, S = 0.7030431782074831, norm_err = 3.8e-03
# Current memory usage 189.0 MB, time elapsed: 37.6 s
# Delta E = 3.8147e-10, Delta S = -4.3909e-04 (per sweep)
# max_trunc_err = 1.5695e-15, max_E_trunc = 9.0949e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 130, age = 1644
# Energy = -1.0156870252365877, S = 0.7066675255305701, norm_err = 3.6e-03
# Current memory usage 189.0 MB, time elapsed: 40.9 s
# Delta E = 2.5686e-10, Delta S = 3.6243e-04 (per sweep)
# max_trunc_err = 3.6789e-15, max_E_trunc = 1.5916e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 140, age = 1764
# Energy = -1.0156870234014264, S = 0.7150558440922252, norm_err = 4.1e-03
# Current memory usage 189.0 MB, time elapsed: 44.0 s
# Delta E = 1.8352e-10, Delta S = 8.3883e-04 (per sweep)
# max_trunc_err = 2.3939e-15, max_E_trunc = 6.8212e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 150, age = 1884
# Energy = -1.0156870218705478, S = 0.7192250997642139, norm_err = 4.4e-03
# Current memory usage 189.0 MB, time elapsed: 47.1 s
# Delta E = 1.5309e-10, Delta S = 4.1693e-04 (per sweep)
# max_trunc_err = 2.7941e-16, max_E_trunc = 6.8212e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 160, age = 2004
# Energy = -1.0156870204773725, S = 0.7134214903570432, norm_err = 4.3e-03
# Current memory usage 189.0 MB, time elapsed: 50.0 s
# Delta E = 1.3932e-10, Delta S = -5.8036e-04 (per sweep)
# max_trunc_err = 7.7194e-17, max_E_trunc = 2.0464e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 170, age = 2124
# Energy = -1.0156870191951839, S = 0.6987364713066642, norm_err = 3.8e-03
# Current memory usage 189.0 MB, time elapsed: 53.3 s
# Delta E = 1.2822e-10, Delta S = -1.4685e-03 (per sweep)
# max_trunc_err = 1.1788e-16, max_E_trunc = 1.8190e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 180, age = 2244
# Energy = -1.0156870182284479, S = 0.6826058001997503, norm_err = 3.0e-03
# Current memory usage 189.0 MB, time elapsed: 56.3 s
# Delta E = 9.6674e-11, Delta S = -1.6131e-03 (per sweep)
# max_trunc_err = 2.3145e-15, max_E_trunc = 2.2737e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 190, age = 2364
# Energy = -1.0156870175183030, S = 0.6746828602736367, norm_err = 2.2e-03
# Current memory usage 189.0 MB, time elapsed: 59.2 s
# Delta E = 7.1014e-11, Delta S = -7.9229e-04 (per sweep)
# max_trunc_err = 3.3672e-16, max_E_trunc = 2.2737e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 200, age = 2484
# Energy = -1.0156870170577577, S = 0.6790830316150118, norm_err = 2.2e-03
# Current memory usage 189.0 MB, time elapsed: 62.2 s
# Delta E = 4.6055e-11, Delta S = 4.4002e-04 (per sweep)
# max_trunc_err = 1.7251e-15, max_E_trunc = 1.3642e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 210, age = 2604
# Energy = -1.0156870016931521, S = 0.6933247625603270, norm_err = 3.0e-03
# Current memory usage 189.0 MB, time elapsed: 65.1 s
# Delta E = 1.5365e-09, Delta S = 1.4242e-03 (per sweep)
# max_trunc_err = 9.1908e-16, max_E_trunc = 9.0949e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 220, age = 2724
# Energy = -1.0156870165060354, S = 0.7095782716378860, norm_err = 3.8e-03
# Current memory usage 189.2 MB, time elapsed: 68.5 s
# Delta E = -1.4813e-09, Delta S = 1.6254e-03 (per sweep)
# max_trunc_err = 1.1721e-15, max_E_trunc = 3.1832e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 230, age = 2844
# Energy = -1.0156870162423388, S = 0.7191030661914508, norm_err = 4.6e-03
# Current memory usage 189.2 MB, time elapsed: 71.5 s
# Delta E = 2.6370e-11, Delta S = 9.5248e-04 (per sweep)
# max_trunc_err = 1.0554e-15, max_E_trunc = 1.8190e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 240, age = 2964
# Energy = -1.0156870158898528, S = 0.7123346150330054, norm_err = 4.8e-03
# Current memory usage 189.2 MB, time elapsed: 75.0 s
# Delta E = 3.5249e-11, Delta S = -6.7685e-04 (per sweep)
# max_trunc_err = 6.7668e-17, max_E_trunc = 3.6380e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 250, age = 3084
# Energy = -1.0156870154779654, S = 0.6879971475069129, norm_err = 4.4e-03
# Current memory usage 189.2 MB, time elapsed: 78.3 s
# Delta E = 4.1189e-11, Delta S = -2.4337e-03 (per sweep)
# max_trunc_err = 1.9880e-17, max_E_trunc = 1.3642e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 260, age = 3204
# Energy = -1.0156870150723307, S = 0.6530912298717683, norm_err = 3.7e-03
# Current memory usage 189.2 MB, time elapsed: 81.5 s
# Delta E = 4.0563e-11, Delta S = -3.4906e-03 (per sweep)
# max_trunc_err = 1.1680e-16, max_E_trunc = 9.0949e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 270, age = 3324
# Energy = -1.0156870147375230, S = 0.6190045410349270, norm_err = 2.7e-03
# Current memory usage 189.2 MB, time elapsed: 84.8 s
# Delta E = 3.3481e-11, Delta S = -3.4087e-03 (per sweep)
# max_trunc_err = 1.3197e-15, max_E_trunc = 4.5475e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 280, age = 3444
# Energy = -1.0156870145123094, S = 0.5958316406988355, norm_err = 1.7e-03
# Current memory usage 189.2 MB, time elapsed: 88.0 s
# Delta E = 2.2521e-11, Delta S = -2.3173e-03 (per sweep)
# max_trunc_err = 4.5661e-15, max_E_trunc = 1.3642e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 290, age = 3564
# Energy = -1.0156870143847527, S = 0.5897538867157935, norm_err = 1.2e-03
# Current memory usage 189.2 MB, time elapsed: 91.3 s
# Delta E = 1.2756e-11, Delta S = -6.0778e-04 (per sweep)
# max_trunc_err = 3.0036e-15, max_E_trunc = 0.0000e+00
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 300, age = 3684
# Energy = -1.0156870143471224, S = 0.6020988238087470, norm_err = 1.6e-03
# Current memory usage 189.2 MB, time elapsed: 94.5 s
# Delta E = 3.7630e-12, Delta S = 1.2345e-03 (per sweep)
# max_trunc_err = 8.4796e-16, max_E_trunc = -4.5475e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 310, age = 3804
# Energy = -1.0156865709257659, S = 0.6297629049457025, norm_err = 2.6e-03
# Current memory usage 189.2 MB, time elapsed: 97.8 s
# Delta E = 4.4342e-08, Delta S = 2.7664e-03 (per sweep)
# max_trunc_err = 1.8222e-15, max_E_trunc = 4.5475e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 320, age = 3924
# Energy = -1.0156870144282379, S = 0.6657275273580332, norm_err = 3.7e-03
# Current memory usage 189.2 MB, time elapsed: 100.8 s
# Delta E = -4.4350e-08, Delta S = 3.5965e-03 (per sweep)
# max_trunc_err = 7.5167e-16, max_E_trunc = 2.7285e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 330, age = 4044
# Energy = -1.0156870144820687, S = 0.7009624009569873, norm_err = 5.0e-03
# Current memory usage 189.2 MB, time elapsed: 103.7 s
# Delta E = -5.3831e-12, Delta S = 3.5235e-03 (per sweep)
# max_trunc_err = 2.7145e-15, max_E_trunc = 9.0949e-13
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 340, age = 4164
# Energy = -1.0156870144692220, S = 0.7190813019713745, norm_err = 6.1e-03
# Current memory usage 189.2 MB, time elapsed: 106.7 s
# Delta E = 1.2847e-12, Delta S = 1.8119e-03 (per sweep)
# max_trunc_err = 9.1724e-16, max_E_trunc = 3.6380e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 350, age = 4284
# Energy = -1.0156870143429160, S = 0.7045233756187996, norm_err = 6.4e-03
# Current memory usage 189.2 MB, time elapsed: 109.7 s
# Delta E = 1.2631e-11, Delta S = -1.4558e-03 (per sweep)
# max_trunc_err = 6.8710e-16, max_E_trunc = 3.6380e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 360, age = 4404
# Energy = -1.0156870141113359, S = 0.6541181603790964, norm_err = 5.9e-03
# Current memory usage 189.2 MB, time elapsed: 112.7 s
# Delta E = 2.3158e-11, Delta S = -5.0405e-03 (per sweep)
# max_trunc_err = 3.3426e-17, max_E_trunc = 2.7285e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 370, age = 4524
# Energy = -1.0156870138500835, S = 0.5816543976554043, norm_err = 4.6e-03
# Current memory usage 189.3 MB, time elapsed: 115.6 s
# Delta E = 2.6125e-11, Delta S = -7.2464e-03 (per sweep)
# max_trunc_err = 1.5539e-16, max_E_trunc = 2.7285e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 380, age = 4644
# Energy = -1.0156870136222551, S = 0.5081449087616945, norm_err = 3.3e-03
# Current memory usage 189.3 MB, time elapsed: 118.5 s
# Delta E = 2.2783e-11, Delta S = -7.3509e-03 (per sweep)
# max_trunc_err = 4.4155e-16, max_E_trunc = 1.8190e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 390, age = 4764
# Energy = -1.0156870134629798, S = 0.4474623362747920, norm_err = 2.2e-03
# Current memory usage 189.3 MB, time elapsed: 121.5 s
# Delta E = 1.5928e-11, Delta S = -6.0683e-03 (per sweep)
# max_trunc_err = 4.0412e-16, max_E_trunc = 4.5475e-12
# MPS bond dimensions: [16, 16, 16, 16]
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/tools/params.py:124: UserWarning: unused parameters for Sweep trunc_params:
# ['chi_max', 'svd_min']
#   warnings.warn(msg.format(keys=sorted(unused), descr=warn))
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/tools/params.py:124: UserWarning: unused parameter ['start_env'] for Sweep
#
#   warnings.warn(msg.format(keys=sorted(unused), descr=warn))
# Updating environment
# .....
# ================================================================================
# sweep 400, age = 4884
# Energy = -1.0156870133657776, S = 0.4055848833266784, norm_err = 1.4e-03
# Current memory usage 189.3 MB, time elapsed: 124.5 s
# Delta E = 9.7202e-12, Delta S = -4.1877e-03 (per sweep)
# max_trunc_err = 3.4237e-16, max_E_trunc = 0.0000e+00
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 410, age = 5004
# Energy = -1.0156870133174607, S = 0.3836765763842166, norm_err = 7.8e-04
# Current memory usage 189.3 MB, time elapsed: 127.4 s
# Delta E = 4.8317e-12, Delta S = -2.1908e-03 (per sweep)
# max_trunc_err = 9.2021e-16, max_E_trunc = 2.7285e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 420, age = 5124
# Energy = -1.0156870120015355, S = 0.3828758386159027, norm_err = 6.0e-04
# Current memory usage 189.3 MB, time elapsed: 130.4 s
# Delta E = 1.3159e-10, Delta S = -8.0074e-05 (per sweep)
# max_trunc_err = 1.4134e-15, max_E_trunc = 1.8190e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 430, age = 5244
# Energy = -1.0156870133345137, S = 0.4005771983075924, norm_err = 9.8e-04
# Current memory usage 189.3 MB, time elapsed: 133.3 s
# Delta E = -1.3330e-10, Delta S = 1.7701e-03 (per sweep)
# max_trunc_err = 1.3932e-15, max_E_trunc = 4.5475e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 440, age = 5364
# Energy = -1.0156870134024985, S = 0.4401007240968214, norm_err = 1.8e-03
# Current memory usage 189.3 MB, time elapsed: 136.3 s
# Delta E = -6.7985e-12, Delta S = 3.9524e-03 (per sweep)
# max_trunc_err = 1.7707e-15, max_E_trunc = 2.7285e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 450, age = 5484
# Energy = -1.0156870135136842, S = 0.5003229402136171, norm_err = 3.0e-03
# Current memory usage 189.3 MB, time elapsed: 139.2 s
# Delta E = -1.1119e-11, Delta S = 6.0222e-03 (per sweep)
# max_trunc_err = 3.3872e-15, max_E_trunc = 2.7285e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 460, age = 5604
# Energy = -1.0156870136619318, S = 0.5764024004684709, norm_err = 4.5e-03
# Current memory usage 189.3 MB, time elapsed: 142.2 s
# Delta E = -1.4825e-11, Delta S = 7.6079e-03 (per sweep)
# max_trunc_err = 1.2864e-15, max_E_trunc = 3.6380e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 470, age = 5724
# Energy = -1.0156870138392833, S = 0.6570796895571389, norm_err = 6.6e-03
# Current memory usage 189.3 MB, time elapsed: 145.1 s
# Delta E = -1.7735e-11, Delta S = 8.0677e-03 (per sweep)
# max_trunc_err = 1.6540e-15, max_E_trunc = 2.7285e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 480, age = 5844
# Energy = -1.0156870139563807, S = 0.7124351046454660, norm_err = 8.4e-03
# Current memory usage 189.3 MB, time elapsed: 148.0 s
# Delta E = -1.1710e-11, Delta S = 5.5355e-03 (per sweep)
# max_trunc_err = 4.8867e-16, max_E_trunc = 1.8190e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 490, age = 5964
# Energy = -1.0156870082357727, S = 0.7072941271678641, norm_err = 9.1e-03
# Current memory usage 189.3 MB, time elapsed: 151.0 s
# Delta E = 5.7206e-10, Delta S = -5.1410e-04 (per sweep)
# max_trunc_err = 1.2844e-15, max_E_trunc = 2.7285e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 500, age = 6084
# Energy = -1.0156870137441274, S = 0.6294664448207874, norm_err = 8.0e-03
# Current memory usage 189.3 MB, time elapsed: 153.9 s
# Delta E = -5.5084e-10, Delta S = -7.7828e-03 (per sweep)
# max_trunc_err = 1.0541e-16, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 510, age = 6204
# Energy = -1.0156870134754854, S = 0.5066054805142413, norm_err = 5.9e-03
# Current memory usage 189.3 MB, time elapsed: 156.8 s
# Delta E = 2.6864e-11, Delta S = -1.2286e-02 (per sweep)
# max_trunc_err = 1.2485e-17, max_E_trunc = 1.8190e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 520, age = 6324
# Energy = -1.0156870086677827, S = 0.3831615258766308, norm_err = 3.7e-03
# Current memory usage 189.3 MB, time elapsed: 159.8 s
# Delta E = 4.8077e-10, Delta S = -1.2344e-02 (per sweep)
# max_trunc_err = 7.4394e-17, max_E_trunc = 4.5475e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 530, age = 6444
# Energy = -1.0156870131073674, S = 0.2868077065994580, norm_err = 2.2e-03
# Current memory usage 189.3 MB, time elapsed: 162.7 s
# Delta E = -4.4396e-10, Delta S = -9.6354e-03 (per sweep)
# max_trunc_err = 1.3498e-16, max_E_trunc = 7.2760e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 540, age = 6564
# Energy = -1.0156870129129629, S = 0.2231649889229622, norm_err = 1.2e-03
# Current memory usage 189.3 MB, time elapsed: 165.7 s
# Delta E = 1.9440e-11, Delta S = -6.3643e-03 (per sweep)
# max_trunc_err = 3.0335e-16, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 550, age = 6684
# Energy = -1.0156870129848130, S = 0.1844350452255936, norm_err = 6.7e-04
# Current memory usage 189.3 MB, time elapsed: 168.6 s
# Delta E = -7.1850e-12, Delta S = -3.8730e-03 (per sweep)
# max_trunc_err = 5.4247e-16, max_E_trunc = 4.5475e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 560, age = 6804
# Energy = -1.0156870129633262, S = 0.1636250917416298, norm_err = 3.8e-04
# Current memory usage 189.3 MB, time elapsed: 171.5 s
# Delta E = 2.1487e-12, Delta S = -2.0810e-03 (per sweep)
# max_trunc_err = 1.6996e-16, max_E_trunc = 4.5475e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 570, age = 6924
# Energy = -1.0156870129510480, S = 0.1542722911908766, norm_err = 2.2e-04
# Current memory usage 189.3 MB, time elapsed: 174.4 s
# Delta E = 1.2278e-12, Delta S = -9.3528e-04 (per sweep)
# max_trunc_err = 1.9735e-16, max_E_trunc = 7.2760e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 580, age = 7044
# Energy = -1.0156870129491153, S = 0.1549330176650080, norm_err = 1.9e-04
# Current memory usage 189.3 MB, time elapsed: 177.3 s
# Delta E = 1.9327e-13, Delta S = 6.6073e-05 (per sweep)
# max_trunc_err = 2.0931e-16, max_E_trunc = 4.5475e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 590, age = 7164
# Energy = -1.0156870116525170, S = 0.1638595157947720, norm_err = 2.8e-04
# Current memory usage 189.3 MB, time elapsed: 180.4 s
# Delta E = 1.2966e-10, Delta S = 8.9265e-04 (per sweep)
# max_trunc_err = 5.8573e-17, max_E_trunc = 6.3665e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 600, age = 7284
# Energy = -1.0156870129599156, S = 0.1811407464764773, norm_err = 4.5e-04
# Current memory usage 189.3 MB, time elapsed: 183.4 s
# Delta E = -1.3074e-10, Delta S = 1.7281e-03 (per sweep)
# max_trunc_err = 1.2484e-16, max_E_trunc = 7.2760e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 610, age = 7404
# Energy = -1.0156870129941353, S = 0.2086946140236582, norm_err = 7.2e-04
# Current memory usage 189.3 MB, time elapsed: 186.5 s
# Delta E = -3.4220e-12, Delta S = 2.7554e-03 (per sweep)
# max_trunc_err = 8.9798e-17, max_E_trunc = 8.1855e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 620, age = 7524
# Energy = -1.0156870130358584, S = 0.2512268068985882, norm_err = 1.2e-03
# Current memory usage 189.3 MB, time elapsed: 189.4 s
# Delta E = -4.1723e-12, Delta S = 4.2532e-03 (per sweep)
# max_trunc_err = 1.4377e-16, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 630, age = 7644
# Energy = -1.0156870131020241, S = 0.3126288645101332, norm_err = 2.0e-03
# Current memory usage 189.3 MB, time elapsed: 192.3 s
# Delta E = -6.6166e-12, Delta S = 6.1402e-03 (per sweep)
# max_trunc_err = 4.6354e-16, max_E_trunc = 3.6380e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 640, age = 7764
# Energy = -1.0156870084537104, S = 0.3987113548702971, norm_err = 3.3e-03
# Current memory usage 189.3 MB, time elapsed: 195.6 s
# Delta E = 4.6483e-10, Delta S = 8.6082e-03 (per sweep)
# max_trunc_err = 2.5759e-16, max_E_trunc = 8.1855e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 650, age = 7884
# Energy = -1.0156870133785105, S = 0.5076825147337587, norm_err = 5.2e-03
# Current memory usage 189.3 MB, time elapsed: 199.2 s
# Delta E = -4.9248e-10, Delta S = 1.0897e-02 (per sweep)
# max_trunc_err = 8.0935e-16, max_E_trunc = 1.8190e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 660, age = 8004
# Energy = -1.0156870136045200, S = 0.6282381731307024, norm_err = 8.3e-03
# Current memory usage 189.3 MB, time elapsed: 202.2 s
# Delta E = -2.2601e-11, Delta S = 1.2056e-02 (per sweep)
# max_trunc_err = 5.8268e-16, max_E_trunc = 1.0004e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 670, age = 8124
# Energy = -1.0156870137900569, S = 0.7122814862123338, norm_err = 1.1e-02
# Current memory usage 189.3 MB, time elapsed: 205.1 s
# Delta E = -1.8554e-11, Delta S = 8.4043e-03 (per sweep)
# max_trunc_err = 3.9400e-15, max_E_trunc = 3.6380e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 680, age = 8244
# Energy = -1.0156870137739133, S = 0.6898335098890418, norm_err = 1.2e-02
# Current memory usage 189.3 MB, time elapsed: 208.0 s
# Delta E = 1.6144e-12, Delta S = -2.2448e-03 (per sweep)
# max_trunc_err = 1.7650e-15, max_E_trunc = 7.2760e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 690, age = 8364
# Energy = -1.0156870132489075, S = 0.5490382507898288, norm_err = 9.0e-03
# Current memory usage 189.3 MB, time elapsed: 210.9 s
# Delta E = 5.2501e-11, Delta S = -1.4080e-02 (per sweep)
# max_trunc_err = 3.8472e-16, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 700, age = 8484
# Energy = -1.0156870132295808, S = 0.3712688409828566, norm_err = 5.2e-03
# Current memory usage 189.3 MB, time elapsed: 213.8 s
# Delta E = 1.9327e-12, Delta S = -1.7777e-02 (per sweep)
# max_trunc_err = 2.2676e-17, max_E_trunc = 7.2760e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 710, age = 8604
# Energy = -1.0156870130390416, S = 0.2321902999530811, norm_err = 2.6e-03
# Current memory usage 189.3 MB, time elapsed: 216.7 s
# Delta E = 1.9054e-11, Delta S = -1.3908e-02 (per sweep)
# max_trunc_err = 5.2036e-17, max_E_trunc = 1.2733e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 720, age = 8724
# Energy = -1.0156870128528226, S = 0.1482132108968630, norm_err = 1.2e-03
# Current memory usage 189.3 MB, time elapsed: 219.6 s
# Delta E = 1.8622e-11, Delta S = -8.3977e-03 (per sweep)
# max_trunc_err = 1.0735e-16, max_E_trunc = 9.0949e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 730, age = 8844
# Energy = -1.0156870129053459, S = 0.1025031397855642, norm_err = 5.4e-04
# Current memory usage 189.3 MB, time elapsed: 222.4 s
# Delta E = -5.2523e-12, Delta S = -4.5710e-03 (per sweep)
# max_trunc_err = 6.1473e-17, max_E_trunc = 9.0949e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 740, age = 8964
# Energy = -1.0156870128266746, S = 0.0790375568340874, norm_err = 2.6e-04
# Current memory usage 189.3 MB, time elapsed: 225.3 s
# Delta E = 7.8671e-12, Delta S = -2.3466e-03 (per sweep)
# max_trunc_err = 1.9745e-16, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 750, age = 9084
# Energy = -1.0156870128791979, S = 0.0667406692500303, norm_err = 1.4e-04
# Current memory usage 189.3 MB, time elapsed: 228.3 s
# Delta E = -5.2523e-12, Delta S = -1.2297e-03 (per sweep)
# max_trunc_err = 7.7538e-17, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 760, age = 9204
# Energy = -1.0156870128737410, S = 0.0604016455616072, norm_err = 8.0e-05
# Current memory usage 189.3 MB, time elapsed: 231.2 s
# Delta E = 5.4570e-13, Delta S = -6.3390e-04 (per sweep)
# max_trunc_err = 1.2253e-17, max_E_trunc = 1.0914e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 770, age = 9324
# Energy = -1.0156870128703304, S = 0.0575341480569901, norm_err = 5.1e-05
# Current memory usage 189.5 MB, time elapsed: 234.1 s
# Delta E = 3.4106e-13, Delta S = -2.8675e-04 (per sweep)
# max_trunc_err = 7.1583e-17, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 780, age = 9444
# Energy = -1.0156870128685114, S = 0.0566146155836367, norm_err = 4.1e-05
# Current memory usage 189.5 MB, time elapsed: 237.0 s
# Delta E = 1.8190e-13, Delta S = -9.1953e-05 (per sweep)
# max_trunc_err = 1.1570e-17, max_E_trunc = 9.0949e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 790, age = 9564
# Energy = -1.0156870128680566, S = 0.0573943906668049, norm_err = 4.1e-05
# Current memory usage 189.5 MB, time elapsed: 239.8 s
# Delta E = 4.5475e-14, Delta S = 7.7978e-05 (per sweep)
# max_trunc_err = 9.0989e-17, max_E_trunc = 7.2760e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 800, age = 9684
# Energy = -1.0156870128676019, S = 0.0595397969969315, norm_err = 4.9e-05
# Current memory usage 189.5 MB, time elapsed: 242.7 s
# Delta E = 4.5475e-14, Delta S = 2.1454e-04 (per sweep)
# max_trunc_err = 5.9074e-18, max_E_trunc = 1.0914e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 810, age = 9804
# Energy = -1.0156870128671471, S = 0.0632221743487307, norm_err = 6.7e-05
# Current memory usage 189.5 MB, time elapsed: 245.6 s
# Delta E = 4.5475e-14, Delta S = 3.6824e-04 (per sweep)
# max_trunc_err = 1.3340e-17, max_E_trunc = 3.6380e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 820, age = 9924
# Energy = -1.0156870128726041, S = 0.0688720560995407, norm_err = 9.6e-05
# Current memory usage 189.5 MB, time elapsed: 248.5 s
# Delta E = -5.4570e-13, Delta S = 5.6499e-04 (per sweep)
# max_trunc_err = 1.3342e-17, max_E_trunc = 9.0949e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 830, age = 10044
# Energy = -1.0156870128737410, S = 0.0772863416381634, norm_err = 1.4e-04
# Current memory usage 189.5 MB, time elapsed: 251.4 s
# Delta E = -1.1369e-13, Delta S = 8.4143e-04 (per sweep)
# max_trunc_err = 9.0350e-18, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 840, age = 10164
# Energy = -1.0156870128814717, S = 0.0897527620519158, norm_err = 2.2e-04
# Current memory usage 189.5 MB, time elapsed: 254.3 s
# Delta E = -7.7307e-13, Delta S = 1.2466e-03 (per sweep)
# max_trunc_err = 1.2862e-17, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 850, age = 10284
# Energy = -1.0156870128887476, S = 0.1080632326434020, norm_err = 3.5e-04
# Current memory usage 189.8 MB, time elapsed: 257.2 s
# Delta E = -7.2760e-13, Delta S = 1.8310e-03 (per sweep)
# max_trunc_err = 2.0448e-17, max_E_trunc = 1.0914e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 860, age = 10404
# Energy = -1.0156870129035269, S = 0.1354563131315895, norm_err = 5.8e-04
# Current memory usage 189.8 MB, time elapsed: 260.1 s
# Delta E = -1.4779e-12, Delta S = 2.7393e-03 (per sweep)
# max_trunc_err = 3.3731e-17, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 870, age = 10524
# Energy = -1.0156870129310391, S = 0.1765955441771083, norm_err = 9.8e-04
# Current memory usage 189.8 MB, time elapsed: 263.0 s
# Delta E = -2.7512e-12, Delta S = 4.1139e-03 (per sweep)
# max_trunc_err = 5.8921e-17, max_E_trunc = 1.2733e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 880, age = 10644
# Energy = -1.0156870129746949, S = 0.2381753782264962, norm_err = 1.7e-03
# Current memory usage 189.8 MB, time elapsed: 265.9 s
# Delta E = -4.3656e-12, Delta S = 6.1580e-03 (per sweep)
# max_trunc_err = 1.9906e-16, max_E_trunc = 7.2760e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 890, age = 10764
# Energy = -1.0156870130606421, S = 0.3300306848267734, norm_err = 3.1e-03
# Current memory usage 189.8 MB, time elapsed: 268.8 s
# Delta E = -8.5947e-12, Delta S = 9.1855e-03 (per sweep)
# max_trunc_err = 1.0401e-16, max_E_trunc = 0.0000e+00
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 900, age = 10884
# Energy = -1.0156870132022959, S = 0.4580086447848412, norm_err = 5.5e-03
# Current memory usage 189.8 MB, time elapsed: 271.7 s
# Delta E = -1.4165e-11, Delta S = 1.2798e-02 (per sweep)
# max_trunc_err = 4.5305e-16, max_E_trunc = 9.0949e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 910, age = 11004
# Energy = -1.0156870133985194, S = 0.6053595572555448, norm_err = 9.1e-03
# Current memory usage 190.0 MB, time elapsed: 274.6 s
# Delta E = -1.9622e-11, Delta S = 1.4735e-02 (per sweep)
# max_trunc_err = 1.8388e-15, max_E_trunc = 1.2733e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 920, age = 11124
# Energy = -1.0156870135836016, S = 0.7101986053377676, norm_err = 1.2e-02
# Current memory usage 190.0 MB, time elapsed: 277.5 s
# Delta E = -1.8508e-11, Delta S = 1.0484e-02 (per sweep)
# max_trunc_err = 5.4278e-16, max_E_trunc = 5.4570e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 930, age = 11244
# Energy = -1.0156870135917870, S = 0.6825133352330834, norm_err = 1.3e-02
# Current memory usage 190.0 MB, time elapsed: 280.4 s
# Delta E = -8.1855e-13, Delta S = -2.7685e-03 (per sweep)
# max_trunc_err = 3.5209e-15, max_E_trunc = 1.8190e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 940, age = 11364
# Energy = -1.0156870133639586, S = 0.5123655614133188, norm_err = 9.3e-03
# Current memory usage 190.0 MB, time elapsed: 283.3 s
# Delta E = 2.2783e-11, Delta S = -1.7015e-02 (per sweep)
# max_trunc_err = 5.9241e-16, max_E_trunc = 9.0949e-12
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 950, age = 11484
# Energy = -1.0156870131106643, S = 0.3129960170439952, norm_err = 4.8e-03
# Current memory usage 190.0 MB, time elapsed: 286.3 s
# Delta E = 2.5329e-11, Delta S = -1.9937e-02 (per sweep)
# max_trunc_err = 2.5573e-16, max_E_trunc = 1.0914e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 960, age = 11604
# Energy = -1.0156870129590061, S = 0.1729161669144766, norm_err = 2.0e-03
# Current memory usage 190.0 MB, time elapsed: 289.2 s
# Delta E = 1.5166e-11, Delta S = -1.4008e-02 (per sweep)
# max_trunc_err = 1.2601e-18, max_E_trunc = 3.6380e-12
# MPS bond dimensions: [16, 15, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 970, age = 11724
# Energy = -1.0156870128969331, S = 0.0977052978874286, norm_err = 8.0e-04
# Current memory usage 190.0 MB, time elapsed: 292.2 s
# Delta E = 6.2073e-12, Delta S = -7.5211e-03 (per sweep)
# max_trunc_err = 1.6357e-16, max_E_trunc = 1.8190e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 980, age = 11844
# Energy = -1.0156869489401288, S = 0.0623333583928186, norm_err = 3.1e-04
# Current memory usage 190.3 MB, time elapsed: 295.1 s
# Delta E = 6.3957e-09, Delta S = -3.5372e-03 (per sweep)
# max_trunc_err = 4.6066e-17, max_E_trunc = 1.2733e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 990, age = 11964
# Energy = -1.0156870128653281, S = 0.0461309051774210, norm_err = 1.3e-04
# Current memory usage 190.3 MB, time elapsed: 298.1 s
# Delta E = -6.3925e-09, Delta S = -1.6202e-03 (per sweep)
# max_trunc_err = 1.1708e-16, max_E_trunc = 1.0914e-11
# MPS bond dimensions: [16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 1000, age = 12084
# Energy = -1.0156870128612354, S = 0.0387828481753699, norm_err = 5.7e-05
# Current memory usage 190.3 MB, time elapsed: 300.9 s
# Delta E = 4.0927e-13, Delta S = -7.3481e-04 (per sweep)
# max_trunc_err = 1.4366e-17, max_E_trunc = 7.2760e-12
# MPS bond dimensions: [16, 16, 16, 16]
# norm_tol=1.00e-05 not reached, norm_err=5.66e-05
# Updating environment
# .....
# Updating environment
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:446: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# .....
# Updating environment
# .....
# Updating environment
# .....
# Updating environment
# .....
# DMRG: norm_tol 1.00e-05 not reached by updating the environment, current norm_err = 2.48e-05
# Call psi.canonical_form()
# ================================================================================
# DMRG finished after 1000 sweeps.
# total size = 12284, maximum chi = 7
# ================================================================================
# Before the canonicalization:
# Bond dim =  [7, 7, 7, 7]
# Canonicalizing...
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2174: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2018: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   self.canonical_form_infinite(renormalize)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2195: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2174: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2195: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# The norm is:  1.0
# The overlap is:  (1.0000000000000018+0j)
# After the canonicalization:
# Bond dim =  [6, 6, 6, 6]
# Computing properties
# Optimizing
# Loop for chi=16 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  22
#
# Initial sweeps...
# Updating environment
# ..........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 204
# Energy = -1.0156870128528084, S = nan, norm_err = 1.2e-15
# Current memory usage 190.3 MB, time elapsed: 1.9 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.3176e-21, max_E_trunc = 1.1369e-13
# MPS bond dimensions: [8, 7, 7, 9]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 324
# Energy = -1.0156870128527657, S = nan, norm_err = 1.3e-15
# Current memory usage 190.3 MB, time elapsed: 4.0 s
# Delta E = 4.2633e-15, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.7062e-21, max_E_trunc = 2.2737e-13
# MPS bond dimensions: [7, 6, 7, 7]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 444
# Energy = -1.0156870128528936, S = 0.0261747609094906, norm_err = 3.1e-16
# Current memory usage 190.3 MB, time elapsed: 4.9 s
# Delta E = -1.2790e-14, Delta S = nan (per sweep)
# max_trunc_err = 5.4362e-22, max_E_trunc = 5.6843e-14
# MPS bond dimensions: [9, 9, 9, 9]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 564
# Energy = -1.0156870128528652, S = 0.0261747609094969, norm_err = 4.2e-16
# Current memory usage 190.3 MB, time elapsed: 5.9 s
# Delta E = 2.8422e-15, Delta S = 6.3005e-16 (per sweep)
# max_trunc_err = 5.4366e-22, max_E_trunc = 3.4106e-13
# MPS bond dimensions: [9, 9, 9, 9]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 564, maximum chi = 9
# ================================================================================
# Before the canonicalization:
# Bond dim =  [9, 9, 9, 9]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000016+0j)
# After the canonicalization:
# Bond dim =  [6, 6, 6, 6]
# Computing properties
# Optimizing
# Loop for chi=22 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  32
#
# Initial sweeps...
# Updating environment
# ..
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2174: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2195: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# ........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 204
# Energy = -1.0156870128527586, S = nan, norm_err = 1.1e-15
# Current memory usage 190.3 MB, time elapsed: 2.2 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.6464e-21, max_E_trunc = 1.4211e-13
# MPS bond dimensions: [7, 8, 8, 8]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 324
# Energy = -1.0156870128527942, S = nan, norm_err = 1.6e-15
# Current memory usage 190.3 MB, time elapsed: 4.4 s
# Delta E = -3.5527e-15, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 6.0148e-21, max_E_trunc = 5.6843e-14
# MPS bond dimensions: [7, 9, 6, 9]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 444
# Energy = -1.0156870128528368, S = 0.0261747609094863, norm_err = 6.2e-16
# Current memory usage 190.3 MB, time elapsed: 5.3 s
# Delta E = -4.2633e-15, Delta S = nan (per sweep)
# max_trunc_err = 5.4358e-22, max_E_trunc = 3.9790e-13
# MPS bond dimensions: [9, 9, 9, 9]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 564
# Energy = -1.0156870128529221, S = 0.0261747609094899, norm_err = 6.6e-16
# Current memory usage 190.3 MB, time elapsed: 6.3 s
# Delta E = -8.5265e-15, Delta S = 3.5284e-16 (per sweep)
# max_trunc_err = 5.4357e-22, max_E_trunc = 1.1369e-13
# MPS bond dimensions: [9, 9, 9, 9]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 564, maximum chi = 9
# ================================================================================
# Before the canonicalization:
# Bond dim =  [9, 9, 9, 9]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (0.9999999999999981+0j)
# After the canonicalization:
# Bond dim =  [6, 6, 6, 6]
# Computing properties
# Optimizing
# Loop for chi=32 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  45
#
# Initial sweeps...
# Updating environment
# ..
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2174: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2195: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# ........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 204
# Energy = -1.0156870128528297, S = nan, norm_err = 9.4e-16
# Current memory usage 190.3 MB, time elapsed: 2.3 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.0308e-21, max_E_trunc = 1.4211e-13
# MPS bond dimensions: [6, 8, 7, 7]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 324
# Energy = -1.0156870128528155, S = nan, norm_err = 1.7e-15
# Current memory usage 190.3 MB, time elapsed: 4.4 s
# Delta E = 1.4211e-15, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.1617e-21, max_E_trunc = 3.9790e-13
# MPS bond dimensions: [8, 7, 7, 9]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 444
# Energy = -1.0156870128528581, S = 0.0261747609094899, norm_err = 4.3e-16
# Current memory usage 190.3 MB, time elapsed: 5.3 s
# Delta E = -4.2633e-15, Delta S = nan (per sweep)
# max_trunc_err = 5.4367e-22, max_E_trunc = 1.7053e-13
# MPS bond dimensions: [9, 9, 9, 9]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 564
# Energy = -1.0156870128528510, S = 0.0261747609094808, norm_err = 5.1e-16
# Current memory usage 190.3 MB, time elapsed: 6.3 s
# Delta E = 7.1054e-16, Delta S = -9.1038e-16 (per sweep)
# max_trunc_err = 5.4370e-22, max_E_trunc = 2.2737e-13
# MPS bond dimensions: [9, 9, 9, 9]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 564, maximum chi = 9
# ================================================================================
# Before the canonicalization:
# Bond dim =  [9, 9, 9, 9]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000013+0j)
# After the canonicalization:
# Bond dim =  [6, 6, 6, 6]
# Computing properties
# Optimizing
# Loop for chi=45 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  64
#
# Initial sweeps...
# Updating environment
# ..
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2174: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2195: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# ........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 204
# Energy = -1.0156870128528190, S = nan, norm_err = 2.1e-15
# Current memory usage 190.3 MB, time elapsed: 2.2 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 7.7105e-21, max_E_trunc = 2.8422e-14
# MPS bond dimensions: [6, 8, 7, 8]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 324
# Energy = -1.0156870128529505, S = nan, norm_err = 1.6e-15
# Current memory usage 190.3 MB, time elapsed: 4.2 s
# Delta E = -1.3145e-14, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.0759e-21, max_E_trunc = 1.7053e-13
# MPS bond dimensions: [6, 8, 6, 9]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 444
# Energy = -1.0156870128528865, S = 0.0261747609094872, norm_err = 4.2e-16
# Current memory usage 190.3 MB, time elapsed: 5.2 s
# Delta E = 6.3949e-15, Delta S = nan (per sweep)
# max_trunc_err = 5.4360e-22, max_E_trunc = 1.7053e-13
# MPS bond dimensions: [9, 9, 9, 9]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 564
# Energy = -1.0156870128529079, S = 0.0261747609094912, norm_err = 4.3e-16
# Current memory usage 190.3 MB, time elapsed: 6.1 s
# Delta E = -2.1316e-15, Delta S = 3.9656e-16 (per sweep)
# max_trunc_err = 5.4359e-22, max_E_trunc = 0.0000e+00
# MPS bond dimensions: [9, 9, 9, 9]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 564, maximum chi = 9
# ================================================================================
# Before the canonicalization:
# Bond dim =  [9, 9, 9, 9]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (0.9999999999999981+0j)
# After the canonicalization:
# Bond dim =  [6, 6, 6, 6]
# Computing properties
# Optimizing
# Loop for chi=64 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  90
#
# Initial sweeps...
# Updating environment
# ..
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2174: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2195: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])
# ........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 204
# Energy = -1.0156870128528652, S = nan, norm_err = 1.4e-15
# Current memory usage 190.3 MB, time elapsed: 2.2 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.2496e-21, max_E_trunc = 5.6843e-14
# MPS bond dimensions: [7, 8, 6, 9]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 324
# Energy = -1.0156870128528794, S = nan, norm_err = 1.2e-15
# Current memory usage 190.3 MB, time elapsed: 4.2 s
# Delta E = -1.4211e-15, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.6077e-20, max_E_trunc = 4.5475e-13
# MPS bond dimensions: [6, 9, 6, 10]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 444
# Energy = -1.0156870128529008, S = 0.0261747609094982, norm_err = 5.9e-16
# Current memory usage 190.3 MB, time elapsed: 5.2 s
# Delta E = -2.1316e-15, Delta S = nan (per sweep)
# max_trunc_err = 5.4362e-22, max_E_trunc = 2.2737e-13
# MPS bond dimensions: [9, 9, 9, 9]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 564
# Energy = -1.0156870128528226, S = 0.0261747609094921, norm_err = 4.8e-16
# Current memory usage 190.3 MB, time elapsed: 6.2 s
# Delta E = 7.8160e-15, Delta S = -6.1721e-16 (per sweep)
# max_trunc_err = 5.4361e-22, max_E_trunc = 1.1369e-13
# MPS bond dimensions: [9, 9, 9, 9]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 564, maximum chi = 9
# ================================================================================
# Before the canonicalization:
# Bond dim =  [9, 9, 9, 9]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000013+0j)
# After the canonicalization:
# Bond dim =  [6, 6, 6, 6]
# Computing properties
# Optimizing
# Loop for chi=90 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2174: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(i1, Gl, Wr)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2195: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   Gl, Wr = self._canonical_form_correct_left(j1, Gl, Wr_list[j1 % L])

# %%
plot_results(data)

# %%
chi_list = data['chi_list']
energy_list = data['energy_list']
entropy_list = data['entropy_list']
correlation_list = data['correlation_list']

# entropy_list = entropy_list[0:5]
# correlation_list = correlation_list[0:5]
log_xi = np.log(correlation_list)

print((entropy_list[-1] - entropy_list[0])/(log_xi[-1] - log_xi[0]) * 6)
# Out:
# -1.0857554652108882e-09

# %%
data=run_TFI()
# Out:
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  16
#
# parameter 'verbose'=1.0 for Sweep
# parameter 'trunc_params'={'chi_max': 4, 'svd_min': 1e-10} for Sweep
# Initial sweeps...
# parameter 'start_env'=10 for Sweep
# Updating environment
# ..........
# parameter 'max_sweeps'=1000 for DMRG
# parameter 'max_E_err'=1e-10 for DMRG
# parameter 'max_S_err'=1e-08 for DMRG
# parameter 'mixer'=True for Sweep
# parameter 'mixer_params'={'amplitude': 1e-05, 'decay': 1.2, 'disable_after': 30} for Sweep
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 200
# Energy = -1.2732294404668103, S = nan, norm_err = 9.1e-04
# Current memory usage 178.7 MB, time elapsed: 1.8 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 6.2977e-10, max_E_trunc = 2.0405e-09
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 320
# Energy = -1.2732370232930705, S = nan, norm_err = 5.4e-04
# Current memory usage 178.7 MB, time elapsed: 3.4 s
# Delta E = -7.5828e-07, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 8.3432e-09, max_E_trunc = 2.6269e-08
# MPS bond dimensions: [16, 16]
# disable mixer after 30 sweeps, final amplitude 4.21e-08
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 440
# Energy = -1.2732382655098746, S = 0.6863540298218318, norm_err = 3.5e-04
# Current memory usage 178.7 MB, time elapsed: 4.8 s
# Delta E = -1.2422e-07, Delta S = nan (per sweep)
# max_trunc_err = 1.9050e-08, max_E_trunc = 5.9667e-08
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 560
# Energy = -1.2732386358999435, S = 0.7062256809435722, norm_err = 2.9e-04
# Current memory usage 178.7 MB, time elapsed: 5.8 s
# Delta E = -3.7039e-08, Delta S = 1.9872e-03 (per sweep)
# max_trunc_err = 1.4677e-08, max_E_trunc = 9.1585e-08
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 680
# Energy = -1.2732388248019220, S = 0.7210315248694521, norm_err = 1.4e-04
# Current memory usage 178.7 MB, time elapsed: 6.6 s
# Delta E = -1.8890e-08, Delta S = 1.4806e-03 (per sweep)
# max_trunc_err = 1.8730e-08, max_E_trunc = 1.1683e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 800
# Energy = -1.2732388668344186, S = 0.7312943053419467, norm_err = 1.7e-04
# Current memory usage 178.7 MB, time elapsed: 7.7 s
# Delta E = -4.2032e-09, Delta S = 1.0263e-03 (per sweep)
# max_trunc_err = 2.2553e-08, max_E_trunc = 1.4036e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 920
# Energy = -1.2732389314105035, S = 0.7392545060817544, norm_err = 1.0e-04
# Current memory usage 178.7 MB, time elapsed: 8.3 s
# Delta E = -6.4576e-09, Delta S = 7.9602e-04 (per sweep)
# max_trunc_err = 2.4526e-08, max_E_trunc = 1.5314e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 1040
# Energy = -1.2732389490681726, S = 0.7450214184769577, norm_err = 8.1e-05
# Current memory usage 178.7 MB, time elapsed: 8.8 s
# Delta E = -1.7658e-09, Delta S = 5.7669e-04 (per sweep)
# max_trunc_err = 2.6666e-08, max_E_trunc = 1.6643e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 1160
# Energy = -1.2732389579508947, S = 0.7493266747257276, norm_err = 7.1e-05
# Current memory usage 178.7 MB, time elapsed: 9.4 s
# Delta E = -8.8827e-10, Delta S = 4.3053e-04 (per sweep)
# max_trunc_err = 2.8339e-08, max_E_trunc = 1.7682e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 1280
# Energy = -1.2732389625129770, S = 0.7526951265896773, norm_err = 6.3e-05
# Current memory usage 178.7 MB, time elapsed: 9.9 s
# Delta E = -4.5621e-10, Delta S = 3.3685e-04 (per sweep)
# max_trunc_err = 2.9616e-08, max_E_trunc = 1.8476e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 110, age = 1400
# Energy = -1.2732389646446620, S = 0.7551929576736799, norm_err = 6.1e-05
# Current memory usage 178.7 MB, time elapsed: 10.4 s
# Delta E = -2.1317e-10, Delta S = 2.4978e-04 (per sweep)
# max_trunc_err = 3.0623e-08, max_E_trunc = 1.9100e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 120, age = 1520
# Energy = -1.2732389656673320, S = 0.7571831249445234, norm_err = 5.6e-05
# Current memory usage 178.7 MB, time elapsed: 11.0 s
# Delta E = -1.0227e-10, Delta S = 1.9902e-04 (per sweep)
# max_trunc_err = 3.1384e-08, max_E_trunc = 1.9572e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 130, age = 1640
# Energy = -1.2732389659971091, S = 0.7586119620922158, norm_err = 5.6e-05
# Current memory usage 178.7 MB, time elapsed: 11.5 s
# Delta E = -3.2978e-11, Delta S = 1.4288e-04 (per sweep)
# max_trunc_err = 3.1993e-08, max_E_trunc = 1.9948e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 140, age = 1760
# Energy = -1.2732389661451293, S = 0.7597806244744699, norm_err = 5.1e-05
# Current memory usage 178.7 MB, time elapsed: 12.1 s
# Delta E = -1.4802e-11, Delta S = 1.1687e-04 (per sweep)
# max_trunc_err = 3.2443e-08, max_E_trunc = 2.0228e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 150, age = 1880
# Energy = -1.2732389660988588, S = 0.7605647318604543, norm_err = 5.0e-05
# Current memory usage 178.7 MB, time elapsed: 12.6 s
# Delta E = 4.6271e-12, Delta S = 7.8411e-05 (per sweep)
# max_trunc_err = 3.2814e-08, max_E_trunc = 2.0457e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 160, age = 2000
# Energy = -1.2732389661153434, S = 0.7612427699013611, norm_err = 4.3e-05
# Current memory usage 178.7 MB, time elapsed: 13.1 s
# Delta E = -1.6485e-12, Delta S = 6.7804e-05 (per sweep)
# max_trunc_err = 3.3077e-08, max_E_trunc = 2.0621e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 170, age = 2120
# Energy = -1.2732389660455965, S = 0.7616410695692775, norm_err = 4.1e-05
# Current memory usage 178.7 MB, time elapsed: 13.7 s
# Delta E = 6.9747e-12, Delta S = 3.9830e-05 (per sweep)
# max_trunc_err = 3.3305e-08, max_E_trunc = 2.0763e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 180, age = 2240
# Energy = -1.2732389660729950, S = 0.7620350988603246, norm_err = 3.2e-05
# Current memory usage 178.7 MB, time elapsed: 14.2 s
# Delta E = -2.7399e-12, Delta S = 3.9403e-05 (per sweep)
# max_trunc_err = 3.3456e-08, max_E_trunc = 2.0858e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 190, age = 2360
# Energy = -1.2732389660115473, S = 0.7622114352239265, norm_err = 2.9e-05
# Current memory usage 178.7 MB, time elapsed: 14.7 s
# Delta E = 6.1448e-12, Delta S = 1.7634e-05 (per sweep)
# max_trunc_err = 3.3602e-08, max_E_trunc = 2.0949e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 200, age = 2480
# Energy = -1.2732389660366721, S = 0.7624530775767862, norm_err = 2.0e-05
# Current memory usage 178.7 MB, time elapsed: 15.3 s
# Delta E = -2.5125e-12, Delta S = 2.4164e-05 (per sweep)
# max_trunc_err = 3.3686e-08, max_E_trunc = 2.1003e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 210, age = 2600
# Energy = -1.2732389659634578, S = 0.7625091806443471, norm_err = 1.8e-05
# Current memory usage 178.7 MB, time elapsed: 15.8 s
# Delta E = 7.3214e-12, Delta S = 5.6103e-06 (per sweep)
# max_trunc_err = 3.3785e-08, max_E_trunc = 2.1065e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 220, age = 2720
# Energy = -1.2732389659751107, S = 0.7626773690686126, norm_err = 1.0e-05
# Current memory usage 178.7 MB, time elapsed: 16.3 s
# Delta E = -1.1653e-12, Delta S = 1.6819e-05 (per sweep)
# max_trunc_err = 3.3830e-08, max_E_trunc = 2.1094e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 230, age = 2840
# Energy = -1.2732389658900161, S = 0.7626696668536169, norm_err = 1.0e-05
# Current memory usage 178.7 MB, time elapsed: 16.9 s
# Delta E = 8.5095e-12, Delta S = -7.7022e-07 (per sweep)
# max_trunc_err = 3.3903e-08, max_E_trunc = 2.1139e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 240, age = 2960
# Energy = -1.2732389658974057, S = 0.7628060112587649, norm_err = 3.1e-06
# Current memory usage 178.7 MB, time elapsed: 17.4 s
# Delta E = -7.3896e-13, Delta S = 1.3634e-05 (per sweep)
# max_trunc_err = 3.3921e-08, max_E_trunc = 2.1151e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 250, age = 3080
# Energy = -1.2732389658128227, S = 0.7627614371108491, norm_err = 4.8e-06
# Current memory usage 178.7 MB, time elapsed: 17.9 s
# Delta E = 8.4583e-12, Delta S = -4.4574e-06 (per sweep)
# max_trunc_err = 3.3981e-08, max_E_trunc = 2.1188e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 260, age = 3200
# Energy = -1.2732389658272609, S = 0.7628858556533269, norm_err = 3.6e-06
# Current memory usage 178.7 MB, time elapsed: 18.4 s
# Delta E = -1.4438e-12, Delta S = 1.2442e-05 (per sweep)
# max_trunc_err = 3.3979e-08, max_E_trunc = 2.1187e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 270, age = 3320
# Energy = -1.2732389657439853, S = 0.7628161071746734, norm_err = 2.7e-06
# Current memory usage 178.7 MB, time elapsed: 18.9 s
# Delta E = 8.3276e-12, Delta S = -6.9748e-06 (per sweep)
# max_trunc_err = 3.4031e-08, max_E_trunc = 2.1220e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 280, age = 3440
# Energy = -1.2732389657680869, S = 0.7629384266543060, norm_err = 6.4e-06
# Current memory usage 178.7 MB, time elapsed: 19.5 s
# Delta E = -2.4102e-12, Delta S = 1.2232e-05 (per sweep)
# max_trunc_err = 3.4015e-08, max_E_trunc = 2.1210e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 290, age = 3560
# Energy = -1.2732389656873693, S = 0.7628485781856204, norm_err = 3.2e-06
# Current memory usage 178.7 MB, time elapsed: 20.0 s
# Delta E = 8.0718e-12, Delta S = -8.9848e-06 (per sweep)
# max_trunc_err = 3.4065e-08, max_E_trunc = 2.1240e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 300, age = 3680
# Energy = -1.2732389657202248, S = 0.7629744512860243, norm_err = 8.4e-06
# Current memory usage 178.7 MB, time elapsed: 20.5 s
# Delta E = -3.2855e-12, Delta S = 1.2587e-05 (per sweep)
# max_trunc_err = 3.4037e-08, max_E_trunc = 2.1224e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 310, age = 3800
# Energy = -1.2732389656393934, S = 0.7628667487485268, norm_err = 3.9e-06
# Current memory usage 178.7 MB, time elapsed: 21.0 s
# Delta E = 8.0831e-12, Delta S = -1.0770e-05 (per sweep)
# max_trunc_err = 3.4087e-08, max_E_trunc = 2.1254e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 320, age = 3920
# Energy = -1.2732389656821397, S = 0.7630000367805649, norm_err = 9.8e-06
# Current memory usage 178.7 MB, time elapsed: 21.5 s
# Delta E = -4.2746e-12, Delta S = 1.3329e-05 (per sweep)
# max_trunc_err = 3.4050e-08, max_E_trunc = 2.1231e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 330, age = 4040
# Energy = -1.2732389655957377, S = 0.7628753405798310, norm_err = 4.4e-06
# Current memory usage 178.7 MB, time elapsed: 22.1 s
# Delta E = 8.6402e-12, Delta S = -1.2470e-05 (per sweep)
# max_trunc_err = 3.4102e-08, max_E_trunc = 2.1263e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 340, age = 4160
# Energy = -1.2732389656440546, S = 0.7630190167260901, norm_err = 1.1e-05
# Current memory usage 178.7 MB, time elapsed: 22.6 s
# Delta E = -4.8317e-12, Delta S = 1.4368e-05 (per sweep)
# max_trunc_err = 3.4058e-08, max_E_trunc = 2.1236e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 350, age = 4280
# Energy = -1.2732389655518546, S = 0.7628773667134094, norm_err = 4.7e-06
# Current memory usage 178.7 MB, time elapsed: 23.1 s
# Delta E = 9.2200e-12, Delta S = -1.4165e-05 (per sweep)
# max_trunc_err = 3.4114e-08, max_E_trunc = 2.1270e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 360, age = 4400
# Energy = -1.2732389656055147, S = 0.7630338961500776, norm_err = 1.2e-05
# Current memory usage 178.7 MB, time elapsed: 23.7 s
# Delta E = -5.3660e-12, Delta S = 1.5653e-05 (per sweep)
# max_trunc_err = 3.4062e-08, max_E_trunc = 2.1239e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 370, age = 4520
# Energy = -1.2732389655041061, S = 0.7628747793504425, norm_err = 5.0e-06
# Current memory usage 178.7 MB, time elapsed: 24.2 s
# Delta E = 1.0141e-11, Delta S = -1.5912e-05 (per sweep)
# max_trunc_err = 3.4123e-08, max_E_trunc = 2.1276e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 380, age = 4640
# Energy = -1.2732389655639054, S = 0.7630463063070099, norm_err = 1.3e-05
# Current memory usage 178.7 MB, time elapsed: 24.8 s
# Delta E = -5.9799e-12, Delta S = 1.7153e-05 (per sweep)
# max_trunc_err = 3.4064e-08, max_E_trunc = 2.1240e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 390, age = 4760
# Energy = -1.2732389654509007, S = 0.7628688331517868, norm_err = 5.2e-06
# Current memory usage 178.7 MB, time elapsed: 25.4 s
# Delta E = 1.1300e-11, Delta S = -1.7747e-05 (per sweep)
# max_trunc_err = 3.4131e-08, max_E_trunc = 2.1281e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 400, age = 4880
# Energy = -1.2732389655142242, S = 0.7630572926959780, norm_err = 1.3e-05
# Current memory usage 178.7 MB, time elapsed: 25.9 s
# Delta E = -6.3324e-12, Delta S = 1.8846e-05 (per sweep)
# max_trunc_err = 3.4066e-08, max_E_trunc = 2.1241e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 410, age = 5000
# Energy = -1.2732389653887140, S = 0.7628603180590192, norm_err = 5.5e-06
# Current memory usage 178.7 MB, time elapsed: 26.5 s
# Delta E = 1.2551e-11, Delta S = -1.9697e-05 (per sweep)
# max_trunc_err = 3.4140e-08, max_E_trunc = 2.1286e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 420, age = 5120
# Energy = -1.2732389654536291, S = 0.7630674797267314, norm_err = 1.4e-05
# Current memory usage 178.7 MB, time elapsed: 27.0 s
# Delta E = -6.4915e-12, Delta S = 2.0716e-05 (per sweep)
# max_trunc_err = 3.4066e-08, max_E_trunc = 2.1241e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 430, age = 5240
# Energy = -1.2732389653168639, S = 0.7628497178436571, norm_err = 5.8e-06
# Current memory usage 178.7 MB, time elapsed: 27.5 s
# Delta E = 1.3677e-11, Delta S = -2.1776e-05 (per sweep)
# max_trunc_err = 3.4148e-08, max_E_trunc = 2.1290e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 440, age = 5360
# Energy = -1.2732389653862128, S = 0.7630772049301662, norm_err = 1.5e-05
# Current memory usage 178.7 MB, time elapsed: 28.1 s
# Delta E = -6.9349e-12, Delta S = 2.2749e-05 (per sweep)
# max_trunc_err = 3.4067e-08, max_E_trunc = 2.1242e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 450, age = 5480
# Energy = -1.2732389652348957, S = 0.7628373297007049, norm_err = 6.1e-06
# Current memory usage 178.7 MB, time elapsed: 28.6 s
# Delta E = 1.5132e-11, Delta S = -2.3988e-05 (per sweep)
# max_trunc_err = 3.4157e-08, max_E_trunc = 2.1296e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 460, age = 5600
# Energy = -1.2732389653076552, S = 0.7630865767419082, norm_err = 1.6e-05
# Current memory usage 178.7 MB, time elapsed: 29.2 s
# Delta E = -7.2760e-12, Delta S = 2.4925e-05 (per sweep)
# max_trunc_err = 3.4067e-08, max_E_trunc = 2.1242e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 470, age = 5720
# Energy = -1.2732389651409903, S = 0.7628233353625198, norm_err = 6.5e-06
# Current memory usage 178.7 MB, time elapsed: 29.8 s
# Delta E = 1.6666e-11, Delta S = -2.6324e-05 (per sweep)
# max_trunc_err = 3.4166e-08, max_E_trunc = 2.1301e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 480, age = 5840
# Energy = -1.2732389229288401, S = 0.7628010617125807, norm_err = 7.7e-05
# Current memory usage 178.7 MB, time elapsed: 30.9 s
# Delta E = 4.2212e-09, Delta S = -2.2274e-06 (per sweep)
# max_trunc_err = 3.5036e-08, max_E_trunc = 2.1759e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 490, age = 5960
# Energy = -1.2732389563965398, S = 0.7619535659758334, norm_err = 5.8e-05
# Current memory usage 178.7 MB, time elapsed: 31.9 s
# Delta E = -3.3468e-09, Delta S = -8.4750e-05 (per sweep)
# max_trunc_err = 3.4964e-08, max_E_trunc = 2.1715e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 500, age = 6080
# Energy = -1.2732389026388091, S = 0.7624955501655474, norm_err = 9.6e-05
# Current memory usage 178.7 MB, time elapsed: 33.0 s
# Delta E = 5.3758e-09, Delta S = 5.4198e-05 (per sweep)
# max_trunc_err = 3.5258e-08, max_E_trunc = 2.1892e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 510, age = 6200
# Energy = -1.2732389590062212, S = 0.7624178343108778, norm_err = 4.4e-05
# Current memory usage 178.7 MB, time elapsed: 34.1 s
# Delta E = -5.6367e-09, Delta S = -7.7716e-06 (per sweep)
# max_trunc_err = 3.5035e-08, max_E_trunc = 2.1759e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 520, age = 6320
# Energy = -1.2732388995525525, S = 0.7645774094917632, norm_err = 9.8e-05
# Current memory usage 178.7 MB, time elapsed: 35.1 s
# Delta E = 5.9454e-09, Delta S = 2.1596e-04 (per sweep)
# max_trunc_err = 3.5309e-08, max_E_trunc = 2.1924e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 530, age = 6440
# Energy = -1.2732389611237522, S = 0.7643770159581202, norm_err = 3.5e-05
# Current memory usage 178.7 MB, time elapsed: 36.1 s
# Delta E = -6.1571e-09, Delta S = -2.0039e-05 (per sweep)
# max_trunc_err = 3.5548e-08, max_E_trunc = 2.2071e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 540, age = 6560
# Energy = -1.2732388474948948, S = 0.7646539276354072, norm_err = 1.2e-04
# Current memory usage 178.7 MB, time elapsed: 37.2 s
# Delta E = 1.1363e-08, Delta S = 2.7691e-05 (per sweep)
# max_trunc_err = 3.5198e-08, max_E_trunc = 2.1857e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 550, age = 6680
# Energy = -1.2732389474533647, S = 0.7623721600263371, norm_err = 7.7e-05
# Current memory usage 178.7 MB, time elapsed: 38.3 s
# Delta E = -9.9958e-09, Delta S = -2.2818e-04 (per sweep)
# max_trunc_err = 3.5589e-08, max_E_trunc = 2.2096e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 560, age = 6800
# Energy = -1.2732389549046275, S = 0.7631607281480288, norm_err = 4.4e-05
# Current memory usage 178.7 MB, time elapsed: 39.4 s
# Delta E = -7.4513e-10, Delta S = 7.8857e-05 (per sweep)
# max_trunc_err = 3.5690e-08, max_E_trunc = 2.2160e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 570, age = 6920
# Energy = -1.2732389089060234, S = 0.7640797654137376, norm_err = 8.4e-05
# Current memory usage 178.7 MB, time elapsed: 40.4 s
# Delta E = 4.5999e-09, Delta S = 9.1904e-05 (per sweep)
# max_trunc_err = 3.5571e-08, max_E_trunc = 2.2086e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 580, age = 7040
# Energy = -1.2732389039288137, S = 0.7658107767274354, norm_err = 1.3e-04
# Current memory usage 178.7 MB, time elapsed: 41.6 s
# Delta E = 4.9772e-10, Delta S = 1.7310e-04 (per sweep)
# max_trunc_err = 3.5258e-08, max_E_trunc = 2.1894e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 590, age = 7160
# Energy = -1.2732389647294440, S = 0.7642622088928482, norm_err = 1.7e-05
# Current memory usage 178.7 MB, time elapsed: 42.3 s
# Delta E = -6.0801e-09, Delta S = -1.5486e-04 (per sweep)
# max_trunc_err = 3.4578e-08, max_E_trunc = 2.1540e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 600, age = 7280
# Energy = -1.2732389642412727, S = 0.7642405850823826, norm_err = 5.4e-05
# Current memory usage 178.7 MB, time elapsed: 42.9 s
# Delta E = 4.8817e-11, Delta S = -2.1624e-06 (per sweep)
# max_trunc_err = 3.4276e-08, max_E_trunc = 2.1361e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 610, age = 7400
# Energy = -1.2732389642699218, S = 0.7641130087863039, norm_err = 5.9e-05
# Current memory usage 178.7 MB, time elapsed: 43.5 s
# Delta E = -2.8649e-12, Delta S = -1.2758e-05 (per sweep)
# max_trunc_err = 3.4217e-08, max_E_trunc = 2.1311e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 620, age = 7520
# Energy = -1.2732389645564126, S = 0.7639225801104867, norm_err = 5.6e-05
# Current memory usage 178.7 MB, time elapsed: 44.0 s
# Delta E = -2.8649e-11, Delta S = -1.9043e-05 (per sweep)
# max_trunc_err = 3.4179e-08, max_E_trunc = 2.1286e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 630, age = 7640
# Energy = -1.2732389649090692, S = 0.7637656869654773, norm_err = 4.7e-05
# Current memory usage 178.7 MB, time elapsed: 44.6 s
# Delta E = -3.5266e-11, Delta S = -1.5689e-05 (per sweep)
# max_trunc_err = 3.4130e-08, max_E_trunc = 2.1260e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 640, age = 7760
# Energy = -1.2732389652012444, S = 0.7635869761702239, norm_err = 4.0e-05
# Current memory usage 178.7 MB, time elapsed: 45.1 s
# Delta E = -2.9218e-11, Delta S = -1.7871e-05 (per sweep)
# max_trunc_err = 3.4105e-08, max_E_trunc = 2.1251e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 650, age = 7880
# Energy = -1.2732389654438521, S = 0.7634632102529857, norm_err = 3.0e-05
# Current memory usage 178.7 MB, time elapsed: 45.6 s
# Delta E = -2.4261e-11, Delta S = -1.2377e-05 (per sweep)
# max_trunc_err = 3.4074e-08, max_E_trunc = 2.1239e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 660, age = 8000
# Energy = -1.2732389655898260, S = 0.7633243533698970, norm_err = 2.4e-05
# Current memory usage 178.7 MB, time elapsed: 46.1 s
# Delta E = -1.4597e-11, Delta S = -1.3886e-05 (per sweep)
# max_trunc_err = 3.4068e-08, max_E_trunc = 2.1237e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 670, age = 8120
# Energy = -1.2732389656978285, S = 0.7632481514534435, norm_err = 1.6e-05
# Current memory usage 178.7 MB, time elapsed: 46.6 s
# Delta E = -1.0800e-11, Delta S = -7.6202e-06 (per sweep)
# max_trunc_err = 3.4056e-08, max_E_trunc = 2.1232e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 680, age = 8240
# Energy = -1.2732389657373915, S = 0.7631523901500238, norm_err = 1.1e-05
# Current memory usage 178.7 MB, time elapsed: 47.1 s
# Delta E = -3.9563e-12, Delta S = -9.5761e-06 (per sweep)
# max_trunc_err = 3.4061e-08, max_E_trunc = 2.1237e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 690, age = 8360
# Energy = -1.2732389657735439, S = 0.7631187229989045, norm_err = 5.8e-06
# Current memory usage 178.7 MB, time elapsed: 47.7 s
# Delta E = -3.6152e-12, Delta S = -3.3667e-06 (per sweep)
# max_trunc_err = 3.4057e-08, max_E_trunc = 2.1235e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 700, age = 8480
# Energy = -1.2732389657655858, S = 0.7630544526796627, norm_err = 3.7e-06
# Current memory usage 178.7 MB, time elapsed: 48.2 s
# Delta E = 7.9581e-13, Delta S = -6.4270e-06 (per sweep)
# max_trunc_err = 3.4066e-08, max_E_trunc = 2.1241e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 710, age = 8600
# Energy = -1.2732389657837757, S = 0.7630498643694681, norm_err = 1.2e-06
# Current memory usage 178.7 MB, time elapsed: 48.7 s
# Delta E = -1.8190e-12, Delta S = -4.5883e-07 (per sweep)
# max_trunc_err = 3.4063e-08, max_E_trunc = 2.1240e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 720, age = 8720
# Energy = -1.2732389657621752, S = 0.7630032006484921, norm_err = 1.6e-06
# Current memory usage 178.7 MB, time elapsed: 49.2 s
# Delta E = 2.1600e-12, Delta S = -4.6664e-06 (per sweep)
# max_trunc_err = 3.4073e-08, max_E_trunc = 2.1246e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 730, age = 8840
# Energy = -1.2732389657733165, S = 0.7630162120599765, norm_err = 4.0e-06
# Current memory usage 178.7 MB, time elapsed: 49.7 s
# Delta E = -1.1141e-12, Delta S = 1.3011e-06 (per sweep)
# max_trunc_err = 3.4069e-08, max_E_trunc = 2.1244e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 740, age = 8960
# Energy = -1.2732389657480780, S = 0.7629773266264535, norm_err = 3.6e-06
# Current memory usage 178.7 MB, time elapsed: 50.3 s
# Delta E = 2.5238e-12, Delta S = -3.8885e-06 (per sweep)
# max_trunc_err = 3.4079e-08, max_E_trunc = 2.1249e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 750, age = 9080
# Energy = -1.2732389657605836, S = 0.7630010137514280, norm_err = 5.8e-06
# Current memory usage 178.7 MB, time elapsed: 50.8 s
# Delta E = -1.2506e-12, Delta S = 2.3687e-06 (per sweep)
# max_trunc_err = 3.4073e-08, max_E_trunc = 2.1245e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 760, age = 9200
# Energy = -1.2732389657376189, S = 0.7629641852657663, norm_err = 4.8e-06
# Current memory usage 178.7 MB, time elapsed: 51.3 s
# Delta E = 2.2965e-12, Delta S = -3.6828e-06 (per sweep)
# max_trunc_err = 3.4084e-08, max_E_trunc = 2.1253e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 770, age = 9320
# Energy = -1.2732389657544445, S = 0.7629950308126698, norm_err = 6.8e-06
# Current memory usage 178.7 MB, time elapsed: 51.8 s
# Delta E = -1.6826e-12, Delta S = 3.0846e-06 (per sweep)
# max_trunc_err = 3.4075e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 780, age = 9440
# Energy = -1.2732389657337535, S = 0.7629571166913552, norm_err = 5.4e-06
# Current memory usage 178.7 MB, time elapsed: 52.4 s
# Delta E = 2.0691e-12, Delta S = -3.7914e-06 (per sweep)
# max_trunc_err = 3.4088e-08, max_E_trunc = 2.1255e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 790, age = 9560
# Energy = -1.2732389657512613, S = 0.7629935720255611, norm_err = 7.5e-06
# Current memory usage 178.7 MB, time elapsed: 52.9 s
# Delta E = -1.7508e-12, Delta S = 3.6455e-06 (per sweep)
# max_trunc_err = 3.4077e-08, max_E_trunc = 2.1248e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 800, age = 9680
# Energy = -1.2732389657232943, S = 0.7629527862626442, norm_err = 5.6e-06
# Current memory usage 178.7 MB, time elapsed: 53.4 s
# Delta E = 2.7967e-12, Delta S = -4.0786e-06 (per sweep)
# max_trunc_err = 3.4090e-08, max_E_trunc = 2.1257e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 810, age = 9800
# Energy = -1.2732389657458043, S = 0.7629943397382841, norm_err = 7.9e-06
# Current memory usage 178.7 MB, time elapsed: 54.0 s
# Delta E = -2.2510e-12, Delta S = 4.1553e-06 (per sweep)
# max_trunc_err = 3.4077e-08, max_E_trunc = 2.1248e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 820, age = 9920
# Energy = -1.2732389657210206, S = 0.7629495564347717, norm_err = 5.7e-06
# Current memory usage 178.7 MB, time elapsed: 54.5 s
# Delta E = 2.4784e-12, Delta S = -4.4783e-06 (per sweep)
# max_trunc_err = 3.4093e-08, max_E_trunc = 2.1257e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 830, age = 10040
# Energy = -1.2732389657437579, S = 0.7629962382313559, norm_err = 8.2e-06
# Current memory usage 178.7 MB, time elapsed: 55.1 s
# Delta E = -2.2737e-12, Delta S = 4.6682e-06 (per sweep)
# max_trunc_err = 3.4078e-08, max_E_trunc = 2.1250e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 840, age = 10160
# Energy = -1.2732389657139720, S = 0.7629466382014540, norm_err = 5.8e-06
# Current memory usage 178.7 MB, time elapsed: 55.6 s
# Delta E = 2.9786e-12, Delta S = -4.9600e-06 (per sweep)
# max_trunc_err = 3.4095e-08, max_E_trunc = 2.1259e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 850, age = 10280
# Energy = -1.2732389657394378, S = 0.7629987752777219, norm_err = 8.4e-06
# Current memory usage 178.7 MB, time elapsed: 56.1 s
# Delta E = -2.5466e-12, Delta S = 5.2137e-06 (per sweep)
# max_trunc_err = 3.4078e-08, max_E_trunc = 2.1249e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 860, age = 10400
# Energy = -1.2732389657073782, S = 0.7629436458312754, norm_err = 5.7e-06
# Current memory usage 178.7 MB, time elapsed: 56.7 s
# Delta E = 3.2060e-12, Delta S = -5.5129e-06 (per sweep)
# max_trunc_err = 3.4097e-08, max_E_trunc = 2.1259e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 870, age = 10520
# Energy = -1.2732389657339809, S = 0.7630017347004524, norm_err = 8.6e-06
# Current memory usage 178.7 MB, time elapsed: 57.2 s
# Delta E = -2.6603e-12, Delta S = 5.8089e-06 (per sweep)
# max_trunc_err = 3.4077e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 880, age = 10640
# Energy = -1.2732389656989653, S = 0.7629403819993039, norm_err = 5.6e-06
# Current memory usage 178.7 MB, time elapsed: 57.7 s
# Delta E = 3.5016e-12, Delta S = -6.1353e-06 (per sweep)
# max_trunc_err = 3.4099e-08, max_E_trunc = 2.1261e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 890, age = 10760
# Energy = -1.2732389657294334, S = 0.7630050438203518, norm_err = 8.9e-06
# Current memory usage 178.7 MB, time elapsed: 58.3 s
# Delta E = -3.0468e-12, Delta S = 6.4662e-06 (per sweep)
# max_trunc_err = 3.4077e-08, max_E_trunc = 2.1248e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 900, age = 10880
# Energy = -1.2732389656912346, S = 0.7629367457456664, norm_err = 5.6e-06
# Current memory usage 178.7 MB, time elapsed: 58.8 s
# Delta E = 3.8199e-12, Delta S = -6.8298e-06 (per sweep)
# max_trunc_err = 3.4101e-08, max_E_trunc = 2.1262e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 910, age = 11000
# Energy = -1.2732389657239764, S = 0.7630086912517532, norm_err = 9.1e-06
# Current memory usage 178.7 MB, time elapsed: 59.3 s
# Delta E = -3.2742e-12, Delta S = 7.1946e-06 (per sweep)
# max_trunc_err = 3.4076e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 920, age = 11120
# Energy = -1.2732389656787291, S = 0.7629326692159208, norm_err = 5.5e-06
# Current memory usage 178.7 MB, time elapsed: 59.8 s
# Delta E = 4.5247e-12, Delta S = -7.6022e-06 (per sweep)
# max_trunc_err = 3.4103e-08, max_E_trunc = 2.1264e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 930, age = 11240
# Energy = -1.2732389657153362, S = 0.7630126957152378, norm_err = 9.4e-06
# Current memory usage 178.7 MB, time elapsed: 60.3 s
# Delta E = -3.6607e-12, Delta S = 8.0026e-06 (per sweep)
# max_trunc_err = 3.4075e-08, max_E_trunc = 2.1246e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 940, age = 11360
# Energy = -1.2732389656659961, S = 0.7629280978332021, norm_err = 5.4e-06
# Current memory usage 178.7 MB, time elapsed: 60.9 s
# Delta E = 4.9340e-12, Delta S = -8.4598e-06 (per sweep)
# max_trunc_err = 3.4105e-08, max_E_trunc = 2.1266e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 950, age = 11480
# Energy = -1.2732389657048770, S = 0.7630170850360531, norm_err = 9.7e-06
# Current memory usage 178.7 MB, time elapsed: 61.4 s
# Delta E = -3.8881e-12, Delta S = 8.8987e-06 (per sweep)
# max_trunc_err = 3.4075e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 960, age = 11600
# Energy = -1.2732389656509895, S = 0.7629229766153071, norm_err = 5.3e-06
# Current memory usage 178.7 MB, time elapsed: 61.9 s
# Delta E = 5.3888e-12, Delta S = -9.4108e-06 (per sweep)
# max_trunc_err = 3.4108e-08, max_E_trunc = 2.1267e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 970, age = 11720
# Energy = -1.2732389656898704, S = 0.7630218927812633, norm_err = 1.0e-05
# Current memory usage 178.7 MB, time elapsed: 62.4 s
# Delta E = -3.8881e-12, Delta S = 9.8916e-06 (per sweep)
# max_trunc_err = 3.4074e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 980, age = 11840
# Energy = -1.2732389656325722, S = 0.7629172538108216, norm_err = 5.2e-06
# Current memory usage 178.7 MB, time elapsed: 63.0 s
# Delta E = 5.7298e-12, Delta S = -1.0464e-05 (per sweep)
# max_trunc_err = 3.4111e-08, max_E_trunc = 2.1269e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 990, age = 11960
# Energy = -1.2732389656732721, S = 0.7630271554988620, norm_err = 1.0e-05
# Current memory usage 178.7 MB, time elapsed: 63.5 s
# Delta E = -4.0700e-12, Delta S = 1.0990e-05 (per sweep)
# max_trunc_err = 3.4073e-08, max_E_trunc = 2.1245e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 1000, age = 12080
# Energy = -1.2732389656093801, S = 0.7629108666296570, norm_err = 5.1e-06
# Current memory usage 178.7 MB, time elapsed: 64.0 s
# Delta E = 6.3892e-12, Delta S = -1.1629e-05 (per sweep)
# max_trunc_err = 3.4115e-08, max_E_trunc = 2.1270e-07
# MPS bond dimensions: [16, 16]
# ================================================================================
# DMRG finished after 1000 sweeps.
# total size = 12080, maximum chi = 16
# ================================================================================
# Before the canonicalization:
# Bond dim =  [16, 16]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000076387414+0j)
# After the canonicalization:
# Bond dim =  [16, 16]
# Computing properties
# Optimizing
# Loop for chi=16 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  22
#
# Initial sweeps...
# Updating environment
# ..........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 200
# Energy = -1.2732388766038270, S = nan, norm_err = 5.3e-04
# Current memory usage 178.7 MB, time elapsed: 1.7 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.0955e-08, max_E_trunc = 6.9615e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 320
# Energy = -1.2732391549906126, S = nan, norm_err = 3.3e-04
# Current memory usage 178.7 MB, time elapsed: 3.2 s
# Delta E = -2.7839e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.1029e-08, max_E_trunc = 6.9668e-08
# MPS bond dimensions: [22, 22]
# disable mixer after 30 sweeps, final amplitude 4.21e-08
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 440
# Energy = -1.2732392278783635, S = 0.7681182586310779, norm_err = 2.2e-04
# Current memory usage 178.7 MB, time elapsed: 4.6 s
# Delta E = -7.2888e-09, Delta S = nan (per sweep)
# max_trunc_err = 1.8817e-08, max_E_trunc = 6.3011e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 560
# Energy = -1.2732392776958221, S = 0.7739707069763749, norm_err = 6.9e-05
# Current memory usage 178.7 MB, time elapsed: 5.6 s
# Delta E = -4.9817e-09, Delta S = 5.8524e-04 (per sweep)
# max_trunc_err = 8.9905e-09, max_E_trunc = 6.0562e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 680
# Energy = -1.2732393141058509, S = 0.7799546143098386, norm_err = 1.0e-04
# Current memory usage 178.7 MB, time elapsed: 6.6 s
# Delta E = -3.6410e-09, Delta S = 5.9839e-04 (per sweep)
# max_trunc_err = 8.8745e-09, max_E_trunc = 6.0153e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 800
# Energy = -1.2732393334456447, S = 0.7828228813943057, norm_err = 1.5e-05
# Current memory usage 178.7 MB, time elapsed: 7.1 s
# Delta E = -1.9340e-09, Delta S = 2.8683e-04 (per sweep)
# max_trunc_err = 8.9796e-09, max_E_trunc = 6.1094e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 920
# Energy = -1.2732393146617653, S = 0.7870879011111270, norm_err = 8.2e-05
# Current memory usage 178.7 MB, time elapsed: 8.1 s
# Delta E = 1.8784e-09, Delta S = 4.2650e-04 (per sweep)
# max_trunc_err = 9.4827e-09, max_E_trunc = 6.4277e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 1040
# Energy = -1.2732393332902348, S = 0.7902544098661737, norm_err = 5.8e-05
# Current memory usage 178.7 MB, time elapsed: 9.1 s
# Delta E = -1.8628e-09, Delta S = 3.1665e-04 (per sweep)
# max_trunc_err = 9.8475e-09, max_E_trunc = 6.6692e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 1160
# Energy = -1.2732393266543625, S = 0.7918086394515265, norm_err = 5.5e-05
# Current memory usage 178.7 MB, time elapsed: 10.1 s
# Delta E = 6.6359e-10, Delta S = 1.5542e-04 (per sweep)
# max_trunc_err = 1.0142e-08, max_E_trunc = 6.8639e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 1280
# Energy = -1.2732393270462978, S = 0.7935956255968357, norm_err = 3.8e-05
# Current memory usage 178.7 MB, time elapsed: 11.1 s
# Delta E = -3.9194e-11, Delta S = 1.7870e-04 (per sweep)
# max_trunc_err = 1.0424e-08, max_E_trunc = 7.0501e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 110, age = 1400
# Energy = -1.2732393427356214, S = 0.7957599980135118, norm_err = 7.5e-05
# Current memory usage 178.7 MB, time elapsed: 11.6 s
# Delta E = -1.5689e-09, Delta S = 2.1644e-04 (per sweep)
# max_trunc_err = 1.0320e-08, max_E_trunc = 7.0062e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 120, age = 1520
# Energy = -1.2732393297750377, S = 0.7961106869086035, norm_err = 4.8e-05
# Current memory usage 178.7 MB, time elapsed: 12.6 s
# Delta E = 1.2961e-09, Delta S = 3.5069e-05 (per sweep)
# max_trunc_err = 1.0710e-08, max_E_trunc = 7.2395e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 130, age = 1640
# Energy = -1.2732393435600784, S = 0.7965563872455855, norm_err = 3.2e-05
# Current memory usage 178.7 MB, time elapsed: 13.2 s
# Delta E = -1.3785e-09, Delta S = 4.4570e-05 (per sweep)
# max_trunc_err = 1.0674e-08, max_E_trunc = 7.2388e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 140, age = 1760
# Energy = -1.2732393236101984, S = 0.7979745524683859, norm_err = 4.4e-05
# Current memory usage 178.7 MB, time elapsed: 14.2 s
# Delta E = 1.9950e-09, Delta S = 1.4182e-04 (per sweep)
# max_trunc_err = 1.1024e-08, max_E_trunc = 7.4456e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 150, age = 1880
# Energy = -1.2732393439805492, S = 0.7991218505157356, norm_err = 5.7e-05
# Current memory usage 178.7 MB, time elapsed: 14.8 s
# Delta E = -2.0370e-09, Delta S = 1.1473e-04 (per sweep)
# max_trunc_err = 1.0834e-08, max_E_trunc = 7.3449e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 160, age = 2000
# Energy = -1.2732393235405652, S = 0.7991441855449641, norm_err = 4.4e-05
# Current memory usage 178.7 MB, time elapsed: 15.8 s
# Delta E = 2.0440e-09, Delta S = 2.2335e-06 (per sweep)
# max_trunc_err = 1.1171e-08, max_E_trunc = 7.5427e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 170, age = 2120
# Energy = -1.2732393432862068, S = 0.8003807993726008, norm_err = 7.6e-05
# Current memory usage 178.7 MB, time elapsed: 16.3 s
# Delta E = -1.9746e-09, Delta S = 1.2366e-04 (per sweep)
# max_trunc_err = 1.0961e-08, max_E_trunc = 7.4284e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 180, age = 2240
# Energy = -1.2732393224227394, S = 0.7999064108903919, norm_err = 4.6e-05
# Current memory usage 178.7 MB, time elapsed: 17.4 s
# ...
# Energy = -1.2732395415439441, S = 0.9339077447644251, norm_err = 6.9e-06
# Current memory usage 189.0 MB, time elapsed: 124.3 s
# Delta E = -7.0258e-12, Delta S = 1.3648e-04 (per sweep)
# max_trunc_err = 1.0302e-11, max_E_trunc = 8.1855e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 630, age = 7640
# Energy = -1.2732395416594500, S = 0.9354334422503825, norm_err = 9.8e-06
# Current memory usage 189.0 MB, time elapsed: 126.5 s
# Delta E = -1.1551e-11, Delta S = 1.5257e-04 (per sweep)
# max_trunc_err = 1.0599e-11, max_E_trunc = 7.8217e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 640, age = 7760
# Energy = -1.2732395417378939, S = 0.9371242053241942, norm_err = 2.8e-05
# Current memory usage 189.0 MB, time elapsed: 128.5 s
# Delta E = -7.8444e-12, Delta S = 1.6908e-04 (per sweep)
# max_trunc_err = 1.0868e-11, max_E_trunc = 8.9130e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 650, age = 7880
# Energy = -1.2732395418486249, S = 0.9381155078072486, norm_err = 1.6e-05
# Current memory usage 189.0 MB, time elapsed: 130.6 s
# Delta E = -1.1073e-11, Delta S = 9.9130e-05 (per sweep)
# max_trunc_err = 1.1169e-11, max_E_trunc = 7.6398e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 660, age = 8000
# Energy = -1.2732395412822370, S = 0.9408353021250391, norm_err = 7.7e-05
# Current memory usage 189.0 MB, time elapsed: 132.4 s
# Delta E = 5.6639e-11, Delta S = 2.7198e-04 (per sweep)
# max_trunc_err = 1.1708e-11, max_E_trunc = 7.2760e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 670, age = 8120
# Energy = -1.2732395419457134, S = 0.9414240159429976, norm_err = 5.3e-05
# Current memory usage 189.0 MB, time elapsed: 134.8 s
# Delta E = -6.6348e-11, Delta S = 5.8871e-05 (per sweep)
# max_trunc_err = 1.1855e-11, max_E_trunc = 7.6398e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 680, age = 8240
# Energy = -1.2732395420598550, S = 0.9423076732362758, norm_err = 3.4e-05
# Current memory usage 189.0 MB, time elapsed: 137.1 s
# Delta E = -1.1414e-11, Delta S = 8.8366e-05 (per sweep)
# max_trunc_err = 1.2158e-11, max_E_trunc = 7.2760e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 690, age = 8360
# Energy = -1.2732395421076035, S = 0.9431456714465676, norm_err = 1.1e-05
# Current memory usage 189.0 MB, time elapsed: 139.2 s
# Delta E = -4.7748e-12, Delta S = 8.3800e-05 (per sweep)
# max_trunc_err = 1.2337e-11, max_E_trunc = 9.0949e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 700, age = 8480
# Energy = -1.2732395421774072, S = 0.9446873507078537, norm_err = 1.7e-05
# Current memory usage 189.0 MB, time elapsed: 141.4 s
# Delta E = -6.9804e-12, Delta S = 1.5417e-04 (per sweep)
# max_trunc_err = 1.2644e-11, max_E_trunc = 9.4587e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 710, age = 8600
# Energy = -1.2732395422881382, S = 0.9458090329934601, norm_err = 1.5e-05
# Current memory usage 189.0 MB, time elapsed: 143.2 s
# Delta E = -1.1073e-11, Delta S = 1.1217e-04 (per sweep)
# max_trunc_err = 1.2890e-11, max_E_trunc = 8.1855e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 720, age = 8720
# Energy = -1.2732395423547587, S = 0.9468623016851201, norm_err = 1.6e-05
# Current memory usage 189.0 MB, time elapsed: 144.2 s
# Delta E = -6.6620e-12, Delta S = 1.0533e-04 (per sweep)
# max_trunc_err = 1.2317e-11, max_E_trunc = 9.4587e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 730, age = 8840
# Energy = -1.2732395424100105, S = 0.9481014608020882, norm_err = 1.8e-05
# Current memory usage 189.0 MB, time elapsed: 145.1 s
# Delta E = -5.5252e-12, Delta S = 1.2392e-04 (per sweep)
# max_trunc_err = 1.2414e-11, max_E_trunc = 8.9130e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 740, age = 8960
# Energy = -1.2732395424663991, S = 0.9493363400067552, norm_err = 2.0e-05
# Current memory usage 189.0 MB, time elapsed: 146.0 s
# Delta E = -5.6389e-12, Delta S = 1.2349e-04 (per sweep)
# max_trunc_err = 1.2629e-11, max_E_trunc = 9.0949e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 750, age = 9080
# Energy = -1.2732395425230152, S = 0.9504389111991364, norm_err = 1.4e-05
# Current memory usage 189.0 MB, time elapsed: 146.9 s
# Delta E = -5.6616e-12, Delta S = 1.1026e-04 (per sweep)
# max_trunc_err = 1.2856e-11, max_E_trunc = 9.6406e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 760, age = 9200
# Energy = -1.2732395425707637, S = 0.9514126454490486, norm_err = 1.4e-05
# Current memory usage 189.0 MB, time elapsed: 147.8 s
# Delta E = -4.7748e-12, Delta S = 9.7373e-05 (per sweep)
# max_trunc_err = 1.3116e-11, max_E_trunc = 1.0004e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 770, age = 9320
# Energy = -1.2732395426151015, S = 0.9524445262307377, norm_err = 1.0e-05
# Current memory usage 189.0 MB, time elapsed: 149.2 s
# Delta E = -4.4338e-12, Delta S = 1.0319e-04 (per sweep)
# max_trunc_err = 1.3416e-11, max_E_trunc = 9.6406e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 780, age = 9440
# Energy = -1.2732395421653564, S = 0.9536214231057846, norm_err = 5.0e-05
# Current memory usage 189.0 MB, time elapsed: 151.2 s
# Delta E = 4.4975e-11, Delta S = 1.1769e-04 (per sweep)
# max_trunc_err = 1.3727e-11, max_E_trunc = 9.4587e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 790, age = 9560
# Energy = -1.2732395426844505, S = 0.9546107183618762, norm_err = 1.8e-05
# Current memory usage 189.0 MB, time elapsed: 153.6 s
# Delta E = -5.1909e-11, Delta S = 9.8930e-05 (per sweep)
# max_trunc_err = 1.4194e-11, max_E_trunc = 9.6406e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 800, age = 9680
# Energy = -1.2732395427447045, S = 0.9555582988207784, norm_err = 9.0e-06
# Current memory usage 189.0 MB, time elapsed: 155.4 s
# Delta E = -6.0254e-12, Delta S = 9.4758e-05 (per sweep)
# max_trunc_err = 1.4234e-11, max_E_trunc = 1.0004e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 810, age = 9800
# Energy = -1.2732395427754000, S = 0.9571286149262055, norm_err = 3.1e-05
# Current memory usage 189.0 MB, time elapsed: 157.4 s
# Delta E = -3.0695e-12, Delta S = 1.5703e-04 (per sweep)
# max_trunc_err = 1.4772e-11, max_E_trunc = 1.0914e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 820, age = 9920
# Energy = -1.2732395428160999, S = 0.9578387603674732, norm_err = 2.7e-05
# Current memory usage 189.0 MB, time elapsed: 159.8 s
# Delta E = -4.0700e-12, Delta S = 7.1015e-05 (per sweep)
# max_trunc_err = 1.5000e-11, max_E_trunc = 1.0186e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 830, age = 10040
# Energy = -1.2732395428583914, S = 0.9589771345189935, norm_err = 2.4e-05
# Current memory usage 189.0 MB, time elapsed: 161.5 s
# Delta E = -4.2292e-12, Delta S = 1.1384e-04 (per sweep)
# max_trunc_err = 1.4980e-11, max_E_trunc = 1.1460e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 840, age = 10160
# Energy = -1.2732395428597556, S = 0.9599554397793146, norm_err = 3.8e-05
# Current memory usage 189.0 MB, time elapsed: 163.8 s
# Delta E = -1.3642e-13, Delta S = 9.7831e-05 (per sweep)
# max_trunc_err = 1.5582e-11, max_E_trunc = 1.1096e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 850, age = 10280
# Energy = -1.2732395428774907, S = 0.9601075925735549, norm_err = 8.9e-06
# Current memory usage 189.0 MB, time elapsed: 166.2 s
# Delta E = -1.7735e-12, Delta S = 1.5215e-05 (per sweep)
# max_trunc_err = 1.5707e-11, max_E_trunc = 1.0186e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 860, age = 10400
# Energy = -1.2732395429279677, S = 0.9619142987233249, norm_err = 2.8e-05
# Current memory usage 189.0 MB, time elapsed: 168.5 s
# Delta E = -5.0477e-12, Delta S = 1.8067e-04 (per sweep)
# max_trunc_err = 1.5927e-11, max_E_trunc = 1.0914e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 870, age = 10520
# Energy = -1.2732395429716235, S = 0.9620057049234723, norm_err = 4.9e-06
# Current memory usage 189.0 MB, time elapsed: 170.8 s
# Delta E = -4.3656e-12, Delta S = 9.1406e-06 (per sweep)
# max_trunc_err = 1.6080e-11, max_E_trunc = 1.0732e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 880, age = 10640
# Energy = -1.2732395429536609, S = 0.9638580556402148, norm_err = 3.6e-05
# Current memory usage 189.0 MB, time elapsed: 173.0 s
# Delta E = 1.7963e-12, Delta S = 1.8524e-04 (per sweep)
# max_trunc_err = 1.6296e-11, max_E_trunc = 1.1278e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 890, age = 10760
# Energy = -1.2732395430243741, S = 0.9637257847393917, norm_err = 8.7e-06
# Current memory usage 189.0 MB, time elapsed: 175.2 s
# Delta E = -7.0713e-12, Delta S = -1.3227e-05 (per sweep)
# max_trunc_err = 1.6519e-11, max_E_trunc = 1.1823e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 900, age = 10880
# Energy = -1.2732395430321048, S = 0.9657656900094234, norm_err = 4.2e-05
# Current memory usage 189.0 MB, time elapsed: 177.5 s
# Delta E = -7.7307e-13, Delta S = 2.0399e-04 (per sweep)
# max_trunc_err = 1.6802e-11, max_E_trunc = 1.1823e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 910, age = 11000
# Energy = -1.2732395430552970, S = 0.9653373754569157, norm_err = 1.4e-05
# Current memory usage 189.0 MB, time elapsed: 179.8 s
# Delta E = -2.3192e-12, Delta S = -4.2831e-05 (per sweep)
# max_trunc_err = 1.7094e-11, max_E_trunc = 1.1096e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 920, age = 11120
# Energy = -1.2732395430725774, S = 0.9672072666323850, norm_err = 2.4e-05
# Current memory usage 189.0 MB, time elapsed: 182.0 s
# Delta E = -1.7280e-12, Delta S = 1.8699e-04 (per sweep)
# max_trunc_err = 1.7425e-11, max_E_trunc = 9.4587e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 930, age = 11240
# Energy = -1.2732395431312398, S = 0.9671148447205009, norm_err = 1.1e-05
# Current memory usage 189.0 MB, time elapsed: 184.2 s
# Delta E = -5.8662e-12, Delta S = -9.2422e-06 (per sweep)
# max_trunc_err = 1.7597e-11, max_E_trunc = 1.1823e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 940, age = 11360
# Energy = -1.2732395430653014, S = 0.9690909103604530, norm_err = 3.8e-05
# Current memory usage 189.0 MB, time elapsed: 186.4 s
# Delta E = 6.5938e-12, Delta S = 1.9761e-04 (per sweep)
# max_trunc_err = 1.7815e-11, max_E_trunc = 1.2915e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 950, age = 11480
# Energy = -1.2732395431469286, S = 0.9689382760726571, norm_err = 4.6e-06
# Current memory usage 189.0 MB, time elapsed: 188.7 s
# Delta E = -8.1627e-12, Delta S = -1.5263e-05 (per sweep)
# max_trunc_err = 1.8035e-11, max_E_trunc = 1.4370e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 960, age = 11600
# Energy = -1.2732395431112309, S = 0.9707116158114433, norm_err = 4.0e-05
# Current memory usage 189.0 MB, time elapsed: 190.9 s
# Delta E = 3.5698e-12, Delta S = 1.7733e-04 (per sweep)
# max_trunc_err = 1.8211e-11, max_E_trunc = 1.2005e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 970, age = 11720
# Energy = -1.2732395431917212, S = 0.9707453476666683, norm_err = 1.8e-05
# Current memory usage 189.0 MB, time elapsed: 193.2 s
# Delta E = -8.0490e-12, Delta S = 3.3732e-06 (per sweep)
# max_trunc_err = 1.8607e-11, max_E_trunc = 1.3097e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 980, age = 11840
# Energy = -1.2732395423422531, S = 0.9713490223216116, norm_err = 8.6e-05
# Current memory usage 189.0 MB, time elapsed: 194.7 s
# Delta E = 8.4947e-11, Delta S = 6.0367e-05 (per sweep)
# max_trunc_err = 1.8758e-11, max_E_trunc = 1.3279e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 990, age = 11960
# Energy = -1.2732395432190060, S = 0.9726218672308746, norm_err = 3.1e-05
# Current memory usage 189.0 MB, time elapsed: 197.2 s
# Delta E = -8.7675e-11, Delta S = 1.2728e-04 (per sweep)
# max_trunc_err = 1.9386e-11, max_E_trunc = 1.3097e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 1000, age = 12080
# Energy = -1.2732395432917656, S = 0.9728576837553062, norm_err = 5.9e-06
# Current memory usage 189.0 MB, time elapsed: 199.4 s
# Delta E = -7.2760e-12, Delta S = 2.3582e-05 (per sweep)
# max_trunc_err = 1.9197e-11, max_E_trunc = 1.3097e-10
# MPS bond dimensions: [90, 90]
# ================================================================================
# DMRG finished after 1000 sweeps.
# total size = 12080, maximum chi = 90
# ================================================================================
# Before the canonicalization:
# Bond dim =  [90, 90]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (0.9999999350680335+0j)
# After the canonicalization:
# Bond dim =  [90, 90]
# Computing properties
# Optimizing
# Loop for chi=90 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================

# %%
plot_results(data
            )
