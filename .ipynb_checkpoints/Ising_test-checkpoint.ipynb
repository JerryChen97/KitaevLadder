# %%
import numpy as np
import itertools
import warnings
import matplotlib.pyplot as plt

import tenpy

from tenpy.networks.site import Site, SpinHalfFermionSite, SpinHalfSite, GroupedSite, SpinSite
from tenpy.tools.misc import to_iterable, to_iterable_of_len, inverse_permutation
from tenpy.networks.mps import MPS  # only to check boundary conditions

from tenpy.models.lattice import Lattice, _parse_sites
from tenpy.models.model import CouplingMPOModel, NearestNeighborModel
from tenpy.models.tf_ising import TFIChain
from tenpy.tools.params import get_parameter


from tenpy.algorithms import dmrg

# statistics
from scipy.optimize import curve_fit
from scipy import stats

__all__ = ['KitaevLadder', 'Ising1D']

# %%
class KitaevLadder(Lattice):    
    """ A ladder coupling two chains of the Kitaev form
    .. image :: /images/lattices/Ladder.*
    Parameters
    ----------
    L : int
        The length of each chain, we have 2*L sites in total.
    sites : (list of) :class:`~tenpy.networks.site.Site`
        The two local lattice sites making the `unit_cell` of the :class:`Lattice`.
        If only a single :class:`~tenpy.networks.site.Site` is given, it is used for both chains.
    **kwargs :
        Additional keyword arguments given to the :class:`Lattice`.
        `basis`, `pos` and `pairs` are set accordingly.
    """
    dim = 1

    def __init__(self, L, sites, **kwargs):
        sites = _parse_sites(sites, 4)
        basis = np.array([[2., 0.]])
        pos = np.array([[0., 0.], [0., 1.], [1., 0.], [1., 1.]])
        kwargs.setdefault('basis', basis)
        kwargs.setdefault('positions', pos)
        kwargs.setdefault('bc', 'periodic')
        kwargs.setdefault('bc_MPS', 'infinite')
        
        NNz = [(0, 1, np.array([0])), (2, 3, np.array([0]))]
        NNx = [(1, 3, np.array([0])), (2, 0, np.array([1]))]
        NNy = [(0, 2, np.array([0])), (3, 1, np.array([1]))]
        nNNa = [(1, 2, np.array([0])), (3, 0, np.array([1]))]
        nNNb = [(0, 3, np.array([0])), (2, 1, np.array([1]))]
        
        kwargs.setdefault('pairs', {})
        kwargs['pairs'].setdefault('nearest_neighbors_x', NNx)
        kwargs['pairs'].setdefault('nearest_neighbors_y', NNy)
        kwargs['pairs'].setdefault('nearest_neighbors_z', NNz)
        kwargs['pairs'].setdefault('next_nearest_neighbors_a', nNNa)
        kwargs['pairs'].setdefault('next_nearest_neighbors_b', nNNb)
        
        Lattice.__init__(self, [L], sites, **kwargs)
        

class Ising1D(CouplingMPOModel):
    def __init__(self, model_params):
        CouplingMPOModel.__init__(self, model_params)

    def init_sites(self, model_params):
        conserve = get_parameter(model_params, 'conserve', 'parity', self.name)
        fs = SpinHalfSite(conserve=conserve)
        return [fs, fs, fs, fs]

    def init_lattice(self, model_params):
        L = get_parameter(model_params, 'L', 3, self.name)
        gs = self.init_sites(model_params)
        model_params.pop("L")
        lat = KitaevLadder(L, gs)
        return lat

    def init_terms(self, model_params):
        Jz = get_parameter(model_params, 'Jz', 1., self.name, True)
        g = get_parameter(model_params, 'g', 1., self.name, True)
        
        # onsite terms
        for u in range(len(self.lat.unit_cell)):
            self.add_onsite(-g, u, 'Sigmaz')

        # coupling terms
        for u1, u2, dx in self.lat.pairs['nearest_neighbors_z']:
            self.add_coupling(-Jz, u1, 'Sigmax', u2, 'Sigmax', dx)
#         for u1, u2, dx in self.lat.pairs['nearest_neighbors_x']:
#             self.add_coupling(-Jx, u1, 'Sz', u2, 'Sz', dx)
#         for u1, u2, dx in self.lat.pairs['nearest_neighbors_y']:
#             self.add_coupling(-Jy, u1, 'Sy', u2, 'Sy', dx)
        for u1, u2, dx in self.lat.pairs['next_nearest_neighbors_a']:
            self.add_coupling(-Jz, u1, 'Sigmax', u2, 'Sigmax', dx)
    pass

        
def plot_lattice():
    fig, ax = plt.subplots()
    lat = KitaevLadder(5, None, bc='periodic')
    links_name = 'nearest_neighbors_z'
    lat.plot_coupling(ax, lat.pairs[links_name], linewidth=5.)
    lat.plot_coupling(ax, lat.pairs['next_nearest_neighbors_a'], linewidth=5.)
    # print(lat.pairs['nearest_neighbors'])
    print(lat.unit_cell)
    lat.plot_order(ax=ax, linestyle='--')
    lat.plot_sites(ax)
    # lat.plot_basis(ax, color='g', linewidth=3.)
    ax.set_aspect('equal')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.axis('off')
    # plt.title(links_name)
    plt.show()

# %%
plot_lattice()
# Out:
# [None, None, None, None]

# %%
def run(calc_correlation=True):

    model_params = dict(Jz=1., g=1., L=2, verbose=1)
    prod_state = ["up", "up"] * (2 * model_params['L'])
    M = Ising1D(model_params)
    psi = MPS.from_product_state(
        M.lat.mps_sites(), 
        prod_state, 
        bc=M.lat.bc_MPS,
    )

    dmrg_params = {
        'start_env': 10,
#         'mixer': False,  # setting this to True helps to escape local minima
        'mixer': True,
        'mixer_params': {
            'amplitude': 1.e-4,
            'decay': 1.2,
            'disable_after': 100
        },
        'trunc_params': {
            'chi_max': 4,
            'svd_min': 1.e-10,
        },
        'max_E_err': 1.e-10,
        'max_S_err': 1.e-6,
        'max_sweeps': 10000,
        'verbose': 1.,
    }
    
    
#     eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
    
    # we will return this data dictionary in the end, for the further investigation
    data = dict(
        chi_list=[],
        energy_list=[], 
        entropy_list=[], 
        correlation_list=[],
    )
    
#     chi_list = np.arange(4, 129)
    chi_list = [int(2**i) for i in np.arange(4, 7, 0.5)]
    data['chi_list'] = chi_list
    for chi in chi_list:
        
        print("\n")
        print("=" * 80)
        print("="*30 + "START" + "="*30)
        print("=" * 80)
        print("Chi = ", chi, '\n')
        
        eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
        eng.reset_stats()
        eng.trunc_params['chi_max'] = chi
        info = eng.run()
#         print("INFO: \n", info)

        print("Before the canonicalization:")
        print("Bond dim = ", psi.chi)
        
        print("Canonicalizing...")
        psi_before = psi.copy()
        psi.canonical_form()
        ov = psi.overlap(psi_before, charge_sector=0)
        print("The norm is: ",psi.norm)
        print("The overlap is: ", ov)
        print("After the canonicalization:")
        print("Bond dim = ", psi.chi)
        
        print("Computing properties")
        
        energy=info[0]
        data['energy_list'].append(energy)
        
        entropy = np.mean(psi.entanglement_entropy())
        data['entropy_list'].append(entropy)
        
        if calc_correlation:
            correlation = psi.correlation_length()
            data['correlation_list'].append(correlation)
        
        print("Optimizing")
        tenpy.tools.optimization.optimize(3)
        print("Loop for chi=%d done." % chi)
        print("=" * 80)
        print("="*30 + " END " + "="*30)
        print("=" * 80)
        pass
        
    return data

# %%
def plot_results(data):

    chi_list = data['chi_list']
    energy_list = data['energy_list']
    entropy_list = data['entropy_list']
    correlation_list = data['correlation_list']
    
    plt.plot(chi_list, energy_list, '-o')
    plt.xlabel(r"Bond dimension $\chi$")
    plt.ylabel(r"Ground Energy $E$")
    plt.show()
    
    plt.plot(chi_list, entropy_list, '-o')
    plt.xlabel(r"Bond dimension $\chi$")
    plt.ylabel(r"Entanglement Entropy $S$")
    plt.show()
    
    plt.plot(chi_list, correlation_list, '-o')
    plt.xlabel(r"Bond dimension $\chi$")
    plt.ylabel(r"Correlation Length $\xi$")
    plt.show()
    
    plt.plot(np.log(correlation_list), entropy_list, '-o')
    plt.xlabel(r"log Correlation Length $\xi$")
    plt.ylabel(r"Entanglement Entropy $S$")
    plt.show()

# %%
data = run()
# Out:
# parameter 'verbose'=1 for Ising1D
# parameter 'L'=2 for Ising1D
# parameter 'Jz'=1.0 for Ising1D
# parameter 'g'=1.0 for Ising1D
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  16
#
# parameter 'verbose'=1.0 for Sweep
# parameter 'trunc_params'={'chi_max': 4, 'svd_min': 1e-10} for Sweep
# Initial sweeps...
# parameter 'start_env'=10 for Sweep
# Updating environment
# ..........
# parameter 'max_sweeps'=10000 for DMRG
# parameter 'max_E_err'=1e-10 for DMRG
# parameter 'max_S_err'=1e-06 for DMRG
# parameter 'mixer'=True for Sweep
# parameter 'mixer_params'={'amplitude': 0.0001, 'decay': 1.2, 'disable_after': 100} for Sweep
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 408
# Energy = -1.2732366428779294, S = nan, norm_err = 1.4e-03
# Current memory usage 132.1 MB, time elapsed: 7.0 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.7158e-09, max_E_trunc = 1.4977e-08
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 648
# Energy = -1.2732386306973993, S = nan, norm_err = 7.8e-04
# Current memory usage 132.3 MB, time elapsed: 11.1 s
# Delta E = -1.9878e-07, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.5299e-08, max_E_trunc = 7.8830e-08
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 888
# Energy = -1.2732388894555555, S = nan, norm_err = 4.5e-04
# Current memory usage 132.3 MB, time elapsed: 14.4 s
# Delta E = -2.5876e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.0805e-08, max_E_trunc = 1.2737e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1128
# Energy = -1.2732389475546313, S = nan, norm_err = 2.7e-04
# Current memory usage 132.3 MB, time elapsed: 17.6 s
# Delta E = -5.8099e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 5.1363e-08, max_E_trunc = 1.6023e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 1368
# Energy = -1.2732389622078699, S = nan, norm_err = 1.2e-04
# Current memory usage 132.3 MB, time elapsed: 20.6 s
# Delta E = -1.4653e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 5.7946e-08, max_E_trunc = 1.8071e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 1608
# Energy = -1.2732389660868506, S = nan, norm_err = 8.1e-05
# Current memory usage 132.3 MB, time elapsed: 23.7 s
# Delta E = -3.8790e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 6.1913e-08, max_E_trunc = 1.9296e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 1848
# Energy = -1.2732389668808821, S = nan, norm_err = 5.1e-05
# Current memory usage 132.3 MB, time elapsed: 26.9 s
# Delta E = -7.9403e-11, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 6.4326e-08, max_E_trunc = 2.0042e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 2088
# Energy = -1.2732389668129827, S = 0.7602808400712149, norm_err = 2.9e-05
# Current memory usage 132.3 MB, time elapsed: 29.0 s
# Delta E = 6.7899e-12, Delta S = nan (per sweep)
# max_trunc_err = 3.2906e-08, max_E_trunc = 2.0499e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 2328
# Energy = -1.2732389665743824, S = 0.7613141825491836, norm_err = 1.6e-05
# Current memory usage 132.3 MB, time elapsed: 31.0 s
# Delta E = 2.3860e-11, Delta S = 1.0333e-04 (per sweep)
# max_trunc_err = 3.3362e-08, max_E_trunc = 2.0780e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 2568
# Energy = -1.2732389663594290, S = 0.7619452176816535, norm_err = 8.3e-06
# Current memory usage 132.3 MB, time elapsed: 32.9 s
# Delta E = 2.1495e-11, Delta S = 6.3104e-05 (per sweep)
# max_trunc_err = 3.3641e-08, max_E_trunc = 2.0952e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 110, age = 2808
# Energy = -1.2732389662009780, S = 0.7623328906215603, norm_err = 3.8e-06
# Current memory usage 132.3 MB, time elapsed: 35.1 s
# Delta E = 1.5845e-11, Delta S = 3.8767e-05 (per sweep)
# max_trunc_err = 3.3812e-08, max_E_trunc = 2.1056e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 120, age = 3048
# Energy = -1.2732389660963008, S = 0.7625717988614372, norm_err = 1.4e-06
# Current memory usage 132.4 MB, time elapsed: 37.1 s
# Delta E = 1.0468e-11, Delta S = 2.3891e-05 (per sweep)
# max_trunc_err = 3.3917e-08, max_E_trunc = 2.1121e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 130, age = 3288
# Energy = -1.2732389660270655, S = 0.7627191615269712, norm_err = 1.3e-06
# Current memory usage 132.4 MB, time elapsed: 39.0 s
# Delta E = 6.9235e-12, Delta S = 1.4736e-05 (per sweep)
# max_trunc_err = 3.3981e-08, max_E_trunc = 2.1161e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 140, age = 3528
# Energy = -1.2732389659855130, S = 0.7628100354325593, norm_err = 2.0e-06
# Current memory usage 132.4 MB, time elapsed: 41.0 s
# Delta E = 4.1553e-12, Delta S = 9.0874e-06 (per sweep)
# max_trunc_err = 3.4021e-08, max_E_trunc = 2.1185e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 150, age = 3768
# Energy = -1.2732389659579439, S = 0.7628660379649986, norm_err = 2.6e-06
# Current memory usage 132.7 MB, time elapsed: 43.3 s
# Delta E = 2.7569e-12, Delta S = 5.6003e-06 (per sweep)
# max_trunc_err = 3.4045e-08, max_E_trunc = 2.1200e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 160, age = 4008
# Energy = -1.2732389659404930, S = 0.7629005299675953, norm_err = 2.9e-06
# Current memory usage 132.7 MB, time elapsed: 45.3 s
# Delta E = 1.7451e-12, Delta S = 3.4492e-06 (per sweep)
# max_trunc_err = 3.4060e-08, max_E_trunc = 2.1209e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 170, age = 4248
# Energy = -1.2732389659311139, S = 0.7629217629615268, norm_err = 3.2e-06
# Current memory usage 132.9 MB, time elapsed: 47.5 s
# Delta E = 9.3792e-13, Delta S = 2.1233e-06 (per sweep)
# max_trunc_err = 3.4070e-08, max_E_trunc = 2.1215e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 180, age = 4488
# Energy = -1.2732389659237242, S = 0.7629348311416297, norm_err = 3.3e-06
# Current memory usage 132.9 MB, time elapsed: 49.7 s
# Delta E = 7.3896e-13, Delta S = 1.3068e-06 (per sweep)
# max_trunc_err = 3.4075e-08, max_E_trunc = 2.1219e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 190, age = 4728
# Energy = -1.2732389659192904, S = 0.7629428729636163, norm_err = 3.4e-06
# Current memory usage 132.9 MB, time elapsed: 51.7 s
# Delta E = 4.4338e-13, Delta S = 8.0418e-07 (per sweep)
# max_trunc_err = 3.4079e-08, max_E_trunc = 2.1221e-07
# MPS bond dimensions: [16, 16, 16, 16, 16, 16, 16, 16]
# ================================================================================
# DMRG finished after 190 sweeps.
# total size = 4728, maximum chi = 16
# ================================================================================
# Before the canonicalization:
# Bond dim =  [16, 16, 16, 16, 16, 16, 16, 16]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000005392529+0j)
# After the canonicalization:
# Bond dim =  [16, 16, 16, 16, 16, 16, 16, 16]
# Computing properties
# Optimizing
# Loop for chi=16 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  22
#
# Initial sweeps...
# Updating environment
# ..........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 408
# Energy = -1.2732392893786155, S = nan, norm_err = 2.8e-04
# Current memory usage 133.8 MB, time elapsed: 3.7 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.1194e-08, max_E_trunc = 3.8218e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 648
# Energy = -1.2732393229660062, S = nan, norm_err = 3.2e-04
# Current memory usage 133.8 MB, time elapsed: 7.0 s
# Delta E = -3.3587e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.4781e-08, max_E_trunc = 5.0520e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 888
# Energy = -1.2732393356377827, S = nan, norm_err = 1.8e-04
# Current memory usage 133.8 MB, time elapsed: 10.2 s
# Delta E = -1.2672e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.7059e-08, max_E_trunc = 5.8144e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1128
# Energy = -1.2732393409800125, S = nan, norm_err = 9.6e-05
# Current memory usage 133.8 MB, time elapsed: 13.3 s
# Delta E = -5.3422e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.8757e-08, max_E_trunc = 6.3698e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 1368
# Energy = -1.2732393432083313, S = nan, norm_err = 2.4e-05
# Current memory usage 133.8 MB, time elapsed: 16.4 s
# Delta E = -2.2283e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.9973e-08, max_E_trunc = 6.7662e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 1608
# Energy = -1.2732393438667486, S = nan, norm_err = 5.0e-05
# Current memory usage 133.8 MB, time elapsed: 19.6 s
# Delta E = -6.5842e-11, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.0850e-08, max_E_trunc = 7.0491e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 1848
# Energy = -1.2732393432189610, S = 0.7957804523303460, norm_err = 1.5e-04
# Current memory usage 133.8 MB, time elapsed: 21.5 s
# Delta E = 6.4779e-11, Delta S = nan (per sweep)
# max_trunc_err = 1.0752e-08, max_E_trunc = 7.2632e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 2088
# Energy = -1.2732393451663881, S = 0.7989841841488032, norm_err = 4.0e-05
# Current memory usage 133.8 MB, time elapsed: 23.6 s
# Delta E = -1.9474e-10, Delta S = 3.2037e-04 (per sweep)
# max_trunc_err = 1.0937e-08, max_E_trunc = 7.3866e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 2328
# Energy = -1.2732393452055248, S = 0.8001474472730540, norm_err = 4.9e-05
# Current memory usage 133.8 MB, time elapsed: 25.5 s
# Delta E = -3.9137e-12, Delta S = 1.1633e-04 (per sweep)
# max_trunc_err = 1.1065e-08, max_E_trunc = 7.4750e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 2568
# Energy = -1.2732393451424571, S = 0.8009136990448621, norm_err = 7.7e-05
# Current memory usage 133.8 MB, time elapsed: 27.4 s
# Delta E = 6.3068e-12, Delta S = 7.6625e-05 (per sweep)
# max_trunc_err = 1.1165e-08, max_E_trunc = 7.5368e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 110, age = 2808
# Energy = -1.2732393448872870, S = 0.8017913579419047, norm_err = 9.9e-05
# Current memory usage 133.8 MB, time elapsed: 29.4 s
# Delta E = 2.5517e-11, Delta S = 8.7766e-05 (per sweep)
# max_trunc_err = 1.1232e-08, max_E_trunc = 7.5878e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 120, age = 3048
# Energy = -1.2732393447490438, S = 0.8021390016449186, norm_err = 1.2e-04
# Current memory usage 133.8 MB, time elapsed: 31.5 s
# Delta E = 1.3824e-11, Delta S = 3.4764e-05 (per sweep)
# max_trunc_err = 1.1271e-08, max_E_trunc = 7.6093e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 130, age = 3288
# Energy = -1.2732393449069832, S = 0.8003413173968467, norm_err = 7.1e-05
# Current memory usage 133.8 MB, time elapsed: 33.5 s
# Delta E = -1.5794e-11, Delta S = -1.7977e-04 (per sweep)
# max_trunc_err = 1.1330e-08, max_E_trunc = 7.6433e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 140, age = 3528
# Energy = -1.2732393447941490, S = 0.8027073177506778, norm_err = 8.8e-05
# Current memory usage 133.8 MB, time elapsed: 35.5 s
# Delta E = 1.1283e-11, Delta S = 2.3660e-04 (per sweep)
# max_trunc_err = 1.1364e-08, max_E_trunc = 7.6740e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 150, age = 3768
# Energy = -1.2732393448952166, S = 0.8007713033443542, norm_err = 8.2e-05
# Current memory usage 133.8 MB, time elapsed: 37.6 s
# Delta E = -1.0107e-11, Delta S = -1.9360e-04 (per sweep)
# max_trunc_err = 1.1383e-08, max_E_trunc = 7.6769e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 160, age = 4008
# Energy = -1.2732393448483776, S = 0.8027436883720159, norm_err = 8.6e-05
# Current memory usage 133.8 MB, time elapsed: 39.6 s
# Delta E = 4.6839e-12, Delta S = 1.9724e-04 (per sweep)
# max_trunc_err = 1.1400e-08, max_E_trunc = 7.6937e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 170, age = 4248
# Energy = -1.2732393448459902, S = 0.8008574130272799, norm_err = 9.1e-05
# Current memory usage 133.8 MB, time elapsed: 41.7 s
# Delta E = 2.3874e-13, Delta S = -1.8863e-04 (per sweep)
# max_trunc_err = 1.1397e-08, max_E_trunc = 7.6882e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 180, age = 4488
# Energy = -1.2732393447961385, S = 0.8028887541652121, norm_err = 8.7e-05
# Current memory usage 133.8 MB, time elapsed: 43.7 s
# Delta E = 4.9852e-12, Delta S = 2.0313e-04 (per sweep)
# max_trunc_err = 1.1417e-08, max_E_trunc = 7.7056e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 190, age = 4728
# Energy = -1.2732393447774371, S = 0.8008641382021168, norm_err = 9.7e-05
# Current memory usage 134.1 MB, time elapsed: 45.7 s
# Delta E = 1.8701e-12, Delta S = -2.0246e-04 (per sweep)
# max_trunc_err = 1.1407e-08, max_E_trunc = 7.6941e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 200, age = 4968
# Energy = -1.2732393447513459, S = 0.8029716809369452, norm_err = 8.9e-05
# Current memory usage 134.1 MB, time elapsed: 47.8 s
# Delta E = 2.6091e-12, Delta S = 2.1075e-04 (per sweep)
# max_trunc_err = 1.1425e-08, max_E_trunc = 7.7122e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 210, age = 5208
# Energy = -1.2732393447843151, S = 0.8009231805657813, norm_err = 9.6e-05
# Current memory usage 134.3 MB, time elapsed: 49.8 s
# Delta E = -3.2969e-12, Delta S = -2.0485e-04 (per sweep)
# max_trunc_err = 1.1413e-08, max_E_trunc = 7.6974e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 220, age = 5448
# Energy = -1.2732393448155790, S = 0.8029126342648512, norm_err = 8.3e-05
# Current memory usage 134.3 MB, time elapsed: 51.8 s
# Delta E = -3.1264e-12, Delta S = 1.9895e-04 (per sweep)
# max_trunc_err = 1.1426e-08, max_E_trunc = 7.7127e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 230, age = 5688
# Energy = -1.2732393449112465, S = 0.8010905208070036, norm_err = 8.4e-05
# Current memory usage 134.3 MB, time elapsed: 53.9 s
# Delta E = -9.5667e-12, Delta S = -1.8221e-04 (per sweep)
# max_trunc_err = 1.1416e-08, max_E_trunc = 7.7003e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 240, age = 5928
# Energy = -1.2732393449883261, S = 0.8026977538951132, norm_err = 6.8e-05
# Current memory usage 134.3 MB, time elapsed: 55.9 s
# Delta E = -7.7080e-12, Delta S = 1.6072e-04 (per sweep)
# max_trunc_err = 1.1421e-08, max_E_trunc = 7.7077e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 250, age = 6168
# Energy = -1.2732393452113229, S = 0.8015249414214992, norm_err = 3.9e-05
# Current memory usage 134.5 MB, time elapsed: 57.9 s
# Delta E = -2.2300e-11, Delta S = -1.1728e-04 (per sweep)
# max_trunc_err = 1.1422e-08, max_E_trunc = 7.7038e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 260, age = 6408
# Energy = -1.2732393451224198, S = 0.8013489917363471, norm_err = 6.3e-05
# Current memory usage 134.5 MB, time elapsed: 59.8 s
# Delta E = 8.8903e-12, Delta S = -1.7595e-05 (per sweep)
# max_trunc_err = 1.1436e-08, max_E_trunc = 7.7137e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 270, age = 6648
# Energy = -1.2732393449150550, S = 0.8011054236013030, norm_err = 9.6e-05
# Current memory usage 134.5 MB, time elapsed: 61.7 s
# Delta E = 2.0736e-11, Delta S = -2.4357e-05 (per sweep)
# max_trunc_err = 1.1447e-08, max_E_trunc = 7.7198e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 280, age = 6888
# Energy = -1.2732393451375401, S = 0.8023760004576057, norm_err = 5.9e-05
# Current memory usage 134.8 MB, time elapsed: 63.7 s
# Delta E = -2.2249e-11, Delta S = 1.2706e-04 (per sweep)
# max_trunc_err = 1.1403e-08, max_E_trunc = 7.6931e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 290, age = 7128
# Energy = -1.2732393449402934, S = 0.8026748055466275, norm_err = 9.1e-05
# Current memory usage 134.8 MB, time elapsed: 65.7 s
# Delta E = 1.9725e-11, Delta S = 2.9881e-05 (per sweep)
# max_trunc_err = 1.1399e-08, max_E_trunc = 7.6907e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 300, age = 7368
# Energy = -1.2732393452166662, S = 0.8014911657693750, norm_err = 1.4e-05
# Current memory usage 135.1 MB, time elapsed: 67.7 s
# Delta E = -2.7637e-11, Delta S = -1.1836e-04 (per sweep)
# max_trunc_err = 1.1399e-08, max_E_trunc = 7.6874e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 310, age = 7608
# Energy = -1.2732393450750124, S = 0.8012066986730234, norm_err = 6.2e-05
# Current memory usage 135.2 MB, time elapsed: 69.6 s
# Delta E = 1.4165e-11, Delta S = -2.8447e-05 (per sweep)
# max_trunc_err = 1.1433e-08, max_E_trunc = 7.7116e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 320, age = 7848
# Energy = -1.2732393448882249, S = 0.8028047579855430, norm_err = 8.2e-05
# Current memory usage 135.2 MB, time elapsed: 71.6 s
# Delta E = 1.8679e-11, Delta S = 1.5981e-04 (per sweep)
# max_trunc_err = 1.1415e-08, max_E_trunc = 7.7054e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 330, age = 8088
# Energy = -1.2732393451876760, S = 0.8014252661054990, norm_err = 4.4e-05
# Current memory usage 135.4 MB, time elapsed: 73.6 s
# Delta E = -2.9945e-11, Delta S = -1.3795e-04 (per sweep)
# max_trunc_err = 1.1418e-08, max_E_trunc = 7.7018e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 340, age = 8328
# Energy = -1.2732393450341988, S = 0.8012186050958653, norm_err = 7.8e-05
# Current memory usage 135.5 MB, time elapsed: 75.5 s
# Delta E = 1.5348e-11, Delta S = -2.0666e-05 (per sweep)
# max_trunc_err = 1.1437e-08, max_E_trunc = 7.7145e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 350, age = 8568
# Energy = -1.2732393446768810, S = 0.8031128632005580, norm_err = 9.7e-05
# Current memory usage 135.5 MB, time elapsed: 77.5 s
# Delta E = 3.5732e-11, Delta S = 1.8943e-04 (per sweep)
# max_trunc_err = 1.1448e-08, max_E_trunc = 7.7256e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 360, age = 8808
# Energy = -1.2732393452375845, S = 0.8018125099034432, norm_err = 7.6e-06
# Current memory usage 135.7 MB, time elapsed: 79.6 s
# Delta E = -5.6070e-11, Delta S = -1.3004e-04 (per sweep)
# max_trunc_err = 1.1408e-08, max_E_trunc = 7.6931e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 370, age = 9048
# Energy = -1.2732393452737369, S = 0.8017213567843644, norm_err = 7.5e-06
# Current memory usage 135.7 MB, time elapsed: 81.5 s
# Delta E = -3.6152e-12, Delta S = -9.1153e-06 (per sweep)
# max_trunc_err = 1.1416e-08, max_E_trunc = 7.7009e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 380, age = 9288
# Energy = -1.2732393452427004, S = 0.8017860353016782, norm_err = 2.5e-05
# Current memory usage 136.0 MB, time elapsed: 83.4 s
# Delta E = 3.1037e-12, Delta S = 6.4679e-06 (per sweep)
# max_trunc_err = 1.1414e-08, max_E_trunc = 7.6996e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 390, age = 9528
# Energy = -1.2732393452465658, S = 0.8016500187027131, norm_err = 2.0e-05
# Current memory usage 136.1 MB, time elapsed: 85.3 s
# Delta E = -3.8654e-13, Delta S = -1.3602e-05 (per sweep)
# max_trunc_err = 1.1427e-08, max_E_trunc = 7.7083e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 400, age = 9768
# Energy = -1.2732393451955204, S = 0.8017012828017079, norm_err = 4.0e-05
# Current memory usage 136.1 MB, time elapsed: 87.2 s
# Delta E = 5.1045e-12, Delta S = 5.1264e-06 (per sweep)
# max_trunc_err = 1.1419e-08, max_E_trunc = 7.7036e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 410, age = 10008
# Energy = -1.2732393451810822, S = 0.8014779381984491, norm_err = 3.8e-05
# Current memory usage 136.5 MB, time elapsed: 89.0 s
# Delta E = 1.4438e-12, Delta S = -2.2334e-05 (per sweep)
# max_trunc_err = 1.1437e-08, max_E_trunc = 7.7142e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 420, age = 10248
# Energy = -1.2732393450589825, S = 0.8014667159999788, norm_err = 7.0e-05
# Current memory usage 136.5 MB, time elapsed: 90.9 s
# Delta E = 1.2210e-11, Delta S = -1.1222e-06 (per sweep)
# max_trunc_err = 1.1427e-08, max_E_trunc = 7.7074e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 430, age = 10488
# Energy = -1.2732393452697579, S = 0.8019588054332472, norm_err = 2.2e-05
# Current memory usage 136.5 MB, time elapsed: 92.9 s
# Delta E = -2.1078e-11, Delta S = 4.9209e-05 (per sweep)
# max_trunc_err = 1.1405e-08, max_E_trunc = 7.6938e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 440, age = 10728
# Energy = -1.2732393452760107, S = 0.8020192270384092, norm_err = 1.8e-05
# Current memory usage 136.8 MB, time elapsed: 94.7 s
# Delta E = -6.2528e-13, Delta S = 6.0422e-06 (per sweep)
# max_trunc_err = 1.1409e-08, max_E_trunc = 7.6954e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 450, age = 10968
# Energy = -1.2732393452560018, S = 0.8021414107083003, norm_err = 2.4e-05
# Current memory usage 136.8 MB, time elapsed: 96.6 s
# Delta E = 2.0009e-12, Delta S = 1.2218e-05 (per sweep)
# max_trunc_err = 1.1409e-08, max_E_trunc = 7.6965e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 460, age = 11208
# Energy = -1.2732393452100723, S = 0.8022743013665140, norm_err = 4.2e-05
# Current memory usage 137.1 MB, time elapsed: 98.5 s
# Delta E = 4.5929e-12, Delta S = 1.3289e-05 (per sweep)
# max_trunc_err = 1.1408e-08, max_E_trunc = 7.6956e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 470, age = 11448
# Energy = -1.2732393450792188, S = 0.8025300192874606, norm_err = 6.6e-05
# Current memory usage 137.3 MB, time elapsed: 100.4 s
# Delta E = 1.3085e-11, Delta S = 2.5572e-05 (per sweep)
# max_trunc_err = 1.1404e-08, max_E_trunc = 7.6952e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 480, age = 11688
# Energy = -1.2732393447665800, S = 0.8028643079346506, norm_err = 1.1e-04
# Current memory usage 137.3 MB, time elapsed: 102.3 s
# Delta E = 3.1264e-11, Delta S = 3.3429e-05 (per sweep)
# max_trunc_err = 1.1400e-08, max_E_trunc = 7.6929e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 490, age = 11928
# Energy = -1.2732393448828816, S = 0.8008739239922300, norm_err = 7.9e-05
# Current memory usage 137.6 MB, time elapsed: 104.3 s
# Delta E = -1.1630e-11, Delta S = -1.9904e-04 (per sweep)
# max_trunc_err = 1.1421e-08, max_E_trunc = 7.7038e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 500, age = 12168
# Energy = -1.2732393447702179, S = 0.8030907929077995, norm_err = 8.5e-05
# Current memory usage 137.6 MB, time elapsed: 106.3 s
# Delta E = 1.1266e-11, Delta S = 2.2169e-04 (per sweep)
# max_trunc_err = 1.1426e-08, max_E_trunc = 7.7138e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 510, age = 12408
# Energy = -1.2732393448757193, S = 0.8010226928557491, norm_err = 8.5e-05
# Current memory usage 137.6 MB, time elapsed: 108.3 s
# Delta E = -1.0550e-11, Delta S = -2.0681e-04 (per sweep)
# max_trunc_err = 1.1426e-08, max_E_trunc = 7.7063e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 520, age = 12648
# Energy = -1.2732393448313815, S = 0.8029391722867030, norm_err = 8.4e-05
# Current memory usage 137.8 MB, time elapsed: 110.3 s
# Delta E = 4.4338e-12, Delta S = 1.9165e-04 (per sweep)
# max_trunc_err = 1.1430e-08, max_E_trunc = 7.7134e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 530, age = 12888
# Energy = -1.2732393448295625, S = 0.8009757110025434, norm_err = 9.4e-05
# Current memory usage 138.1 MB, time elapsed: 112.4 s
# Delta E = 1.8190e-13, Delta S = -1.9635e-04 (per sweep)
# max_trunc_err = 1.1419e-08, max_E_trunc = 7.7038e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 540, age = 13128
# Energy = -1.2732393447865888, S = 0.8029871682212822, norm_err = 8.7e-05
# Current memory usage 138.2 MB, time elapsed: 114.4 s
# Delta E = 4.2974e-12, Delta S = 2.0115e-04 (per sweep)
# max_trunc_err = 1.1432e-08, max_E_trunc = 7.7154e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 550, age = 13368
# Energy = -1.2732393447652157, S = 0.8009224432383545, norm_err = 9.8e-05
# Current memory usage 138.2 MB, time elapsed: 116.4 s
# Delta E = 2.1373e-12, Delta S = -2.0647e-04 (per sweep)
# max_trunc_err = 1.1418e-08, max_E_trunc = 7.7023e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 560, age = 13608
# Energy = -1.2732393447520280, S = 0.8030150405001979, norm_err = 8.8e-05
# Current memory usage 138.2 MB, time elapsed: 118.3 s
# Delta E = 1.3188e-12, Delta S = 2.0926e-04 (per sweep)
# max_trunc_err = 1.1432e-08, max_E_trunc = 7.7169e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 570, age = 13848
# Energy = -1.2732393447895447, S = 0.8009657396982743, norm_err = 9.5e-05
# Current memory usage 138.5 MB, time elapsed: 120.4 s
# Delta E = -3.7517e-12, Delta S = -2.0493e-04 (per sweep)
# max_trunc_err = 1.1418e-08, max_E_trunc = 7.7009e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 580, age = 14088
# Energy = -1.2732393448329731, S = 0.8029118231782919, norm_err = 8.1e-05
# Current memory usage 138.7 MB, time elapsed: 122.4 s
# Delta E = -4.3428e-12, Delta S = 1.9461e-04 (per sweep)
# max_trunc_err = 1.1428e-08, max_E_trunc = 7.7129e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 590, age = 14328
# Energy = -1.2732393449307438, S = 0.8011301196308384, norm_err = 8.2e-05
# Current memory usage 138.8 MB, time elapsed: 124.4 s
# Delta E = -9.7771e-12, Delta S = -1.7817e-04 (per sweep)
# max_trunc_err = 1.1419e-08, max_E_trunc = 7.7023e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 600, age = 14568
# Energy = -1.2732393451883581, S = 0.8023276109831319, norm_err = 4.1e-05
# Current memory usage 138.8 MB, time elapsed: 126.3 s
# Delta E = -2.5761e-11, Delta S = 1.1975e-04 (per sweep)
# max_trunc_err = 1.1406e-08, max_E_trunc = 7.6943e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 610, age = 14808
# Energy = -1.2732393450357904, S = 0.8025850339234729, norm_err = 7.4e-05
# Current memory usage 138.8 MB, time elapsed: 128.3 s
# Delta E = 1.5257e-11, Delta S = 2.5742e-05 (per sweep)
# max_trunc_err = 1.1401e-08, max_E_trunc = 7.6947e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 620, age = 15048
# Energy = -1.2732393446467540, S = 0.8029886225556681, norm_err = 1.2e-04
# Current memory usage 139.1 MB, time elapsed: 130.2 s
# Delta E = 3.8904e-11, Delta S = 4.0359e-05 (per sweep)
# max_trunc_err = 1.1398e-08, max_E_trunc = 7.6925e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 630, age = 15288
# Energy = -1.2732393447879531, S = 0.8007678964201099, norm_err = 8.8e-05
# Current memory usage 139.1 MB, time elapsed: 132.2 s
# Delta E = -1.4120e-11, Delta S = -2.2207e-04 (per sweep)
# max_trunc_err = 1.1421e-08, max_E_trunc = 7.7038e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 640, age = 15528
# Energy = -1.2732393446533479, S = 0.8032164172780972, norm_err = 9.4e-05
# Current memory usage 139.1 MB, time elapsed: 134.2 s
# Delta E = 1.3461e-11, Delta S = 2.4485e-04 (per sweep)
# max_trunc_err = 1.1429e-08, max_E_trunc = 7.7180e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 650, age = 15768
# Energy = -1.2732393446440256, S = 0.8006100219963632, norm_err = 9.6e-05
# Current memory usage 139.1 MB, time elapsed: 136.2 s
# Delta E = 9.3223e-13, Delta S = -2.6064e-04 (per sweep)
# max_trunc_err = 1.1413e-08, max_E_trunc = 7.6980e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 660, age = 16008
# Energy = -1.2732393451653934, S = 0.8019159581260280, norm_err = 1.1e-05
# Current memory usage 139.5 MB, time elapsed: 138.2 s
# Delta E = -5.2137e-11, Delta S = 1.3059e-04 (per sweep)
# max_trunc_err = 1.1470e-08, max_E_trunc = 7.7333e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 670, age = 16248
# Energy = -1.2732393452722590, S = 0.8018512931582112, norm_err = 1.4e-05
# Current memory usage 139.5 MB, time elapsed: 140.3 s
# Delta E = -1.0687e-11, Delta S = -6.4665e-06 (per sweep)
# max_trunc_err = 1.1421e-08, max_E_trunc = 7.7052e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 680, age = 16488
# Energy = -1.2732393452909037, S = 0.8018530363060588, norm_err = 7.8e-06
# Current memory usage 139.5 MB, time elapsed: 142.2 s
# Delta E = -1.8645e-12, Delta S = 1.7431e-07 (per sweep)
# max_trunc_err = 1.1413e-08, max_E_trunc = 7.7001e-08
# MPS bond dimensions: [22, 22, 22, 22, 22, 22, 22, 22]
# ================================================================================
# DMRG finished after 680 sweeps.
# total size = 16488, maximum chi = 22
# ================================================================================
# Before the canonicalization:
# Bond dim =  [22, 22, 22, 22, 22, 22, 22, 22]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.000000002056769+0j)
# After the canonicalization:
# Bond dim =  [22, 22, 22, 22, 22, 22, 22, 22]
# Computing properties
# Optimizing
# Loop for chi=22 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  32
#
# Initial sweeps...
# Updating environment
# ..........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 408
# Energy = -1.2732394236083877, S = nan, norm_err = 9.2e-04
# Current memory usage 139.5 MB, time elapsed: 5.5 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.2727e-09, max_E_trunc = 7.7571e-09
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 648
# Energy = -1.2732394711510153, S = nan, norm_err = 4.8e-04
# Current memory usage 139.5 MB, time elapsed: 10.3 s
# Delta E = -4.7543e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.8259e-09, max_E_trunc = 9.6394e-09
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 888
# Energy = -1.2732394852435220, S = nan, norm_err = 3.0e-04
# Current memory usage 139.5 MB, time elapsed: 14.7 s
# Delta E = -1.4093e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.7913e-09, max_E_trunc = 9.5297e-09
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1128
# Energy = -1.2732394916169198, S = nan, norm_err = 2.3e-04
# Current memory usage 139.5 MB, time elapsed: 19.2 s
# Delta E = -6.3734e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.8737e-09, max_E_trunc = 9.8194e-09
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 1368
# Energy = -1.2732394951804338, S = nan, norm_err = 2.0e-04
# Current memory usage 139.5 MB, time elapsed: 23.6 s
# Delta E = -3.5635e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 3.0195e-09, max_E_trunc = 1.0305e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 1608
# Energy = -1.2732394974253509, S = nan, norm_err = 1.4e-04
# Current memory usage 139.5 MB, time elapsed: 27.9 s
# Delta E = -2.2449e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 3.1965e-09, max_E_trunc = 1.0886e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 1848
# Energy = -1.2732394989079410, S = nan, norm_err = 1.3e-04
# Current memory usage 139.7 MB, time elapsed: 32.3 s
# Delta E = -1.4826e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 3.3737e-09, max_E_trunc = 1.1461e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 2088
# Energy = -1.2732394999072767, S = nan, norm_err = 1.2e-04
# Current memory usage 139.7 MB, time elapsed: 36.7 s
# Delta E = -9.9934e-11, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 3.5294e-09, max_E_trunc = 1.1965e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 2328
# Energy = -1.2732395005810702, S = 0.8523167809153980, norm_err = 8.9e-05
# Current memory usage 139.7 MB, time elapsed: 38.7 s
# Delta E = -6.7379e-11, Delta S = nan (per sweep)
# max_trunc_err = 1.8372e-09, max_E_trunc = 1.2432e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 2568
# Energy = -1.2732395010955884, S = 0.8547997690762925, norm_err = 4.5e-05
# Current memory usage 139.7 MB, time elapsed: 40.7 s
# Delta E = -5.1452e-11, Delta S = 2.4830e-04 (per sweep)
# max_trunc_err = 1.9006e-09, max_E_trunc = 1.2849e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 110, age = 2808
# Energy = -1.2732395014401732, S = 0.8576189349294726, norm_err = 7.2e-05
# Current memory usage 139.7 MB, time elapsed: 42.7 s
# Delta E = -3.4458e-11, Delta S = 2.8192e-04 (per sweep)
# max_trunc_err = 1.9606e-09, max_E_trunc = 1.3228e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 120, age = 3048
# Energy = -1.2732395016823261, S = 0.8588837253540802, norm_err = 5.3e-05
# Current memory usage 139.7 MB, time elapsed: 44.6 s
# Delta E = -2.4215e-11, Delta S = 1.2648e-04 (per sweep)
# max_trunc_err = 2.0058e-09, max_E_trunc = 1.3516e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 130, age = 3288
# Energy = -1.2732395018447278, S = 0.8609555131087119, norm_err = 3.3e-05
# Current memory usage 139.7 MB, time elapsed: 46.6 s
# Delta E = -1.6240e-11, Delta S = 2.0718e-04 (per sweep)
# max_trunc_err = 2.0531e-09, max_E_trunc = 1.3817e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 140, age = 3528
# Energy = -1.2732395019601199, S = 0.8622762406328019, norm_err = 5.9e-05
# Current memory usage 139.7 MB, time elapsed: 48.6 s
# Delta E = -1.1539e-11, Delta S = 1.3207e-04 (per sweep)
# max_trunc_err = 2.0854e-09, max_E_trunc = 1.4009e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 150, age = 3768
# Energy = -1.2732395020476019, S = 0.8635497333169244, norm_err = 7.5e-05
# Current memory usage 139.7 MB, time elapsed: 50.6 s
# Delta E = -8.7482e-12, Delta S = 1.2735e-04 (per sweep)
# max_trunc_err = 2.1104e-09, max_E_trunc = 1.4178e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 160, age = 4008
# Energy = -1.2732395021029674, S = 0.8638365412765908, norm_err = 3.7e-06
# Current memory usage 139.7 MB, time elapsed: 52.6 s
# Delta E = -5.5365e-12, Delta S = 2.8681e-05 (per sweep)
# max_trunc_err = 2.1394e-09, max_E_trunc = 1.4363e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 170, age = 4248
# Energy = -1.2732395021524212, S = 0.8657397954765671, norm_err = 3.0e-05
# Current memory usage 139.7 MB, time elapsed: 54.5 s
# Delta E = -4.9454e-12, Delta S = 1.9033e-04 (per sweep)
# max_trunc_err = 2.1736e-09, max_E_trunc = 1.4564e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 180, age = 4488
# Energy = -1.2732395021898242, S = 0.8656266269826992, norm_err = 2.3e-05
# Current memory usage 139.7 MB, time elapsed: 56.5 s
# Delta E = -3.7403e-12, Delta S = -1.1317e-05 (per sweep)
# max_trunc_err = 2.1849e-09, max_E_trunc = 1.4641e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 190, age = 4728
# Energy = -1.2732395021920411, S = 0.8669105642073455, norm_err = 1.1e-05
# Current memory usage 139.7 MB, time elapsed: 58.4 s
# Delta E = -2.2169e-13, Delta S = 1.2839e-04 (per sweep)
# max_trunc_err = 2.2111e-09, max_E_trunc = 1.4803e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 200, age = 4968
# Energy = -1.2732395021523075, S = 0.8676431902151870, norm_err = 9.2e-05
# Current memory usage 139.7 MB, time elapsed: 60.5 s
# Delta E = 3.9734e-12, Delta S = 7.3263e-05 (per sweep)
# max_trunc_err = 2.2165e-09, max_E_trunc = 1.4852e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 210, age = 5208
# Energy = -1.2732395021241700, S = 0.8679596438669603, norm_err = 7.8e-05
# Current memory usage 139.7 MB, time elapsed: 62.7 s
# Delta E = 2.8137e-12, Delta S = 3.1645e-05 (per sweep)
# max_trunc_err = 2.2461e-09, max_E_trunc = 1.5018e-08
# MPS bond dimensions: [32, 32, 32, 32, 32, 32, 32, 32]
# Updating environment
# .....
# ================================================================================
# sweep 220, age = 5448
# ...
# sweep 5490, age = 131928
# Energy = -1.2732395438288222, S = 1.0355260917848628, norm_err = 9.8e-05
# Current memory usage 217.0 MB, time elapsed: 3102.6 s
# Delta E = -7.2760e-13, Delta S = -2.1217e-04 (per sweep)
# max_trunc_err = 4.1474e-11, max_E_trunc = 4.6566e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5500, age = 132168
# Energy = -1.2732395438179083, S = 1.0381182018462518, norm_err = 9.6e-05
# Current memory usage 217.3 MB, time elapsed: 3108.4 s
# Delta E = 1.0914e-12, Delta S = 2.5921e-04 (per sweep)
# max_trunc_err = 4.2174e-11, max_E_trunc = 5.2387e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5510, age = 132408
# Energy = -1.2732395437851665, S = 1.0346221017438455, norm_err = 1.8e-04
# Current memory usage 217.3 MB, time elapsed: 3114.5 s
# Delta E = 3.2742e-12, Delta S = -3.4961e-04 (per sweep)
# max_trunc_err = 4.1337e-11, max_E_trunc = 4.6566e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5520, age = 132648
# Energy = -1.2732395438360982, S = 1.0350463228599542, norm_err = 1.7e-04
# Current memory usage 217.3 MB, time elapsed: 3121.5 s
# Delta E = -5.0932e-12, Delta S = 4.2422e-05 (per sweep)
# max_trunc_err = 4.1616e-11, max_E_trunc = 5.8208e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5530, age = 132888
# Energy = -1.2732395437451487, S = 1.0361823315928822, norm_err = 8.9e-05
# Current memory usage 217.3 MB, time elapsed: 3127.0 s
# Delta E = 9.0949e-12, Delta S = 1.1360e-04 (per sweep)
# max_trunc_err = 4.3243e-11, max_E_trunc = 7.2760e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5540, age = 133128
# Energy = -1.2732395437669766, S = 1.0382452181714728, norm_err = 1.4e-04
# Current memory usage 217.6 MB, time elapsed: 3132.2 s
# Delta E = -2.1828e-12, Delta S = 2.0629e-04 (per sweep)
# max_trunc_err = 4.2617e-11, max_E_trunc = 4.9477e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5550, age = 133368
# Energy = -1.2732395438397361, S = 1.0347626449662961, norm_err = 1.6e-04
# Current memory usage 217.6 MB, time elapsed: 3138.3 s
# Delta E = -7.2760e-12, Delta S = -3.4826e-04 (per sweep)
# max_trunc_err = 4.1454e-11, max_E_trunc = 5.2387e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5560, age = 133608
# Energy = -1.2732395438270032, S = 1.0356686408252456, norm_err = 1.3e-04
# Current memory usage 217.6 MB, time elapsed: 3145.0 s
# Delta E = 1.2733e-12, Delta S = 9.0600e-05 (per sweep)
# max_trunc_err = 4.2376e-11, max_E_trunc = 5.5297e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5570, age = 133848
# Energy = -1.2732395428211021, S = 1.0420308863544492, norm_err = 6.6e-04
# Current memory usage 217.6 MB, time elapsed: 3149.8 s
# Delta E = 1.0059e-10, Delta S = 6.3622e-04 (per sweep)
# max_trunc_err = 4.2659e-11, max_E_trunc = 5.5297e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5580, age = 134088
# Energy = -1.2732395434941282, S = 1.0333463498507602, norm_err = 4.3e-04
# Current memory usage 217.6 MB, time elapsed: 3158.5 s
# Delta E = -6.7303e-11, Delta S = -8.6845e-04 (per sweep)
# max_trunc_err = 4.3669e-11, max_E_trunc = 4.0745e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5590, age = 134328
# Energy = -1.2732395436705701, S = 1.0338263319594720, norm_err = 2.6e-04
# Current memory usage 217.9 MB, time elapsed: 3165.7 s
# Delta E = -1.7644e-11, Delta S = 4.7998e-05 (per sweep)
# max_trunc_err = 4.1486e-11, max_E_trunc = 4.6566e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5600, age = 134568
# Energy = -1.2732395438615640, S = 1.0362347853868574, norm_err = 8.6e-05
# Current memory usage 217.9 MB, time elapsed: 3172.5 s
# Delta E = -1.9099e-11, Delta S = 2.4085e-04 (per sweep)
# max_trunc_err = 4.1733e-11, max_E_trunc = 5.5297e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5610, age = 134808
# Energy = -1.2732395438542881, S = 1.0375071035496430, norm_err = 5.5e-05
# Current memory usage 217.9 MB, time elapsed: 3176.2 s
# Delta E = 7.2760e-13, Delta S = 1.2723e-04 (per sweep)
# max_trunc_err = 4.1347e-11, max_E_trunc = 5.2387e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5620, age = 135048
# Energy = -1.2732395438160893, S = 1.0347487501905110, norm_err = 1.5e-04
# Current memory usage 217.9 MB, time elapsed: 3181.3 s
# Delta E = 3.8199e-12, Delta S = -2.7584e-04 (per sweep)
# max_trunc_err = 4.1477e-11, max_E_trunc = 5.5297e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5630, age = 135288
# Energy = -1.2732395437415107, S = 1.0359239191982774, norm_err = 1.8e-04
# Current memory usage 218.2 MB, time elapsed: 3187.5 s
# Delta E = 7.4579e-12, Delta S = 1.1752e-04 (per sweep)
# max_trunc_err = 4.3312e-11, max_E_trunc = 5.5297e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5640, age = 135528
# Energy = -1.2732395437815285, S = 1.0345186898870684, norm_err = 1.2e-04
# Current memory usage 218.2 MB, time elapsed: 3192.6 s
# Delta E = -4.0018e-12, Delta S = -1.4052e-04 (per sweep)
# max_trunc_err = 4.1282e-11, max_E_trunc = 5.2387e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5650, age = 135768
# Energy = -1.2732395434941282, S = 1.0343137711514396, norm_err = 4.1e-04
# Current memory usage 218.2 MB, time elapsed: 3198.7 s
# Delta E = 2.8740e-11, Delta S = -2.0492e-05 (per sweep)
# max_trunc_err = 4.2813e-11, max_E_trunc = 5.8208e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5660, age = 136008
# Energy = -1.2732395436869410, S = 1.0340547817022716, norm_err = 2.7e-04
# Current memory usage 218.5 MB, time elapsed: 3206.2 s
# Delta E = -1.9281e-11, Delta S = -2.5899e-05 (per sweep)
# max_trunc_err = 4.1595e-11, max_E_trunc = 5.2387e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5670, age = 136248
# Energy = -1.2732395437724335, S = 1.0343522154118463, norm_err = 2.2e-04
# Current memory usage 218.5 MB, time elapsed: 3212.9 s
# Delta E = -8.5493e-12, Delta S = 2.9743e-05 (per sweep)
# max_trunc_err = 4.1436e-11, max_E_trunc = 5.2387e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5680, age = 136488
# Energy = -1.2732395438288222, S = 1.0352370264431676, norm_err = 1.6e-04
# Current memory usage 218.5 MB, time elapsed: 3219.8 s
# Delta E = -5.6389e-12, Delta S = 8.8481e-05 (per sweep)
# max_trunc_err = 4.2313e-11, max_E_trunc = 5.8208e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5690, age = 136728
# Energy = -1.2732395435050421, S = 1.0392075495327560, norm_err = 2.3e-04
# Current memory usage 218.8 MB, time elapsed: 3224.6 s
# Delta E = 3.2378e-11, Delta S = 3.9705e-04 (per sweep)
# max_trunc_err = 4.2000e-11, max_E_trunc = 5.8208e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5700, age = 136968
# Energy = -1.2732395435832586, S = 1.0380175907874749, norm_err = 9.6e-05
# Current memory usage 218.8 MB, time elapsed: 3231.4 s
# Delta E = -7.8217e-12, Delta S = -1.1900e-04 (per sweep)
# max_trunc_err = 4.2548e-11, max_E_trunc = 5.8208e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5710, age = 137208
# Energy = -1.2732395437451487, S = 1.0358436541768279, norm_err = 1.1e-04
# Current memory usage 219.0 MB, time elapsed: 3237.1 s
# Delta E = -1.6189e-11, Delta S = -2.1739e-04 (per sweep)
# max_trunc_err = 4.2737e-11, max_E_trunc = 6.9849e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5720, age = 137448
# Energy = -1.2732395438215462, S = 1.0379809388627761, norm_err = 1.2e-04
# Current memory usage 219.1 MB, time elapsed: 3243.1 s
# Delta E = -7.6398e-12, Delta S = 2.1373e-04 (per sweep)
# max_trunc_err = 4.1571e-11, max_E_trunc = 4.6566e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5730, age = 137688
# Energy = -1.2732395438251842, S = 1.0352565318699729, norm_err = 8.6e-05
# Current memory usage 219.1 MB, time elapsed: 3249.2 s
# Delta E = -3.6380e-13, Delta S = -2.7244e-04 (per sweep)
# max_trunc_err = 4.2167e-11, max_E_trunc = 4.6566e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5740, age = 137928
# Energy = -1.2732395437324158, S = 1.0386024519713797, norm_err = 1.8e-04
# Current memory usage 219.3 MB, time elapsed: 3255.2 s
# Delta E = 9.2768e-12, Delta S = 3.3459e-04 (per sweep)
# max_trunc_err = 4.1459e-11, max_E_trunc = 4.6566e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5750, age = 138168
# Energy = -1.2732395435887156, S = 1.0393317196204386, norm_err = 2.4e-04
# Current memory usage 219.3 MB, time elapsed: 3261.6 s
# Delta E = 1.4370e-11, Delta S = 7.2927e-05 (per sweep)
# max_trunc_err = 4.2419e-11, max_E_trunc = 5.2387e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5760, age = 138408
# Energy = -1.2732395437051309, S = 1.0387069247500604, norm_err = 1.7e-04
# Current memory usage 219.6 MB, time elapsed: 3269.2 s
# Delta E = -1.1642e-11, Delta S = -6.2479e-05 (per sweep)
# max_trunc_err = 4.3266e-11, max_E_trunc = 5.5297e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5770, age = 138648
# Energy = -1.2732395438451931, S = 1.0373156817646634, norm_err = 1.1e-04
# Current memory usage 219.6 MB, time elapsed: 3276.1 s
# Delta E = -1.4006e-11, Delta S = -1.3912e-04 (per sweep)
# max_trunc_err = 4.2239e-11, max_E_trunc = 5.5297e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5780, age = 138888
# Energy = -1.2732395434213686, S = 1.0346495623946377, norm_err = 3.2e-04
# Current memory usage 219.6 MB, time elapsed: 3280.7 s
# Delta E = 4.2382e-11, Delta S = -2.6661e-04 (per sweep)
# max_trunc_err = 4.2432e-11, max_E_trunc = 7.5670e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5790, age = 139128
# Energy = -1.2732395438288222, S = 1.0353519800383166, norm_err = 1.9e-04
# Current memory usage 219.9 MB, time elapsed: 3288.5 s
# Delta E = -4.0745e-11, Delta S = 7.0242e-05 (per sweep)
# max_trunc_err = 4.2501e-11, max_E_trunc = 4.9477e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5800, age = 139368
# Energy = -1.2732395436287334, S = 1.0366343038966499, norm_err = 1.7e-04
# Current memory usage 219.9 MB, time elapsed: 3294.3 s
# Delta E = 2.0009e-11, Delta S = 1.2823e-04 (per sweep)
# max_trunc_err = 4.2927e-11, max_E_trunc = 4.9477e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5810, age = 139608
# Energy = -1.2732395432503836, S = 1.0359540410172778, norm_err = 2.0e-04
# Current memory usage 219.9 MB, time elapsed: 3299.6 s
# Delta E = 3.7835e-11, Delta S = -6.8026e-05 (per sweep)
# max_trunc_err = 4.1725e-11, max_E_trunc = 5.5297e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5820, age = 139848
# Energy = -1.2732395437324158, S = 1.0367074667799585, norm_err = 1.1e-04
# Current memory usage 220.2 MB, time elapsed: 3305.5 s
# Delta E = -4.8203e-11, Delta S = 7.5343e-05 (per sweep)
# max_trunc_err = 4.2032e-11, max_E_trunc = 6.1118e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 5830, age = 140088
# Energy = -1.2732395439088577, S = 1.0366985203737884, norm_err = 2.8e-05
# Current memory usage 220.2 MB, time elapsed: 3310.3 s
# Delta E = -1.7644e-11, Delta S = -8.9464e-07 (per sweep)
# max_trunc_err = 4.1474e-11, max_E_trunc = 4.3656e-10
# MPS bond dimensions: [90, 90, 90, 90, 90, 90, 90, 90]
# norm_tol=1.00e-05 not reached, norm_err=2.82e-05
# Updating environment
# .
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:446: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ....
# Updating environment
# .....
# Updating environment
# .....
# Updating environment
# .....
# Updating environment
# .....
# DMRG: norm_tol 1.00e-05 not reached by updating the environment, current norm_err = 2.49e-05
# Call psi.canonical_form()
# ================================================================================
# DMRG finished after 5830 sweeps.
# total size = 140488, maximum chi = 90
# ================================================================================
# Before the canonicalization:
# Bond dim =  [90, 90, 90, 90, 90, 90, 90, 90]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.0000000000000027+0j)
# After the canonicalization:
# Bond dim =  [90, 90, 90, 90, 90, 90, 90, 90]
# Computing properties
# Optimizing
# Loop for chi=90 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================

# %%
plot_results(data)

# %%
chi_list = data['chi_list']
energy_list = data['energy_list']
entropy_list = data['entropy_list']
correlation_list = data['correlation_list']

# entropy_list = entropy_list[0:5]
# correlation_list = correlation_list[0:5]
log_xi = np.log(correlation_list)

print((entropy_list[-1] - entropy_list[0])/(log_xi[-1] - log_xi[0]) * 6)
# Out:
# 0.48243599625283146

# %%
def run_TFI(calc_correlation=True):

    model_params = dict(
        L=2, 
        J=1., 
        g=1., 
        bc_MPS='infinite', 
        conserve='best',
        verbose=0,
        )
    prod_state = ["up"] * model_params['L']
    M = TFIChain(model_params)
    psi = MPS.from_product_state(
        M.lat.mps_sites(), 
        prod_state, 
        bc=M.lat.bc_MPS,
    )

    dmrg_params = {
        'start_env': 10,
#         'mixer': False,  # setting this to True helps to escape local minima
        'mixer': True,
        'mixer_params': {
            'amplitude': 1.e-5,
            'decay': 1.2,
            'disable_after': 30
        },
        'trunc_params': {
            'chi_max': 4,
            'svd_min': 1.e-10,
        },
        'max_E_err': 1.e-10,
        'max_S_err': 1.e-8,
        'max_sweeps': 1000,
        'verbose': 1.,
    }
    
    
#     eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
    
    # we will return this data dictionary in the end, for the further investigation
    data = dict(
        chi_list=[],
        energy_list=[], 
        entropy_list=[], 
        correlation_list=[],
    )
    
#     chi_list = np.arange(4, 129)
    chi_list = [int(2**i) for i in np.arange(4, 7, 0.5)]
    data['chi_list'] = chi_list
    for chi in chi_list:
        
        print("\n")
        print("=" * 80)
        print("="*30 + "START" + "="*30)
        print("=" * 80)
        print("Chi = ", chi, '\n')
        
        eng = dmrg.TwoSiteDMRGEngine(psi, M, dmrg_params)
        eng.reset_stats()
        eng.trunc_params['chi_max'] = chi
        info = eng.run()
#         print("INFO: \n", info)

        print("Before the canonicalization:")
        print("Bond dim = ", psi.chi)
        
        print("Canonicalizing...")
        psi_before = psi.copy()
        psi.canonical_form()
        ov = psi.overlap(psi_before, charge_sector=0)
        print("The norm is: ",psi.norm)
        print("The overlap is: ", ov)
        print("After the canonicalization:")
        print("Bond dim = ", psi.chi)
        
        print("Computing properties")
        
        energy=info[0]
        data['energy_list'].append(energy)
        
        entropy = np.mean(psi.entanglement_entropy())
        data['entropy_list'].append(entropy)
        
        if calc_correlation:
            correlation = psi.correlation_length()
            data['correlation_list'].append(correlation)
        
        print("Optimizing")
        tenpy.tools.optimization.optimize(3)
        print("Loop for chi=%d done." % chi)
        print("=" * 80)
        print("="*30 + " END " + "="*30)
        print("=" * 80)
        pass
        
    return data

# %%
data=run_TFI()
# Out:
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  16
#
# parameter 'verbose'=1.0 for Sweep
# parameter 'trunc_params'={'chi_max': 4, 'svd_min': 1e-10} for Sweep
# Initial sweeps...
# parameter 'start_env'=10 for Sweep
# Updating environment
# ..........
# parameter 'max_sweeps'=1000 for DMRG
# parameter 'max_E_err'=1e-10 for DMRG
# parameter 'max_S_err'=1e-08 for DMRG
# parameter 'mixer'=True for Sweep
# parameter 'mixer_params'={'amplitude': 1e-05, 'decay': 1.2, 'disable_after': 30} for Sweep
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 200
# Energy = -1.2732294404668103, S = nan, norm_err = 9.1e-04
# Current memory usage 220.5 MB, time elapsed: 1.8 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 6.2977e-10, max_E_trunc = 2.0405e-09
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 320
# Energy = -1.2732370232930705, S = nan, norm_err = 5.4e-04
# Current memory usage 220.5 MB, time elapsed: 3.4 s
# Delta E = -7.5828e-07, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 8.3432e-09, max_E_trunc = 2.6269e-08
# MPS bond dimensions: [16, 16]
# disable mixer after 30 sweeps, final amplitude 4.21e-08
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 440
# Energy = -1.2732382655098746, S = 0.6863540298218318, norm_err = 3.5e-04
# Current memory usage 220.5 MB, time elapsed: 4.7 s
# Delta E = -1.2422e-07, Delta S = nan (per sweep)
# max_trunc_err = 1.9050e-08, max_E_trunc = 5.9667e-08
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 560
# Energy = -1.2732386358999435, S = 0.7062256809435722, norm_err = 2.9e-04
# Current memory usage 220.5 MB, time elapsed: 5.6 s
# Delta E = -3.7039e-08, Delta S = 1.9872e-03 (per sweep)
# max_trunc_err = 1.4677e-08, max_E_trunc = 9.1585e-08
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 680
# Energy = -1.2732388248019220, S = 0.7210315248694521, norm_err = 1.4e-04
# Current memory usage 220.5 MB, time elapsed: 6.5 s
# Delta E = -1.8890e-08, Delta S = 1.4806e-03 (per sweep)
# max_trunc_err = 1.8730e-08, max_E_trunc = 1.1683e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 800
# Energy = -1.2732388668344186, S = 0.7312943053419467, norm_err = 1.7e-04
# Current memory usage 220.5 MB, time elapsed: 7.4 s
# Delta E = -4.2032e-09, Delta S = 1.0263e-03 (per sweep)
# max_trunc_err = 2.2553e-08, max_E_trunc = 1.4036e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 920
# Energy = -1.2732389314105035, S = 0.7392545060817544, norm_err = 1.0e-04
# Current memory usage 220.5 MB, time elapsed: 8.0 s
# Delta E = -6.4576e-09, Delta S = 7.9602e-04 (per sweep)
# max_trunc_err = 2.4526e-08, max_E_trunc = 1.5314e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 1040
# Energy = -1.2732389490681726, S = 0.7450214184769577, norm_err = 8.1e-05
# Current memory usage 220.5 MB, time elapsed: 8.5 s
# Delta E = -1.7658e-09, Delta S = 5.7669e-04 (per sweep)
# max_trunc_err = 2.6666e-08, max_E_trunc = 1.6643e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 1160
# Energy = -1.2732389579508947, S = 0.7493266747257276, norm_err = 7.1e-05
# Current memory usage 220.5 MB, time elapsed: 9.0 s
# Delta E = -8.8827e-10, Delta S = 4.3053e-04 (per sweep)
# max_trunc_err = 2.8339e-08, max_E_trunc = 1.7682e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 1280
# Energy = -1.2732389625129770, S = 0.7526951265896773, norm_err = 6.3e-05
# Current memory usage 220.5 MB, time elapsed: 9.5 s
# Delta E = -4.5621e-10, Delta S = 3.3685e-04 (per sweep)
# max_trunc_err = 2.9616e-08, max_E_trunc = 1.8476e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 110, age = 1400
# Energy = -1.2732389646446620, S = 0.7551929576736799, norm_err = 6.1e-05
# Current memory usage 220.5 MB, time elapsed: 10.0 s
# Delta E = -2.1317e-10, Delta S = 2.4978e-04 (per sweep)
# max_trunc_err = 3.0623e-08, max_E_trunc = 1.9100e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 120, age = 1520
# Energy = -1.2732389656673320, S = 0.7571831249445234, norm_err = 5.6e-05
# Current memory usage 220.5 MB, time elapsed: 10.5 s
# Delta E = -1.0227e-10, Delta S = 1.9902e-04 (per sweep)
# max_trunc_err = 3.1384e-08, max_E_trunc = 1.9572e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 130, age = 1640
# Energy = -1.2732389659971091, S = 0.7586119620922158, norm_err = 5.6e-05
# Current memory usage 220.5 MB, time elapsed: 11.0 s
# Delta E = -3.2978e-11, Delta S = 1.4288e-04 (per sweep)
# max_trunc_err = 3.1993e-08, max_E_trunc = 1.9948e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 140, age = 1760
# Energy = -1.2732389661451293, S = 0.7597806244744699, norm_err = 5.1e-05
# Current memory usage 220.5 MB, time elapsed: 11.5 s
# Delta E = -1.4802e-11, Delta S = 1.1687e-04 (per sweep)
# max_trunc_err = 3.2443e-08, max_E_trunc = 2.0228e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 150, age = 1880
# Energy = -1.2732389660988588, S = 0.7605647318604543, norm_err = 5.0e-05
# Current memory usage 220.5 MB, time elapsed: 12.0 s
# Delta E = 4.6271e-12, Delta S = 7.8411e-05 (per sweep)
# max_trunc_err = 3.2814e-08, max_E_trunc = 2.0457e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 160, age = 2000
# Energy = -1.2732389661153434, S = 0.7612427699013611, norm_err = 4.3e-05
# Current memory usage 220.5 MB, time elapsed: 12.6 s
# Delta E = -1.6485e-12, Delta S = 6.7804e-05 (per sweep)
# max_trunc_err = 3.3077e-08, max_E_trunc = 2.0621e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 170, age = 2120
# Energy = -1.2732389660455965, S = 0.7616410695692775, norm_err = 4.1e-05
# Current memory usage 220.5 MB, time elapsed: 13.1 s
# Delta E = 6.9747e-12, Delta S = 3.9830e-05 (per sweep)
# max_trunc_err = 3.3305e-08, max_E_trunc = 2.0763e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 180, age = 2240
# Energy = -1.2732389660729950, S = 0.7620350988603246, norm_err = 3.2e-05
# Current memory usage 220.5 MB, time elapsed: 13.6 s
# Delta E = -2.7399e-12, Delta S = 3.9403e-05 (per sweep)
# max_trunc_err = 3.3456e-08, max_E_trunc = 2.0858e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 190, age = 2360
# Energy = -1.2732389660115473, S = 0.7622114352239265, norm_err = 2.9e-05
# Current memory usage 220.5 MB, time elapsed: 14.1 s
# Delta E = 6.1448e-12, Delta S = 1.7634e-05 (per sweep)
# max_trunc_err = 3.3602e-08, max_E_trunc = 2.0949e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 200, age = 2480
# Energy = -1.2732389660366721, S = 0.7624530775767862, norm_err = 2.0e-05
# Current memory usage 220.5 MB, time elapsed: 14.6 s
# Delta E = -2.5125e-12, Delta S = 2.4164e-05 (per sweep)
# max_trunc_err = 3.3686e-08, max_E_trunc = 2.1003e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 210, age = 2600
# Energy = -1.2732389659634578, S = 0.7625091806443471, norm_err = 1.8e-05
# Current memory usage 220.5 MB, time elapsed: 15.1 s
# Delta E = 7.3214e-12, Delta S = 5.6103e-06 (per sweep)
# max_trunc_err = 3.3785e-08, max_E_trunc = 2.1065e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 220, age = 2720
# Energy = -1.2732389659751107, S = 0.7626773690686126, norm_err = 1.0e-05
# Current memory usage 220.5 MB, time elapsed: 15.6 s
# Delta E = -1.1653e-12, Delta S = 1.6819e-05 (per sweep)
# max_trunc_err = 3.3830e-08, max_E_trunc = 2.1094e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 230, age = 2840
# Energy = -1.2732389658900161, S = 0.7626696668536169, norm_err = 1.0e-05
# Current memory usage 220.5 MB, time elapsed: 16.1 s
# Delta E = 8.5095e-12, Delta S = -7.7022e-07 (per sweep)
# max_trunc_err = 3.3903e-08, max_E_trunc = 2.1139e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 240, age = 2960
# Energy = -1.2732389658974057, S = 0.7628060112587649, norm_err = 3.1e-06
# Current memory usage 220.5 MB, time elapsed: 16.6 s
# Delta E = -7.3896e-13, Delta S = 1.3634e-05 (per sweep)
# max_trunc_err = 3.3921e-08, max_E_trunc = 2.1151e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 250, age = 3080
# Energy = -1.2732389658128227, S = 0.7627614371108491, norm_err = 4.8e-06
# Current memory usage 220.5 MB, time elapsed: 17.1 s
# Delta E = 8.4583e-12, Delta S = -4.4574e-06 (per sweep)
# max_trunc_err = 3.3981e-08, max_E_trunc = 2.1188e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 260, age = 3200
# Energy = -1.2732389658272609, S = 0.7628858556533269, norm_err = 3.6e-06
# Current memory usage 220.5 MB, time elapsed: 17.6 s
# Delta E = -1.4438e-12, Delta S = 1.2442e-05 (per sweep)
# max_trunc_err = 3.3979e-08, max_E_trunc = 2.1187e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 270, age = 3320
# Energy = -1.2732389657439853, S = 0.7628161071746734, norm_err = 2.7e-06
# Current memory usage 220.5 MB, time elapsed: 18.1 s
# Delta E = 8.3276e-12, Delta S = -6.9748e-06 (per sweep)
# max_trunc_err = 3.4031e-08, max_E_trunc = 2.1220e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 280, age = 3440
# Energy = -1.2732389657680869, S = 0.7629384266543060, norm_err = 6.4e-06
# Current memory usage 220.5 MB, time elapsed: 18.6 s
# Delta E = -2.4102e-12, Delta S = 1.2232e-05 (per sweep)
# max_trunc_err = 3.4015e-08, max_E_trunc = 2.1210e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 290, age = 3560
# Energy = -1.2732389656873693, S = 0.7628485781856204, norm_err = 3.2e-06
# Current memory usage 220.5 MB, time elapsed: 19.1 s
# Delta E = 8.0718e-12, Delta S = -8.9848e-06 (per sweep)
# max_trunc_err = 3.4065e-08, max_E_trunc = 2.1240e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 300, age = 3680
# Energy = -1.2732389657202248, S = 0.7629744512860243, norm_err = 8.4e-06
# Current memory usage 220.5 MB, time elapsed: 19.6 s
# Delta E = -3.2855e-12, Delta S = 1.2587e-05 (per sweep)
# max_trunc_err = 3.4037e-08, max_E_trunc = 2.1224e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 310, age = 3800
# Energy = -1.2732389656393934, S = 0.7628667487485268, norm_err = 3.9e-06
# Current memory usage 220.5 MB, time elapsed: 20.1 s
# Delta E = 8.0831e-12, Delta S = -1.0770e-05 (per sweep)
# max_trunc_err = 3.4087e-08, max_E_trunc = 2.1254e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 320, age = 3920
# Energy = -1.2732389656821397, S = 0.7630000367805649, norm_err = 9.8e-06
# Current memory usage 220.5 MB, time elapsed: 20.6 s
# Delta E = -4.2746e-12, Delta S = 1.3329e-05 (per sweep)
# max_trunc_err = 3.4050e-08, max_E_trunc = 2.1231e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 330, age = 4040
# Energy = -1.2732389655957377, S = 0.7628753405798310, norm_err = 4.4e-06
# Current memory usage 220.5 MB, time elapsed: 21.1 s
# Delta E = 8.6402e-12, Delta S = -1.2470e-05 (per sweep)
# max_trunc_err = 3.4102e-08, max_E_trunc = 2.1263e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 340, age = 4160
# Energy = -1.2732389656440546, S = 0.7630190167260901, norm_err = 1.1e-05
# Current memory usage 220.5 MB, time elapsed: 21.6 s
# Delta E = -4.8317e-12, Delta S = 1.4368e-05 (per sweep)
# max_trunc_err = 3.4058e-08, max_E_trunc = 2.1236e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 350, age = 4280
# Energy = -1.2732389655518546, S = 0.7628773667134094, norm_err = 4.7e-06
# Current memory usage 220.5 MB, time elapsed: 22.1 s
# Delta E = 9.2200e-12, Delta S = -1.4165e-05 (per sweep)
# max_trunc_err = 3.4114e-08, max_E_trunc = 2.1270e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 360, age = 4400
# Energy = -1.2732389656055147, S = 0.7630338961500776, norm_err = 1.2e-05
# Current memory usage 220.5 MB, time elapsed: 22.6 s
# Delta E = -5.3660e-12, Delta S = 1.5653e-05 (per sweep)
# max_trunc_err = 3.4062e-08, max_E_trunc = 2.1239e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 370, age = 4520
# Energy = -1.2732389655041061, S = 0.7628747793504425, norm_err = 5.0e-06
# Current memory usage 220.5 MB, time elapsed: 23.1 s
# Delta E = 1.0141e-11, Delta S = -1.5912e-05 (per sweep)
# max_trunc_err = 3.4123e-08, max_E_trunc = 2.1276e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 380, age = 4640
# Energy = -1.2732389655639054, S = 0.7630463063070099, norm_err = 1.3e-05
# Current memory usage 220.5 MB, time elapsed: 23.6 s
# Delta E = -5.9799e-12, Delta S = 1.7153e-05 (per sweep)
# max_trunc_err = 3.4064e-08, max_E_trunc = 2.1240e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 390, age = 4760
# Energy = -1.2732389654509007, S = 0.7628688331517868, norm_err = 5.2e-06
# Current memory usage 220.5 MB, time elapsed: 24.1 s
# Delta E = 1.1300e-11, Delta S = -1.7747e-05 (per sweep)
# max_trunc_err = 3.4131e-08, max_E_trunc = 2.1281e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 400, age = 4880
# Energy = -1.2732389655142242, S = 0.7630572926959780, norm_err = 1.3e-05
# Current memory usage 220.5 MB, time elapsed: 24.6 s
# Delta E = -6.3324e-12, Delta S = 1.8846e-05 (per sweep)
# max_trunc_err = 3.4066e-08, max_E_trunc = 2.1241e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 410, age = 5000
# Energy = -1.2732389653887140, S = 0.7628603180590192, norm_err = 5.5e-06
# Current memory usage 220.5 MB, time elapsed: 25.2 s
# Delta E = 1.2551e-11, Delta S = -1.9697e-05 (per sweep)
# max_trunc_err = 3.4140e-08, max_E_trunc = 2.1286e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 420, age = 5120
# Energy = -1.2732389654536291, S = 0.7630674797267314, norm_err = 1.4e-05
# Current memory usage 220.5 MB, time elapsed: 25.7 s
# Delta E = -6.4915e-12, Delta S = 2.0716e-05 (per sweep)
# max_trunc_err = 3.4066e-08, max_E_trunc = 2.1241e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 430, age = 5240
# Energy = -1.2732389653168639, S = 0.7628497178436571, norm_err = 5.8e-06
# Current memory usage 220.5 MB, time elapsed: 26.2 s
# Delta E = 1.3677e-11, Delta S = -2.1776e-05 (per sweep)
# max_trunc_err = 3.4148e-08, max_E_trunc = 2.1290e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 440, age = 5360
# Energy = -1.2732389653862128, S = 0.7630772049301662, norm_err = 1.5e-05
# Current memory usage 220.5 MB, time elapsed: 26.7 s
# Delta E = -6.9349e-12, Delta S = 2.2749e-05 (per sweep)
# max_trunc_err = 3.4067e-08, max_E_trunc = 2.1242e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 450, age = 5480
# Energy = -1.2732389652348957, S = 0.7628373297007049, norm_err = 6.1e-06
# Current memory usage 220.5 MB, time elapsed: 27.2 s
# Delta E = 1.5132e-11, Delta S = -2.3988e-05 (per sweep)
# max_trunc_err = 3.4157e-08, max_E_trunc = 2.1296e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 460, age = 5600
# Energy = -1.2732389653076552, S = 0.7630865767419082, norm_err = 1.6e-05
# Current memory usage 220.5 MB, time elapsed: 27.7 s
# Delta E = -7.2760e-12, Delta S = 2.4925e-05 (per sweep)
# max_trunc_err = 3.4067e-08, max_E_trunc = 2.1242e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 470, age = 5720
# Energy = -1.2732389651409903, S = 0.7628233353625198, norm_err = 6.5e-06
# Current memory usage 220.5 MB, time elapsed: 28.2 s
# Delta E = 1.6666e-11, Delta S = -2.6324e-05 (per sweep)
# max_trunc_err = 3.4166e-08, max_E_trunc = 2.1301e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 480, age = 5840
# Energy = -1.2732389229288401, S = 0.7628010617125807, norm_err = 7.7e-05
# Current memory usage 220.5 MB, time elapsed: 29.2 s
# Delta E = 4.2212e-09, Delta S = -2.2274e-06 (per sweep)
# max_trunc_err = 3.5036e-08, max_E_trunc = 2.1759e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 490, age = 5960
# Energy = -1.2732389563965398, S = 0.7619535659758334, norm_err = 5.8e-05
# Current memory usage 220.5 MB, time elapsed: 30.2 s
# Delta E = -3.3468e-09, Delta S = -8.4750e-05 (per sweep)
# max_trunc_err = 3.4964e-08, max_E_trunc = 2.1715e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 500, age = 6080
# Energy = -1.2732389026388091, S = 0.7624955501655474, norm_err = 9.6e-05
# Current memory usage 220.5 MB, time elapsed: 31.2 s
# Delta E = 5.3758e-09, Delta S = 5.4198e-05 (per sweep)
# max_trunc_err = 3.5258e-08, max_E_trunc = 2.1892e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 510, age = 6200
# Energy = -1.2732389590062212, S = 0.7624178343108778, norm_err = 4.4e-05
# Current memory usage 220.5 MB, time elapsed: 32.2 s
# Delta E = -5.6367e-09, Delta S = -7.7716e-06 (per sweep)
# max_trunc_err = 3.5035e-08, max_E_trunc = 2.1759e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 520, age = 6320
# Energy = -1.2732388995525525, S = 0.7645774094917632, norm_err = 9.8e-05
# Current memory usage 220.5 MB, time elapsed: 33.2 s
# Delta E = 5.9454e-09, Delta S = 2.1596e-04 (per sweep)
# max_trunc_err = 3.5309e-08, max_E_trunc = 2.1924e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 530, age = 6440
# Energy = -1.2732389611237522, S = 0.7643770159581202, norm_err = 3.5e-05
# Current memory usage 220.5 MB, time elapsed: 34.1 s
# Delta E = -6.1571e-09, Delta S = -2.0039e-05 (per sweep)
# max_trunc_err = 3.5548e-08, max_E_trunc = 2.2071e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 540, age = 6560
# Energy = -1.2732388474948948, S = 0.7646539276354072, norm_err = 1.2e-04
# Current memory usage 220.5 MB, time elapsed: 35.1 s
# Delta E = 1.1363e-08, Delta S = 2.7691e-05 (per sweep)
# max_trunc_err = 3.5198e-08, max_E_trunc = 2.1857e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 550, age = 6680
# Energy = -1.2732389474533647, S = 0.7623721600263371, norm_err = 7.7e-05
# Current memory usage 220.5 MB, time elapsed: 36.1 s
# Delta E = -9.9958e-09, Delta S = -2.2818e-04 (per sweep)
# max_trunc_err = 3.5589e-08, max_E_trunc = 2.2096e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 560, age = 6800
# Energy = -1.2732389549046275, S = 0.7631607281480288, norm_err = 4.4e-05
# Current memory usage 220.5 MB, time elapsed: 37.1 s
# Delta E = -7.4513e-10, Delta S = 7.8857e-05 (per sweep)
# max_trunc_err = 3.5690e-08, max_E_trunc = 2.2160e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 570, age = 6920
# Energy = -1.2732389089060234, S = 0.7640797654137376, norm_err = 8.4e-05
# Current memory usage 220.5 MB, time elapsed: 38.0 s
# Delta E = 4.5999e-09, Delta S = 9.1904e-05 (per sweep)
# max_trunc_err = 3.5571e-08, max_E_trunc = 2.2086e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 580, age = 7040
# Energy = -1.2732389039288137, S = 0.7658107767274354, norm_err = 1.3e-04
# Current memory usage 220.5 MB, time elapsed: 39.0 s
# Delta E = 4.9772e-10, Delta S = 1.7310e-04 (per sweep)
# max_trunc_err = 3.5258e-08, max_E_trunc = 2.1894e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 590, age = 7160
# Energy = -1.2732389647294440, S = 0.7642622088928482, norm_err = 1.7e-05
# Current memory usage 220.5 MB, time elapsed: 39.6 s
# Delta E = -6.0801e-09, Delta S = -1.5486e-04 (per sweep)
# max_trunc_err = 3.4578e-08, max_E_trunc = 2.1540e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 600, age = 7280
# Energy = -1.2732389642412727, S = 0.7642405850823826, norm_err = 5.4e-05
# Current memory usage 220.5 MB, time elapsed: 40.1 s
# Delta E = 4.8817e-11, Delta S = -2.1624e-06 (per sweep)
# max_trunc_err = 3.4276e-08, max_E_trunc = 2.1361e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 610, age = 7400
# Energy = -1.2732389642699218, S = 0.7641130087863039, norm_err = 5.9e-05
# Current memory usage 220.5 MB, time elapsed: 40.6 s
# Delta E = -2.8649e-12, Delta S = -1.2758e-05 (per sweep)
# max_trunc_err = 3.4217e-08, max_E_trunc = 2.1311e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 620, age = 7520
# Energy = -1.2732389645564126, S = 0.7639225801104867, norm_err = 5.6e-05
# Current memory usage 220.5 MB, time elapsed: 41.1 s
# Delta E = -2.8649e-11, Delta S = -1.9043e-05 (per sweep)
# max_trunc_err = 3.4179e-08, max_E_trunc = 2.1286e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 630, age = 7640
# Energy = -1.2732389649090692, S = 0.7637656869654773, norm_err = 4.7e-05
# Current memory usage 220.5 MB, time elapsed: 41.6 s
# Delta E = -3.5266e-11, Delta S = -1.5689e-05 (per sweep)
# max_trunc_err = 3.4130e-08, max_E_trunc = 2.1260e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 640, age = 7760
# Energy = -1.2732389652012444, S = 0.7635869761702239, norm_err = 4.0e-05
# Current memory usage 220.5 MB, time elapsed: 42.1 s
# Delta E = -2.9218e-11, Delta S = -1.7871e-05 (per sweep)
# max_trunc_err = 3.4105e-08, max_E_trunc = 2.1251e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 650, age = 7880
# Energy = -1.2732389654438521, S = 0.7634632102529857, norm_err = 3.0e-05
# Current memory usage 220.5 MB, time elapsed: 42.6 s
# Delta E = -2.4261e-11, Delta S = -1.2377e-05 (per sweep)
# max_trunc_err = 3.4074e-08, max_E_trunc = 2.1239e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 660, age = 8000
# Energy = -1.2732389655898260, S = 0.7633243533698970, norm_err = 2.4e-05
# Current memory usage 220.5 MB, time elapsed: 43.1 s
# Delta E = -1.4597e-11, Delta S = -1.3886e-05 (per sweep)
# max_trunc_err = 3.4068e-08, max_E_trunc = 2.1237e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 670, age = 8120
# Energy = -1.2732389656978285, S = 0.7632481514534435, norm_err = 1.6e-05
# Current memory usage 220.5 MB, time elapsed: 43.6 s
# Delta E = -1.0800e-11, Delta S = -7.6202e-06 (per sweep)
# max_trunc_err = 3.4056e-08, max_E_trunc = 2.1232e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 680, age = 8240
# Energy = -1.2732389657373915, S = 0.7631523901500238, norm_err = 1.1e-05
# Current memory usage 220.5 MB, time elapsed: 44.1 s
# Delta E = -3.9563e-12, Delta S = -9.5761e-06 (per sweep)
# max_trunc_err = 3.4061e-08, max_E_trunc = 2.1237e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 690, age = 8360
# Energy = -1.2732389657735439, S = 0.7631187229989045, norm_err = 5.8e-06
# Current memory usage 220.5 MB, time elapsed: 44.6 s
# Delta E = -3.6152e-12, Delta S = -3.3667e-06 (per sweep)
# max_trunc_err = 3.4057e-08, max_E_trunc = 2.1235e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 700, age = 8480
# Energy = -1.2732389657655858, S = 0.7630544526796627, norm_err = 3.7e-06
# Current memory usage 220.5 MB, time elapsed: 45.1 s
# Delta E = 7.9581e-13, Delta S = -6.4270e-06 (per sweep)
# max_trunc_err = 3.4066e-08, max_E_trunc = 2.1241e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 710, age = 8600
# Energy = -1.2732389657837757, S = 0.7630498643694681, norm_err = 1.2e-06
# Current memory usage 220.5 MB, time elapsed: 45.7 s
# Delta E = -1.8190e-12, Delta S = -4.5883e-07 (per sweep)
# max_trunc_err = 3.4063e-08, max_E_trunc = 2.1240e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 720, age = 8720
# Energy = -1.2732389657621752, S = 0.7630032006484921, norm_err = 1.6e-06
# Current memory usage 220.5 MB, time elapsed: 46.2 s
# Delta E = 2.1600e-12, Delta S = -4.6664e-06 (per sweep)
# max_trunc_err = 3.4073e-08, max_E_trunc = 2.1246e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 730, age = 8840
# Energy = -1.2732389657733165, S = 0.7630162120599765, norm_err = 4.0e-06
# Current memory usage 220.5 MB, time elapsed: 46.7 s
# Delta E = -1.1141e-12, Delta S = 1.3011e-06 (per sweep)
# max_trunc_err = 3.4069e-08, max_E_trunc = 2.1244e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 740, age = 8960
# Energy = -1.2732389657480780, S = 0.7629773266264535, norm_err = 3.6e-06
# Current memory usage 220.5 MB, time elapsed: 47.2 s
# Delta E = 2.5238e-12, Delta S = -3.8885e-06 (per sweep)
# max_trunc_err = 3.4079e-08, max_E_trunc = 2.1249e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 750, age = 9080
# Energy = -1.2732389657605836, S = 0.7630010137514280, norm_err = 5.8e-06
# Current memory usage 220.5 MB, time elapsed: 47.7 s
# Delta E = -1.2506e-12, Delta S = 2.3687e-06 (per sweep)
# max_trunc_err = 3.4073e-08, max_E_trunc = 2.1245e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 760, age = 9200
# Energy = -1.2732389657376189, S = 0.7629641852657663, norm_err = 4.8e-06
# Current memory usage 220.5 MB, time elapsed: 48.2 s
# Delta E = 2.2965e-12, Delta S = -3.6828e-06 (per sweep)
# max_trunc_err = 3.4084e-08, max_E_trunc = 2.1253e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 770, age = 9320
# Energy = -1.2732389657544445, S = 0.7629950308126698, norm_err = 6.8e-06
# Current memory usage 220.5 MB, time elapsed: 48.7 s
# Delta E = -1.6826e-12, Delta S = 3.0846e-06 (per sweep)
# max_trunc_err = 3.4075e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 780, age = 9440
# Energy = -1.2732389657337535, S = 0.7629571166913552, norm_err = 5.4e-06
# Current memory usage 220.5 MB, time elapsed: 49.2 s
# Delta E = 2.0691e-12, Delta S = -3.7914e-06 (per sweep)
# max_trunc_err = 3.4088e-08, max_E_trunc = 2.1255e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 790, age = 9560
# Energy = -1.2732389657512613, S = 0.7629935720255611, norm_err = 7.5e-06
# Current memory usage 220.5 MB, time elapsed: 49.7 s
# Delta E = -1.7508e-12, Delta S = 3.6455e-06 (per sweep)
# max_trunc_err = 3.4077e-08, max_E_trunc = 2.1248e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 800, age = 9680
# Energy = -1.2732389657232943, S = 0.7629527862626442, norm_err = 5.6e-06
# Current memory usage 220.5 MB, time elapsed: 50.2 s
# Delta E = 2.7967e-12, Delta S = -4.0786e-06 (per sweep)
# max_trunc_err = 3.4090e-08, max_E_trunc = 2.1257e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 810, age = 9800
# Energy = -1.2732389657458043, S = 0.7629943397382841, norm_err = 7.9e-06
# Current memory usage 220.5 MB, time elapsed: 50.8 s
# Delta E = -2.2510e-12, Delta S = 4.1553e-06 (per sweep)
# max_trunc_err = 3.4077e-08, max_E_trunc = 2.1248e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 820, age = 9920
# Energy = -1.2732389657210206, S = 0.7629495564347717, norm_err = 5.7e-06
# Current memory usage 220.5 MB, time elapsed: 51.3 s
# Delta E = 2.4784e-12, Delta S = -4.4783e-06 (per sweep)
# max_trunc_err = 3.4093e-08, max_E_trunc = 2.1257e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 830, age = 10040
# Energy = -1.2732389657437579, S = 0.7629962382313559, norm_err = 8.2e-06
# Current memory usage 220.5 MB, time elapsed: 51.8 s
# Delta E = -2.2737e-12, Delta S = 4.6682e-06 (per sweep)
# max_trunc_err = 3.4078e-08, max_E_trunc = 2.1250e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 840, age = 10160
# Energy = -1.2732389657139720, S = 0.7629466382014540, norm_err = 5.8e-06
# Current memory usage 220.5 MB, time elapsed: 52.3 s
# Delta E = 2.9786e-12, Delta S = -4.9600e-06 (per sweep)
# max_trunc_err = 3.4095e-08, max_E_trunc = 2.1259e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 850, age = 10280
# Energy = -1.2732389657394378, S = 0.7629987752777219, norm_err = 8.4e-06
# Current memory usage 220.5 MB, time elapsed: 52.8 s
# Delta E = -2.5466e-12, Delta S = 5.2137e-06 (per sweep)
# max_trunc_err = 3.4078e-08, max_E_trunc = 2.1249e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 860, age = 10400
# Energy = -1.2732389657073782, S = 0.7629436458312754, norm_err = 5.7e-06
# Current memory usage 220.5 MB, time elapsed: 53.3 s
# Delta E = 3.2060e-12, Delta S = -5.5129e-06 (per sweep)
# max_trunc_err = 3.4097e-08, max_E_trunc = 2.1259e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 870, age = 10520
# Energy = -1.2732389657339809, S = 0.7630017347004524, norm_err = 8.6e-06
# Current memory usage 220.5 MB, time elapsed: 53.8 s
# Delta E = -2.6603e-12, Delta S = 5.8089e-06 (per sweep)
# max_trunc_err = 3.4077e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 880, age = 10640
# Energy = -1.2732389656989653, S = 0.7629403819993039, norm_err = 5.6e-06
# Current memory usage 220.5 MB, time elapsed: 54.3 s
# Delta E = 3.5016e-12, Delta S = -6.1353e-06 (per sweep)
# max_trunc_err = 3.4099e-08, max_E_trunc = 2.1261e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 890, age = 10760
# Energy = -1.2732389657294334, S = 0.7630050438203518, norm_err = 8.9e-06
# Current memory usage 220.5 MB, time elapsed: 54.8 s
# Delta E = -3.0468e-12, Delta S = 6.4662e-06 (per sweep)
# max_trunc_err = 3.4077e-08, max_E_trunc = 2.1248e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 900, age = 10880
# Energy = -1.2732389656912346, S = 0.7629367457456664, norm_err = 5.6e-06
# Current memory usage 220.5 MB, time elapsed: 55.3 s
# Delta E = 3.8199e-12, Delta S = -6.8298e-06 (per sweep)
# max_trunc_err = 3.4101e-08, max_E_trunc = 2.1262e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 910, age = 11000
# Energy = -1.2732389657239764, S = 0.7630086912517532, norm_err = 9.1e-06
# Current memory usage 220.5 MB, time elapsed: 55.8 s
# Delta E = -3.2742e-12, Delta S = 7.1946e-06 (per sweep)
# max_trunc_err = 3.4076e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 920, age = 11120
# Energy = -1.2732389656787291, S = 0.7629326692159208, norm_err = 5.5e-06
# Current memory usage 220.5 MB, time elapsed: 56.3 s
# Delta E = 4.5247e-12, Delta S = -7.6022e-06 (per sweep)
# max_trunc_err = 3.4103e-08, max_E_trunc = 2.1264e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 930, age = 11240
# Energy = -1.2732389657153362, S = 0.7630126957152378, norm_err = 9.4e-06
# Current memory usage 220.5 MB, time elapsed: 56.8 s
# Delta E = -3.6607e-12, Delta S = 8.0026e-06 (per sweep)
# max_trunc_err = 3.4075e-08, max_E_trunc = 2.1246e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 940, age = 11360
# Energy = -1.2732389656659961, S = 0.7629280978332021, norm_err = 5.4e-06
# Current memory usage 220.5 MB, time elapsed: 57.3 s
# Delta E = 4.9340e-12, Delta S = -8.4598e-06 (per sweep)
# max_trunc_err = 3.4105e-08, max_E_trunc = 2.1266e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 950, age = 11480
# Energy = -1.2732389657048770, S = 0.7630170850360531, norm_err = 9.7e-06
# Current memory usage 220.5 MB, time elapsed: 57.8 s
# Delta E = -3.8881e-12, Delta S = 8.8987e-06 (per sweep)
# max_trunc_err = 3.4075e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 960, age = 11600
# Energy = -1.2732389656509895, S = 0.7629229766153071, norm_err = 5.3e-06
# Current memory usage 220.5 MB, time elapsed: 58.3 s
# Delta E = 5.3888e-12, Delta S = -9.4108e-06 (per sweep)
# max_trunc_err = 3.4108e-08, max_E_trunc = 2.1267e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 970, age = 11720
# Energy = -1.2732389656898704, S = 0.7630218927812633, norm_err = 1.0e-05
# Current memory usage 220.5 MB, time elapsed: 58.8 s
# Delta E = -3.8881e-12, Delta S = 9.8916e-06 (per sweep)
# max_trunc_err = 3.4074e-08, max_E_trunc = 2.1247e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 980, age = 11840
# Energy = -1.2732389656325722, S = 0.7629172538108216, norm_err = 5.2e-06
# Current memory usage 220.5 MB, time elapsed: 59.4 s
# Delta E = 5.7298e-12, Delta S = -1.0464e-05 (per sweep)
# max_trunc_err = 3.4111e-08, max_E_trunc = 2.1269e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 990, age = 11960
# Energy = -1.2732389656732721, S = 0.7630271554988620, norm_err = 1.0e-05
# Current memory usage 220.5 MB, time elapsed: 59.9 s
# Delta E = -4.0700e-12, Delta S = 1.0990e-05 (per sweep)
# max_trunc_err = 3.4073e-08, max_E_trunc = 2.1245e-07
# MPS bond dimensions: [16, 16]
# Updating environment
# .....
# ================================================================================
# sweep 1000, age = 12080
# Energy = -1.2732389656093801, S = 0.7629108666296570, norm_err = 5.1e-06
# Current memory usage 220.5 MB, time elapsed: 60.4 s
# Delta E = 6.3892e-12, Delta S = -1.1629e-05 (per sweep)
# max_trunc_err = 3.4115e-08, max_E_trunc = 2.1270e-07
# MPS bond dimensions: [16, 16]
# ================================================================================
# DMRG finished after 1000 sweeps.
# total size = 12080, maximum chi = 16
# ================================================================================
# Before the canonicalization:
# Bond dim =  [16, 16]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.000000007638741+0j)
# After the canonicalization:
# Bond dim =  [16, 16]
# Computing properties
# Optimizing
# Loop for chi=16 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  22
#
# Initial sweeps...
# Updating environment
# ..........
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 200
# Energy = -1.2732388766038270, S = nan, norm_err = 5.3e-04
# Current memory usage 220.5 MB, time elapsed: 1.6 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.0955e-08, max_E_trunc = 6.9615e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 320
# Energy = -1.2732391549906126, S = nan, norm_err = 3.3e-04
# Current memory usage 220.5 MB, time elapsed: 3.1 s
# Delta E = -2.7839e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.1029e-08, max_E_trunc = 6.9668e-08
# MPS bond dimensions: [22, 22]
# disable mixer after 30 sweeps, final amplitude 4.21e-08
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 440
# Energy = -1.2732392278783635, S = 0.7681182586310779, norm_err = 2.2e-04
# Current memory usage 220.5 MB, time elapsed: 4.4 s
# Delta E = -7.2888e-09, Delta S = nan (per sweep)
# max_trunc_err = 1.8817e-08, max_E_trunc = 6.3011e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 560
# Energy = -1.2732392776958221, S = 0.7739707069763749, norm_err = 6.9e-05
# Current memory usage 220.5 MB, time elapsed: 5.4 s
# Delta E = -4.9817e-09, Delta S = 5.8524e-04 (per sweep)
# max_trunc_err = 8.9905e-09, max_E_trunc = 6.0562e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 50, age = 680
# Energy = -1.2732393141058509, S = 0.7799546143098386, norm_err = 1.0e-04
# Current memory usage 220.5 MB, time elapsed: 6.4 s
# Delta E = -3.6410e-09, Delta S = 5.9839e-04 (per sweep)
# max_trunc_err = 8.8745e-09, max_E_trunc = 6.0153e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 60, age = 800
# Energy = -1.2732393334456447, S = 0.7828228813943057, norm_err = 1.5e-05
# Current memory usage 220.5 MB, time elapsed: 7.0 s
# Delta E = -1.9340e-09, Delta S = 2.8683e-04 (per sweep)
# max_trunc_err = 8.9796e-09, max_E_trunc = 6.1094e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 70, age = 920
# Energy = -1.2732393146617653, S = 0.7870879011111270, norm_err = 8.2e-05
# Current memory usage 220.5 MB, time elapsed: 8.0 s
# Delta E = 1.8784e-09, Delta S = 4.2650e-04 (per sweep)
# max_trunc_err = 9.4827e-09, max_E_trunc = 6.4277e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 80, age = 1040
# Energy = -1.2732393332902348, S = 0.7902544098661737, norm_err = 5.8e-05
# Current memory usage 220.5 MB, time elapsed: 9.0 s
# Delta E = -1.8628e-09, Delta S = 3.1665e-04 (per sweep)
# max_trunc_err = 9.8475e-09, max_E_trunc = 6.6692e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 90, age = 1160
# Energy = -1.2732393266543625, S = 0.7918086394515265, norm_err = 5.5e-05
# Current memory usage 220.5 MB, time elapsed: 10.0 s
# Delta E = 6.6359e-10, Delta S = 1.5542e-04 (per sweep)
# max_trunc_err = 1.0142e-08, max_E_trunc = 6.8639e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 100, age = 1280
# Energy = -1.2732393270462978, S = 0.7935956255968357, norm_err = 3.8e-05
# Current memory usage 220.5 MB, time elapsed: 11.1 s
# Delta E = -3.9194e-11, Delta S = 1.7870e-04 (per sweep)
# max_trunc_err = 1.0424e-08, max_E_trunc = 7.0501e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 110, age = 1400
# Energy = -1.2732393427356214, S = 0.7957599980135118, norm_err = 7.5e-05
# Current memory usage 220.5 MB, time elapsed: 11.6 s
# Delta E = -1.5689e-09, Delta S = 2.1644e-04 (per sweep)
# max_trunc_err = 1.0320e-08, max_E_trunc = 7.0062e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 120, age = 1520
# Energy = -1.2732393297750377, S = 0.7961106869086035, norm_err = 4.8e-05
# Current memory usage 220.5 MB, time elapsed: 12.7 s
# Delta E = 1.2961e-09, Delta S = 3.5069e-05 (per sweep)
# max_trunc_err = 1.0710e-08, max_E_trunc = 7.2395e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 130, age = 1640
# Energy = -1.2732393435600784, S = 0.7965563872455855, norm_err = 3.2e-05
# Current memory usage 220.5 MB, time elapsed: 13.2 s
# Delta E = -1.3785e-09, Delta S = 4.4570e-05 (per sweep)
# max_trunc_err = 1.0674e-08, max_E_trunc = 7.2388e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 140, age = 1760
# Energy = -1.2732393236101984, S = 0.7979745524683859, norm_err = 4.4e-05
# Current memory usage 220.5 MB, time elapsed: 14.3 s
# Delta E = 1.9950e-09, Delta S = 1.4182e-04 (per sweep)
# max_trunc_err = 1.1024e-08, max_E_trunc = 7.4456e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 150, age = 1880
# Energy = -1.2732393439805492, S = 0.7991218505157356, norm_err = 5.7e-05
# Current memory usage 220.5 MB, time elapsed: 14.8 s
# Delta E = -2.0370e-09, Delta S = 1.1473e-04 (per sweep)
# max_trunc_err = 1.0834e-08, max_E_trunc = 7.3449e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 160, age = 2000
# Energy = -1.2732393235405652, S = 0.7991441855449641, norm_err = 4.4e-05
# Current memory usage 220.5 MB, time elapsed: 15.9 s
# Delta E = 2.0440e-09, Delta S = 2.2335e-06 (per sweep)
# max_trunc_err = 1.1171e-08, max_E_trunc = 7.5427e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 170, age = 2120
# Energy = -1.2732393432862068, S = 0.8003807993726008, norm_err = 7.6e-05
# Current memory usage 220.5 MB, time elapsed: 16.4 s
# Delta E = -1.9746e-09, Delta S = 1.2366e-04 (per sweep)
# max_trunc_err = 1.0961e-08, max_E_trunc = 7.4284e-08
# MPS bond dimensions: [22, 22]
# Updating environment
# .....
# ================================================================================
# sweep 180, age = 2240
# Energy = -1.2732393224227394, S = 0.7999064108903919, norm_err = 4.6e-05
# Current memory usage 220.5 MB, time elapsed: 17.5 s
# ...
# Energy = -1.2732395415439441, S = 0.9339077447644251, norm_err = 6.9e-06
# Current memory usage 220.5 MB, time elapsed: 126.7 s
# Delta E = -7.0258e-12, Delta S = 1.3648e-04 (per sweep)
# max_trunc_err = 1.0302e-11, max_E_trunc = 8.1855e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 630, age = 7640
# Energy = -1.2732395416594500, S = 0.9354334422503825, norm_err = 9.8e-06
# Current memory usage 220.5 MB, time elapsed: 128.9 s
# Delta E = -1.1551e-11, Delta S = 1.5257e-04 (per sweep)
# max_trunc_err = 1.0599e-11, max_E_trunc = 7.8217e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 640, age = 7760
# Energy = -1.2732395417378939, S = 0.9371242053241942, norm_err = 2.8e-05
# Current memory usage 220.5 MB, time elapsed: 131.0 s
# Delta E = -7.8444e-12, Delta S = 1.6908e-04 (per sweep)
# max_trunc_err = 1.0868e-11, max_E_trunc = 8.9130e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 650, age = 7880
# Energy = -1.2732395418486249, S = 0.9381155078072486, norm_err = 1.6e-05
# Current memory usage 220.5 MB, time elapsed: 133.2 s
# Delta E = -1.1073e-11, Delta S = 9.9130e-05 (per sweep)
# max_trunc_err = 1.1169e-11, max_E_trunc = 7.6398e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 660, age = 8000
# Energy = -1.2732395412822370, S = 0.9408353021250391, norm_err = 7.7e-05
# Current memory usage 220.5 MB, time elapsed: 135.0 s
# Delta E = 5.6639e-11, Delta S = 2.7198e-04 (per sweep)
# max_trunc_err = 1.1708e-11, max_E_trunc = 7.2760e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 670, age = 8120
# Energy = -1.2732395419457134, S = 0.9414240159429976, norm_err = 5.3e-05
# Current memory usage 220.5 MB, time elapsed: 137.5 s
# Delta E = -6.6348e-11, Delta S = 5.8871e-05 (per sweep)
# max_trunc_err = 1.1855e-11, max_E_trunc = 7.6398e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 680, age = 8240
# Energy = -1.2732395420598550, S = 0.9423076732362758, norm_err = 3.4e-05
# Current memory usage 220.5 MB, time elapsed: 139.8 s
# Delta E = -1.1414e-11, Delta S = 8.8366e-05 (per sweep)
# max_trunc_err = 1.2158e-11, max_E_trunc = 7.2760e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 690, age = 8360
# Energy = -1.2732395421076035, S = 0.9431456714465676, norm_err = 1.1e-05
# Current memory usage 220.5 MB, time elapsed: 142.0 s
# Delta E = -4.7748e-12, Delta S = 8.3800e-05 (per sweep)
# max_trunc_err = 1.2337e-11, max_E_trunc = 9.0949e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 700, age = 8480
# Energy = -1.2732395421774072, S = 0.9446873507078537, norm_err = 1.7e-05
# Current memory usage 220.5 MB, time elapsed: 144.2 s
# Delta E = -6.9804e-12, Delta S = 1.5417e-04 (per sweep)
# max_trunc_err = 1.2644e-11, max_E_trunc = 9.4587e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 710, age = 8600
# Energy = -1.2732395422881382, S = 0.9458090329934601, norm_err = 1.5e-05
# Current memory usage 220.5 MB, time elapsed: 146.0 s
# Delta E = -1.1073e-11, Delta S = 1.1217e-04 (per sweep)
# max_trunc_err = 1.2890e-11, max_E_trunc = 8.1855e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 720, age = 8720
# Energy = -1.2732395423547587, S = 0.9468623016851201, norm_err = 1.6e-05
# Current memory usage 220.5 MB, time elapsed: 147.0 s
# Delta E = -6.6620e-12, Delta S = 1.0533e-04 (per sweep)
# max_trunc_err = 1.2317e-11, max_E_trunc = 9.4587e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 730, age = 8840
# Energy = -1.2732395424100105, S = 0.9481014608020882, norm_err = 1.8e-05
# Current memory usage 220.5 MB, time elapsed: 148.0 s
# Delta E = -5.5252e-12, Delta S = 1.2392e-04 (per sweep)
# max_trunc_err = 1.2414e-11, max_E_trunc = 8.9130e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 740, age = 8960
# Energy = -1.2732395424663991, S = 0.9493363400067552, norm_err = 2.0e-05
# Current memory usage 220.5 MB, time elapsed: 148.9 s
# Delta E = -5.6389e-12, Delta S = 1.2349e-04 (per sweep)
# max_trunc_err = 1.2629e-11, max_E_trunc = 9.0949e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 750, age = 9080
# Energy = -1.2732395425230152, S = 0.9504389111991364, norm_err = 1.4e-05
# Current memory usage 220.5 MB, time elapsed: 149.8 s
# Delta E = -5.6616e-12, Delta S = 1.1026e-04 (per sweep)
# max_trunc_err = 1.2856e-11, max_E_trunc = 9.6406e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 760, age = 9200
# Energy = -1.2732395425707637, S = 0.9514126454490486, norm_err = 1.4e-05
# Current memory usage 220.5 MB, time elapsed: 150.8 s
# Delta E = -4.7748e-12, Delta S = 9.7373e-05 (per sweep)
# max_trunc_err = 1.3116e-11, max_E_trunc = 1.0004e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 770, age = 9320
# Energy = -1.2732395426151015, S = 0.9524445262307377, norm_err = 1.0e-05
# Current memory usage 220.5 MB, time elapsed: 152.3 s
# Delta E = -4.4338e-12, Delta S = 1.0319e-04 (per sweep)
# max_trunc_err = 1.3416e-11, max_E_trunc = 9.6406e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 780, age = 9440
# Energy = -1.2732395421653564, S = 0.9536214231057846, norm_err = 5.0e-05
# Current memory usage 220.5 MB, time elapsed: 154.3 s
# Delta E = 4.4975e-11, Delta S = 1.1769e-04 (per sweep)
# max_trunc_err = 1.3727e-11, max_E_trunc = 9.4587e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 790, age = 9560
# Energy = -1.2732395426844505, S = 0.9546107183618762, norm_err = 1.8e-05
# Current memory usage 220.5 MB, time elapsed: 156.8 s
# Delta E = -5.1909e-11, Delta S = 9.8930e-05 (per sweep)
# max_trunc_err = 1.4194e-11, max_E_trunc = 9.6406e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 800, age = 9680
# Energy = -1.2732395427447045, S = 0.9555582988207784, norm_err = 9.0e-06
# Current memory usage 220.5 MB, time elapsed: 158.7 s
# Delta E = -6.0254e-12, Delta S = 9.4758e-05 (per sweep)
# max_trunc_err = 1.4234e-11, max_E_trunc = 1.0004e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 810, age = 9800
# Energy = -1.2732395427754000, S = 0.9571286149262055, norm_err = 3.1e-05
# Current memory usage 220.5 MB, time elapsed: 160.7 s
# Delta E = -3.0695e-12, Delta S = 1.5703e-04 (per sweep)
# max_trunc_err = 1.4772e-11, max_E_trunc = 1.0914e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 820, age = 9920
# Energy = -1.2732395428160999, S = 0.9578387603674732, norm_err = 2.7e-05
# Current memory usage 220.5 MB, time elapsed: 163.1 s
# Delta E = -4.0700e-12, Delta S = 7.1015e-05 (per sweep)
# max_trunc_err = 1.5000e-11, max_E_trunc = 1.0186e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 830, age = 10040
# Energy = -1.2732395428583914, S = 0.9589771345189935, norm_err = 2.4e-05
# Current memory usage 220.5 MB, time elapsed: 164.9 s
# Delta E = -4.2292e-12, Delta S = 1.1384e-04 (per sweep)
# max_trunc_err = 1.4980e-11, max_E_trunc = 1.1460e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 840, age = 10160
# Energy = -1.2732395428597556, S = 0.9599554397793146, norm_err = 3.8e-05
# Current memory usage 220.5 MB, time elapsed: 167.2 s
# Delta E = -1.3642e-13, Delta S = 9.7831e-05 (per sweep)
# max_trunc_err = 1.5582e-11, max_E_trunc = 1.1096e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 850, age = 10280
# Energy = -1.2732395428774907, S = 0.9601075925735549, norm_err = 8.9e-06
# Current memory usage 220.5 MB, time elapsed: 169.5 s
# Delta E = -1.7735e-12, Delta S = 1.5215e-05 (per sweep)
# max_trunc_err = 1.5707e-11, max_E_trunc = 1.0186e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 860, age = 10400
# Energy = -1.2732395429279677, S = 0.9619142987233249, norm_err = 2.8e-05
# Current memory usage 220.5 MB, time elapsed: 171.8 s
# Delta E = -5.0477e-12, Delta S = 1.8067e-04 (per sweep)
# max_trunc_err = 1.5927e-11, max_E_trunc = 1.0914e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 870, age = 10520
# Energy = -1.2732395429716235, S = 0.9620057049234723, norm_err = 4.9e-06
# Current memory usage 220.5 MB, time elapsed: 174.1 s
# Delta E = -4.3656e-12, Delta S = 9.1406e-06 (per sweep)
# max_trunc_err = 1.6080e-11, max_E_trunc = 1.0732e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 880, age = 10640
# Energy = -1.2732395429536609, S = 0.9638580556402148, norm_err = 3.6e-05
# Current memory usage 220.5 MB, time elapsed: 176.3 s
# Delta E = 1.7963e-12, Delta S = 1.8524e-04 (per sweep)
# max_trunc_err = 1.6296e-11, max_E_trunc = 1.1278e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 890, age = 10760
# Energy = -1.2732395430243741, S = 0.9637257847393917, norm_err = 8.7e-06
# Current memory usage 220.5 MB, time elapsed: 178.5 s
# Delta E = -7.0713e-12, Delta S = -1.3227e-05 (per sweep)
# max_trunc_err = 1.6519e-11, max_E_trunc = 1.1823e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 900, age = 10880
# Energy = -1.2732395430321048, S = 0.9657656900094234, norm_err = 4.2e-05
# Current memory usage 220.5 MB, time elapsed: 180.8 s
# Delta E = -7.7307e-13, Delta S = 2.0399e-04 (per sweep)
# max_trunc_err = 1.6802e-11, max_E_trunc = 1.1823e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 910, age = 11000
# Energy = -1.2732395430552970, S = 0.9653373754569157, norm_err = 1.4e-05
# Current memory usage 220.5 MB, time elapsed: 183.1 s
# Delta E = -2.3192e-12, Delta S = -4.2831e-05 (per sweep)
# max_trunc_err = 1.7094e-11, max_E_trunc = 1.1096e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 920, age = 11120
# Energy = -1.2732395430725774, S = 0.9672072666323850, norm_err = 2.4e-05
# Current memory usage 220.5 MB, time elapsed: 185.5 s
# Delta E = -1.7280e-12, Delta S = 1.8699e-04 (per sweep)
# max_trunc_err = 1.7425e-11, max_E_trunc = 9.4587e-11
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 930, age = 11240
# Energy = -1.2732395431312398, S = 0.9671148447205009, norm_err = 1.1e-05
# Current memory usage 220.5 MB, time elapsed: 187.7 s
# Delta E = -5.8662e-12, Delta S = -9.2422e-06 (per sweep)
# max_trunc_err = 1.7597e-11, max_E_trunc = 1.1823e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 940, age = 11360
# Energy = -1.2732395430653014, S = 0.9690909103604530, norm_err = 3.8e-05
# Current memory usage 220.5 MB, time elapsed: 189.9 s
# Delta E = 6.5938e-12, Delta S = 1.9761e-04 (per sweep)
# max_trunc_err = 1.7815e-11, max_E_trunc = 1.2915e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 950, age = 11480
# Energy = -1.2732395431469286, S = 0.9689382760726571, norm_err = 4.6e-06
# Current memory usage 220.5 MB, time elapsed: 192.3 s
# Delta E = -8.1627e-12, Delta S = -1.5263e-05 (per sweep)
# max_trunc_err = 1.8035e-11, max_E_trunc = 1.4370e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 960, age = 11600
# Energy = -1.2732395431112309, S = 0.9707116158114433, norm_err = 4.0e-05
# Current memory usage 220.5 MB, time elapsed: 194.4 s
# Delta E = 3.5698e-12, Delta S = 1.7733e-04 (per sweep)
# max_trunc_err = 1.8211e-11, max_E_trunc = 1.2005e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 970, age = 11720
# Energy = -1.2732395431917212, S = 0.9707453476666683, norm_err = 1.8e-05
# Current memory usage 220.5 MB, time elapsed: 196.7 s
# Delta E = -8.0490e-12, Delta S = 3.3732e-06 (per sweep)
# max_trunc_err = 1.8607e-11, max_E_trunc = 1.3097e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 980, age = 11840
# Energy = -1.2732395423422531, S = 0.9713490223216116, norm_err = 8.6e-05
# Current memory usage 220.5 MB, time elapsed: 198.3 s
# Delta E = 8.4947e-11, Delta S = 6.0367e-05 (per sweep)
# max_trunc_err = 1.8758e-11, max_E_trunc = 1.3279e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 990, age = 11960
# Energy = -1.2732395432190060, S = 0.9726218672308746, norm_err = 3.1e-05
# Current memory usage 220.5 MB, time elapsed: 200.8 s
# Delta E = -8.7675e-11, Delta S = 1.2728e-04 (per sweep)
# max_trunc_err = 1.9386e-11, max_E_trunc = 1.3097e-10
# MPS bond dimensions: [90, 90]
# Updating environment
# .....
# ================================================================================
# sweep 1000, age = 12080
# Energy = -1.2732395432917656, S = 0.9728576837553062, norm_err = 5.9e-06
# Current memory usage 220.5 MB, time elapsed: 203.0 s
# Delta E = -7.2760e-12, Delta S = 2.3582e-05 (per sweep)
# max_trunc_err = 1.9197e-11, max_E_trunc = 1.3097e-10
# MPS bond dimensions: [90, 90]
# ================================================================================
# DMRG finished after 1000 sweeps.
# total size = 12080, maximum chi = 90
# ================================================================================
# Before the canonicalization:
# Bond dim =  [90, 90]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (0.999999935068037+0j)
# After the canonicalization:
# Bond dim =  [90, 90]
# Computing properties
# Optimizing
# Loop for chi=90 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================

# %%
plot_results(data
            )
