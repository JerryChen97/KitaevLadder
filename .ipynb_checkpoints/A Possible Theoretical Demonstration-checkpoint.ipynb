# %% [markdown]
# # Finite-Length Kitaev Ladder SVD

# %% [markdown]
# According to some analytic paper, in the Kitaev ladder, the local operator `d`'s should be all good quantum numbers and also commute with each other, and therefore they are acting like some kind of gauge symmetry; furthermore, it is totally fine to randomly fix the gauage and make use of a single gauge fixing to derive a global phase diagram.
#
# However, it is not straight forward that local gauge symmetry has to be randomly fixable. If two operators `A` and `B` are commutable with each other, the only conclusion we can get is that the eigenstates `v` of `A` in the same eigenvalues `k` will remain the same eigenvalues after acted by `B`, i.e. `Av = kv => ABv = BAv = Bkv = kBv = k(Bv)`. Generally, we can only see that commutable operator will not transform the eigenstates out side of its previous energy sector; in particular, a ground state will not be excited by a commutable operator, but we are never sure whether or not it is also an eigenstate of this operator.
#
# However, the random choice of gauge fixing implies that for a Kitaev ladder of length `L` (we define the width of a Kitaev ladder to be `2`), there will be `2^L` ground states. We can reasonably guess that this is again based on the assumption that each ground state must be the eigenstate of each local operator.
#
# The result of gauge fixing shows discrepencies with our iDMRG simulation results, and two papers choosing two different fixing present discrepencies with each other. On this observation, we can cautiously believe that, their random gauge fixing choices are not so proper as they guessed; at least, their gauge fixing cannot be applied to the global phase diagram of Kitaev ladders.
#
# But to demonstrate that they are kind of wrong is difficult: after JW transformation and Majorana transformation, the Hamiltonian has changed a lot and is no longer the same as before. This causes problems when we want to decide how to design the explicit matrix formula. To escape from such difficulty, we can consider count the degeneracy of ground states, i.e. the dimension of the ground state space.

# %% [markdown]
# ## Import

# %%
import numpy as np
from numpy.random import rand

import scipy.sparse as sparse
import scipy.sparse.linalg.eigen.arpack as arp
import warnings
import scipy.integrate

from kitaev_ladder import KitaevLadderModel, fDMRG_KL, run_atomic
from tenpy.algorithms.exact_diag import ExactDiag

# %% [markdown]
# ## Using TeNPy Interfaces

# %%
L=3
Jx=1
Jy=1
Jz=1
bc_MPS='finite'
bc='open'
order='default'
verbose=1

model_params = dict(L=L, Jx=Jx, Jy=Jy, Jz=Jz, bc_MPS=bc_MPS, bc=bc, conserve=None, order=order, verbose=verbose)
M = KitaevLadderModel(model_params)
M.bc = 'finite'
ExactDiag.from_H_mpo(M)
# Out:
# Reading 'L'=3 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=1 for config KitaevLadderModel
# Reading 'Jz'=1 for config KitaevLadderModel
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-0b59ef8e0035> in <module>
#      11 M = KitaevLadderModel(model_params)
#      12 M.bc = 'finite'
# ---> 13 ExactDiag.from_H_mpo(M)
#
# ~/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/exact_diag.py in from_H_mpo(cls, H_MPO, *args, **kwargs)
#     116         from ..models.lattice import TrivialLattice
#     117         assert H_MPO.bc == 'finite'
# --> 118         M = MPOModel(TrivialLattice(H_MPO.sites), H_MPO)
#     119         return cls(M, *args, **kwargs)
#     120
#
# AttributeError: 'KitaevLadderModel' object has no attribute 'sites'

# %% [markdown]
# The interface provided by TeNPy just doesn't work = =.

# %% [markdown]
# ## Brute-force Matrix Construction & Diagonalization

# %%
# parameter setting
L = 3 # here the L is the number of unit cells
J = 1
g = 1

# %% [markdown]
# ### An Ising Demo

# %% [markdown]
# Here is an example code from the official documentation of `TeNPy`.

# %%
# get single site operaors
sx = sparse.csr_matrix(np.array([[0., 1.], [1., 0.]]))
sz = sparse.csr_matrix(np.array([[1., 0.], [0., -1.]]))
id = sparse.csr_matrix(np.eye(2))
sx_list = []  # sx_list[i] = kron([id, id, ..., id, sx, id, .... id])
sz_list = []
for i_site in range(L):
    x_ops = [id] * L
    z_ops = [id] * L
    x_ops[i_site] = sx
    z_ops[i_site] = sz
    X = x_ops[0]
    Z = z_ops[0]
    for j in range(1, L):
        X = sparse.kron(X, x_ops[j], 'csr')
        Z = sparse.kron(Z, z_ops[j], 'csr')
    sx_list.append(X)
    sz_list.append(Z)
H_xx = sparse.csr_matrix((2**L, 2**L))
H_z = sparse.csr_matrix((2**L, 2**L))
for i in range(L - 1):
    H_xx = H_xx + sx_list[i] * sx_list[(i + 1) % L]
for i in range(L):
    H_z = H_z + sz_list[i]
H = -J * H_xx - g * H_z
E, V = arp.eigsh(H, k=1, which='SA', return_eigenvectors=True, ncv=20)
print(E)
# Out:
# [-3.49395921]

# %% [markdown]
# Well it seems quite tedious and not straightforward to me.
#
# We will implement the ED in our own way and demonstrate it to be consistent with `TeNPy`'s code.

# %% [markdown]
# ### Change to Kitaev Ladder

# %%
# get single site operaors
sx = sparse.csr_matrix(np.array([[0., 1.], [1., 0.]]))
sy = sparse.csc_matrix(np.array([[0., -1.0j], [1.0j, 0.]]))
sz = sparse.csr_matrix(np.array([[1., 0.], [0., -1.]]))
id = sparse.csr_matrix(np.eye(2))
sigma_list = [id, sx, sy, sz]

def Sigma(op_num, site, L=12):
    assert op_num==0 or op_num==1 or op_num==2 or op_num==3
    assert site>=0 and site<L
    
    op = sigma_list[op_num]
    
    if site==0:
        return sparse.kron(op, sparse.csr_matrix(np.eye(2**(L-1))))
    elif site==L-1:
        return sparse.kron(sparse.csr_matrix(np.eye(2**(L-1))), op)
    else: 
        IA = sparse.kron(sparse.csr_matrix(np.eye(2**(site))), op)
        return sparse.kron(IA, sparse.csr_matrix(np.eye(2**(L-1-site))))

# %%
# parameter setting
unit_number = 3
unit_size = 4
L = unit_number * unit_size
Jx = 1
Jy = 1
Jz = 1

# %%
# test the complex number operation
1j * 1j
# Out:
# (-1+0j)

# %%
def exact_diagonalization_Kitaev_Ladder(Jx=1, Jy=1, Jz=1, unit_number=3, k=100, bc='open'):

    # parameter setting
    unit_number = 3
    unit_size = 4
    L = unit_number * unit_size

    H_xx = sparse.csr_matrix((2**L, 2**L))
    for i in range(L//2 - 1):
        site1 = 2*i + 1
        site2 = site1+1

        op_num = 1 # 1 represents x

    #     print("i = ", i)
        X1 = Sigma(op_num, site1, L=L)
        X2 = Sigma(op_num, site2, L=L)
        H_xx += X1.dot(X2)

        pass

    H_yy = sparse.csr_matrix((2**L, 2**L))
    for i in range(L//2 - 1):
        site1 = 2*i
        site2 = site1 +3

        op_num = 2
        Y1 = Sigma(op_num, site1, L=L)
        Y2 = Sigma(op_num, site2, L=L)
        H_yy += Y1.dot(Y2)

        pass
    
    if bc=='periodic':
        XN = Sigma(1, L-1, L=L)
#         ...,
#         [-0.0073223 +0.00444902j, -0.00218396+0.01659749j,
#          -0.01547625+0.00632194j, ...,  0.01343748-0.00641763j,
#           0.00596308-0.00201608j, -0.00983343+0.01600727j],
#         [ 0.0041728 +0.01613045j, -0.01155775-0.01054187j,
#          -0.00403941-0.00514057j, ..., -0.02132276+0.00239676j,
#          -0.01611359-0.01212355j,  0.01391377-0.01429841j],
#         [-0.00303507+0.02098658j, -0.00176563+0.00990708j,
#           0.00405289+0.01183658j, ...,  0.00472742+0.00695045j,
#           0.02229955+0.01372116j, -0.01640691-0.00095495j]]))

# %% [markdown]
# ### Back to check the consistency with Ising

# %%
# parameter setting
L = 3
Jx = 1
g = 1

H_xx = sparse.csr_matrix((2**L, 2**L))
for i in range(L - 1):
    site1 = i
    site2 = i+1
    
    op_num = 1 # 1 represents x
    
#     print("i = ", i)
    X1 = Sigma(op_num, site1, L=L)
    X2 = Sigma(op_num, site2, L=L)
    H_xx += X1.dot(X2)
    
    pass

H_z = sparse.csr_matrix((2**L, 2**L))
for i in range(L):
    site1 = i
    
    op_num = 3
    Z1 = Sigma(op_num, site1, L=L)
    H_z += Z1
    
    pass

H = -Jx * H_xx - g * H_z
E, V = arp.eigsh(H, k=1, which='SA')

print(np.sort(E))
# Out:
# [-3.49395921]

# %% [markdown]
# Correct!

# %% [markdown]
# However, this can only show that our implementation of Python code is consistent with Ising model; still we don't know whether or not it is consistent with our Kitaev ladder.
#
# Let's do the fDMRG to convince ourselves.

# %% [markdown]
# ### Finite DMRG

# %%
fDMRG_KL(chi=200)
# Out:
# finite DMRG, Kitaev ladder model
# L = 3, Jx = 1.00, Jy = 1.00, Jz = 1.00,
# Reading 'L'=3 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1.0 for config KitaevLadderModel
# Reading 'Jy'=1.0 for config KitaevLadderModel
# Reading 'Jz'=1.0 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 12
# Energy = -2.3769020374912664, S = nan, norm_err = 4.0e-14
# Current memory usage 224.9 MB, time elapsed: 2.5 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.4333e-20, max_E_trunc = 3.1086e-15
# MPS bond dimensions: [2, 4, 8, 12, 20, 24, 18, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 12
# Energy = -2.3769020374912637, S = nan, norm_err = 7.7e-14
# Current memory usage 225.2 MB, time elapsed: 4.8 s
# Delta E = 2.6645e-16, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.3413e-20, max_E_trunc = 2.2204e-15
# MPS bond dimensions: [2, 4, 8, 12, 20, 24, 19, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 12
# Energy = -2.3769020374912633, S = 1.1140193918446757, norm_err = 3.6e-14
# Current memory usage 225.2 MB, time elapsed: 5.9 s
# Delta E = 4.4409e-17, Delta S = nan (per sweep)
# max_trunc_err = 8.6278e-32, max_E_trunc = 2.2204e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 12
# Energy = -2.3769020374912624, S = 1.1140193918446757, norm_err = 4.0e-14
# Current memory usage 225.2 MB, time elapsed: 7.0 s
# Delta E = 8.8818e-17, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 7.8082e-32, max_E_trunc = 3.1086e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 12, maximum chi = 16
# ================================================================================
# E = -2.3769020374913
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
#         -8.03351475, -8.03351475, -8.03351475, -8.03351475, -7.99666854]),
#  array([[ 7.28290512e-03+1.47707471e-03j, -5.12779189e-04+3.10096803e-03j,
#          -6.70667810e-16-8.78155692e-17j, ...,
#           3.20089211e-17+2.18977438e-17j,  2.01139058e-17+4.12286585e-17j,
#           5.82927351e-17-2.56175985e-17j],
#         [ 4.59589604e-17-1.18870844e-17j,  4.27773471e-17-6.54096505e-17j,
#          -1.06968475e-16-4.33695662e-17j, ...,
#          -2.44563765e-03+5.39004853e-03j, -4.20384622e-03+5.84576615e-03j,
#          -1.79292082e-15-1.22802867e-15j],
#         [-6.80250051e-18-1.43004456e-17j,  5.05003087e-17+2.30682582e-17j,
#           8.87046739e-17-7.35433207e-17j, ...,
#          -1.31675970e-02-1.21258877e-03j,  1.29265909e-03-3.08637502e-03j,
#          -2.25906112e-15+1.14548207e-15j],
#         ...,
#         [ 1.79697094e-18+8.01435751e-18j, -4.10957817e-17-1.72562884e-18j,
#          -9.93180724e-17+1.06735113e-16j, ...,
#          -1.31675970e-02-1.21258877e-03j,  1.29265909e-03-3.08637502e-03j,
#          -2.18611354e-15+1.30286364e-15j],
#         [ 1.77558542e-17+2.50238192e-17j, -1.39893383e-16+2.14322996e-18j,
#          -1.58557885e-16+9.63697243e-18j, ...,
#           2.44563765e-03-5.39004853e-03j,  4.20384622e-03-5.84576615e-03j,
#           1.73377211e-15+1.19585081e-15j],
#         [-7.28290512e-03-1.47707471e-03j,  5.12779189e-04-3.10096803e-03j,
#           6.43779552e-16+1.04221012e-16j, ...,
#           3.24272465e-17+2.36875750e-17j,  2.68129821e-17+1.64784951e-18j,
#          -2.20729003e-19-6.70015680e-18j]]))

# %%
9.50760815/2.3769020374912624
# Out:
# 4.000000000014704

# %% [markdown]
# Maybe TeNPy returns the energy divided by the site number in one single unitcell?

# %%
Jx = np.random.rand()
Jy = np.random.rand()
Jz = np.random.rand()
L = 3

E, psi, M = fDMRG_KL(Jx=Jx, Jy=Jy, Jz=Jz, L=L)
Energies, Vectors = exact_diagonalization_Kitaev_Ladder(Jx=Jx, Jy=Jy, Jz=Jz, unit_number=L)

print(f'The difference between fDMRG and ED for J = ({Jx}, {Jy}, {Jz}) is E_fDMRG - E_ED = {E*4 - Energies[0]}')
# Out:
# finite DMRG, Kitaev ladder model
# L = 3, Jx = 0.25, Jy = 0.60, Jz = 0.95,
# Reading 'L'=3 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=0.2476925437078228 for config KitaevLadderModel
# Reading 'Jy'=0.5968215051620674 for config KitaevLadderModel
# Reading 'Jz'=0.9491845079109834 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 12
# Energy = -1.6390532327636469, S = nan, norm_err = 5.9e-12
# Current memory usage 228.5 MB, time elapsed: 2.5 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.3236e-20, max_E_trunc = 2.6645e-15
# MPS bond dimensions: [2, 4, 8, 10, 19, 24, 19, 11, 8, 4, 2]
# ================================================================================
# sweep 20, age = 12
# Energy = -1.6390532327636429, S = nan, norm_err = 2.1e-13
# Current memory usage 228.5 MB, time elapsed: 5.4 s
# Delta E = 3.9968e-16, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.5449e-20, max_E_trunc = 2.2204e-15
# MPS bond dimensions: [2, 4, 8, 12, 19, 25, 18, 11, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 12
# Energy = -1.6390532327636493, S = 1.0271480763359615, norm_err = 8.2e-14
# Current memory usage 228.5 MB, time elapsed: 6.6 s
# Delta E = -6.4393e-16, Delta S = nan (per sweep)
# max_trunc_err = 8.5724e-32, max_E_trunc = 2.6645e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 12
# Energy = -1.6390532327636460, S = 1.0271480763359613, norm_err = 1.7e-13
# Current memory usage 228.5 MB, time elapsed: 7.7 s
# Delta E = 3.3307e-16, Delta S = -2.2204e-17 (per sweep)
# max_trunc_err = 7.5859e-32, max_E_trunc = 1.5543e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 12, maximum chi = 16
# ================================================================================
# E = -1.6390532327636
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# The 100 lowest energies are:
#  [-6.55621293 -6.55621293 -6.4411306  -6.4411306  -6.4411306  -6.4411306
#  -6.43974621 -6.43974621 -6.42542486 -6.42542486 -6.42542486 -6.42542486
#  -6.32944592 -6.32944592 -6.3129334  -6.3129334  -6.3129334  -6.3129334
#  -6.31027342 -6.31027342 -6.31027342 -6.31027342 -6.30984393 -6.30984393
#  -6.30984393 -6.30984393 -6.29474404 -6.29474404 -6.29311101 -6.29311101
#  -6.29311101 -6.29311101 -6.18607695 -6.18607695 -6.18379562 -6.18379562
#  -6.18379562 -6.18379562 -6.18219007 -6.18219007 -6.18219007 -6.18219007
#  -6.18017715 -6.18017715 -6.16235462 -6.16235462 -6.16235462 -6.16235462
#  -6.16205065 -6.16205065 -6.16205065 -6.16205065 -6.03617475 -6.03617475
#  -6.03617475 -6.03617475 -6.03533027 -6.03533027 -6.03311253 -6.03311253
#  -6.03311253 -6.03311253 -5.88648766 -5.88648766 -5.57163431 -5.57163431
#  -5.57163431 -5.57163431 -5.56723421 -5.56723421 -5.53875321 -5.53875321
#  -5.53875321 -5.53875321 -5.53376512 -5.53376512 -5.53376512 -5.53376512
#  -5.52574881 -5.52574881 -5.52574881 -5.52574881 -5.46395645 -5.46395645
#  -5.45440481 -5.45440481 -5.45440481 -5.45440481 -5.44427374 -5.44427374
#  -5.44427374 -5.44427374 -5.42815241 -5.42815241 -5.42815241 -5.42815241
#  -5.42412632 -5.42412632 -5.42412632 -5.42412632]
# The difference between fDMRG and ED for J = (0.2476925437078228, 0.5968215051620674, 0.9491845079109834) is E_fDMRG - E_ED = 2.9665159217984183e-13

# %% [markdown]
# So we can see that the difference between fDMRG and ED is only `~1e-13`, which means basically this is the machine precision error.
# Therefore, we can reasonably trust the result of fDMRG.

# %%
# Params setting
Jx = 1
Jy = -1
Jz = 1

# Loop control
max_trials = 10
max_E_err = 1e-10

# Stored data
orthogonal_to = []
energy = []

for i in range(max_trials):
    if i > 1: # there are already 2 or more energies
        if energy[i-1] - energy[i-2] > max_E_err:
            break
    
    E, psi, M = fDMRG_KL(Jx=Jx, Jy=Jy, Jz=Jz, L=30, chi=30, orthogonal_to=orthogonal_to)
    energy.append(E)
    orthogonal_to.append(psi.copy())
    
    pass

print("Energy list : ", energy)
# Out:
# finite DMRG, Kitaev ladder model
# L = 30, Jx = 1.00, Jy = -1.00, Jz = 1.00,
# Reading 'L'=30 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=-1 for config KitaevLadderModel
# Reading 'Jz'=1 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 120
# Energy = -25.0245350434565559, S = nan, norm_err = 9.3e-08
# Current memory usage 483.3 MB, time elapsed: 43.6 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.9519e-10, max_E_trunc = 6.8779e-10
# MPS bond dimensions: [2, 4, 8, 12, 18, 26, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 26, 21, 14, 8, 4, 2]
# ================================================================================
# sweep 20, age = 120
# Energy = -25.0245350457947886, S = nan, norm_err = 8.2e-08
# Current memory usage 483.3 MB, time elapsed: 79.8 s
# Delta E = -2.3382e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.2190e-10, max_E_trunc = 6.5275e-10
# MPS bond dimensions: [2, 4, 8, 12, 19, 25, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 27, 21, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 120
# Energy = -25.0245350480291293, S = 1.2131131710273917, norm_err = 7.9e-08
# Current memory usage 483.3 MB, time elapsed: 102.7 s
# Delta E = -2.2343e-10, Delta S = nan (per sweep)
# max_trunc_err = 2.0008e-10, max_E_trunc = 5.4689e-10
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 120
# Energy = -25.0245350480573023, S = 1.2131131711434298, norm_err = 7.9e-08
# Current memory usage 483.3 MB, time elapsed: 125.6 s
# Delta E = -2.8173e-12, Delta S = 1.1604e-11 (per sweep)
# max_trunc_err = 2.0005e-10, max_E_trunc = 5.4659e-10
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 16, 16, 8, 8, 4, 2]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 120, maximum chi = 30
# ================================================================================
# E = -25.0245350480573
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 30, Jx = 1.00, Jy = -1.00, Jz = 1.00,
# Reading 'L'=30 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=-1 for config KitaevLadderModel
# Reading 'Jz'=1 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe9ba941f90>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 120
# Energy = -25.0245350434609257, S = nan, norm_err = 9.6e-08
# Current memory usage 483.3 MB, time elapsed: 56.7 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.9511e-10, max_E_trunc = 6.8770e-10
# MPS bond dimensions: [2, 4, 8, 12, 19, 24, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 23, 19, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 120
# Energy = -25.0245350467500209, S = nan, norm_err = 6.4e-08
# Current memory usage 483.3 MB, time elapsed: 101.9 s
# Delta E = -3.2891e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.1281e-10, max_E_trunc = 6.6148e-10
# MPS bond dimensions: [2, 4, 8, 13, 21, 28, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 24, 19, 11, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 120
# Energy = -25.0245350479270101, S = 1.2131131708262752, norm_err = 6.8e-08
# Current memory usage 483.3 MB, time elapsed: 134.0 s
# Delta E = -1.1770e-10, Delta S = nan (per sweep)
# max_trunc_err = 2.0016e-10, max_E_trunc = 5.4663e-10
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 120
# Energy = -25.0245350481217912, S = 1.2131131715904644, norm_err = 7.4e-08
# Current memory usage 483.3 MB, time elapsed: 165.9 s
# Delta E = -1.9478e-11, Delta S = 7.6419e-11 (per sweep)
# max_trunc_err = 2.0071e-10, max_E_trunc = 5.5032e-10
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 16, 16, 8, 8, 4, 2]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 120, maximum chi = 30
# ================================================================================
# E = -25.0245350481218
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 30, Jx = 1.00, Jy = -1.00, Jz = 1.00,
# Reading 'L'=30 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=-1 for config KitaevLadderModel
# Reading 'Jz'=1 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe9ba941f90>, <tenpy.networks.mps.MPS object at 0x7fe9a75d88d0>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 120
# Energy = -24.9353108421720968, S = nan, norm_err = 2.4e-06
# Current memory usage 483.3 MB, time elapsed: 65.0 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.1509e-09, max_E_trunc = 1.5189e-09
# MPS bond dimensions: [2, 4, 8, 10, 19, 27, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 25, 19, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 120
# Energy = -24.9353103403990666, S = nan, norm_err = 3.6e-04
# Current memory usage 483.3 MB, time elapsed: 115.5 s
# Delta E = 5.0177e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 8.9696e-10, max_E_trunc = 1.1381e-09
# MPS bond dimensions: [2, 4, 8, 11, 18, 26, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 25, 21, 13, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 120
# Energy = -24.9352611273055871, S = 1.2143971339690502, norm_err = 4.1e-03
# Current memory usage 483.3 MB, time elapsed: 152.8 s
# Delta E = 4.9213e-06, Delta S = nan (per sweep)
# max_trunc_err = 4.2269e-10, max_E_trunc = 1.1301e-09
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 24, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 120
# Energy = -24.9352695885033597, S = 1.2143971665799258, norm_err = 3.3e-03
# Current memory usage 483.3 MB, time elapsed: 190.6 s
# Delta E = -8.4612e-07, Delta S = 3.2611e-09 (per sweep)
# max_trunc_err = 4.2189e-10, max_E_trunc = 1.1274e-09
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 22, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 120
# Energy = -24.9351036479603110, S = 1.2143971595393872, norm_err = 7.3e-03
# Current memory usage 483.3 MB, time elapsed: 228.3 s
# Delta E = 1.6594e-05, Delta S = -7.0405e-10 (per sweep)
# max_trunc_err = 4.2242e-10, max_E_trunc = 1.1271e-09
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 20, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=7.29e-03
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 120, maximum chi = 30
# ================================================================================
# E = -24.9351036479603
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 20, 16, 8, 8, 4, 2]
# Energy list :  [-25.024535048057302, -25.02453504812179, -24.93510364796031]

# %%
# Params setting
Jx = 1
Jy = -1
Jz = 1

# Loop control
max_trials = 10
max_E_err = 1e-10

# Stored data
orthogonal_to = []
energy = []

for i in range(max_trials):
    if i > 1: # there are already 2 or more energies
        if energy[i-1] - energy[i-2] > max_E_err:
            break
    
    E, psi, M = fDMRG_KL(Jx=Jx, Jy=Jy, Jz=Jz, L=30, chi=30, orthogonal_to=orthogonal_to)
    energy.append(E)
    orthogonal_to.append(psi.copy())
    
    pass

print("Energy list : ", energy)

# %%
exact_diagonalization_Kitaev_Ladder(Jx=Jx, Jy=Jy, Jz=Jz, unit_number=3)
# Out:
# The 100 lowest energies are:
#  [-9.50760815 -9.50760815 -9.15624404 -9.15624404 -9.15624404 -9.15624404
#  -9.0609573  -9.0609573  -8.92666333 -8.92666333 -8.92666333 -8.92666333
#  -8.9031713  -8.9031713  -8.80415181 -8.80415181 -8.80415181 -8.80415181
#  -8.71547245 -8.71547245 -8.71547245 -8.71547245 -8.69413703 -8.69413703
#  -8.69413703 -8.69413703 -8.67978022 -8.67978022 -8.64095298 -8.64095298
#  -8.64095298 -8.64095298 -8.5394743  -8.5394743  -8.5394743  -8.5394743
#  -8.5359875  -8.5359875  -8.5359875  -8.5359875  -8.49852706 -8.49852706
#  -8.49852706 -8.49852706 -8.43472094 -8.43472094 -8.43472094 -8.43472094
#  -8.40868717 -8.40868717 -8.36636459 -8.36636459 -8.36375738 -8.36375738
#  -8.36375738 -8.36375738 -8.31391071 -8.31391071 -8.31391071 -8.31391071
#  -8.30494151 -8.30494151 -8.30494151 -8.30494151 -8.29465105 -8.29465105
#  -8.29465105 -8.29465105 -8.28543917 -8.28543917 -8.28543917 -8.28543917
#  -8.26399295 -8.26399295 -8.19012984 -8.19012984 -8.19012984 -8.19012984
#  -8.18799635 -8.18799635 -8.18028074 -8.18028074 -8.18028074 -8.18028074
#  -8.10168506 -8.10168506 -8.10168506 -8.10168506 -8.09783468 -8.09783468
#  -8.03351475 -8.03351475 -8.03351475 -8.03351475 -7.99666854 -7.99666854
#  -7.99666854 -7.99666854 -7.98518751 -7.98518751]
# (array([-9.50760815, -9.50760815, -9.0609573 , -9.15624404, -9.15624404,
#         -9.0609573 , -8.92666333, -9.15624404, -9.15624404, -8.80415181,
-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 12
# Energy = -3.8920083075132434, S = 1.3511881007213979, norm_err = 1.6e-14
# Current memory usage 483.3 MB, time elapsed: 7.9 s
# Delta E = -3.1086e-16, Delta S = -2.2204e-17 (per sweep)
# max_trunc_err = 8.3432e-32, max_E_trunc = 3.1086e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 12, maximum chi = 16
# ================================================================================
# E = -3.8920083075132
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# -15.568033230052974

# %%
E, psi, M = fDMRG_KL(Jx=Jx, Jy=Jy, Jz=Jz, L=L, chi=30, bc='open')
E * 4
# Out:
# finite DMRG, Kitaev ladder model
# L = 3, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=3 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'={} for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 12
# Energy = -3.6104480051164809, S = nan, norm_err = 1.9e-12
# Current memory usage 483.3 MB, time elapsed: 2.8 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.6661e-14, max_E_trunc = 5.3291e-15
# MPS bond dimensions: [2, 4, 8, 13, 21, 24, 18, 11, 8, 4, 2]
# ================================================================================
# sweep 20, age = 12
# Energy = -3.6104480051164733, S = nan, norm_err = 3.7e-13
# Current memory usage 483.3 MB, time elapsed: 5.7 s
# Delta E = 7.5495e-16, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 7.5326e-15, max_E_trunc = 3.9968e-15
# MPS bond dimensions: [2, 4, 8, 13, 19, 21, 18, 11, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 12
# Energy = -3.6104480051164676, S = 1.1395649863940980, norm_err = 5.6e-14
# Current memory usage 483.3 MB, time elapsed: 7.2 s
# Delta E = 5.7732e-16, Delta S = nan (per sweep)
# max_trunc_err = 8.6932e-32, max_E_trunc = 5.3291e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 12
# Energy = -3.6104480051164778, S = 1.1395649863940982, norm_err = 3.6e-14
# Current memory usage 483.3 MB, time elapsed: 8.6 s
# Delta E = -1.0214e-15, Delta S = 2.2204e-17 (per sweep)
# max_trunc_err = 9.9843e-32, max_E_trunc = 4.8850e-15
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 12, maximum chi = 16
# ================================================================================
# E = -3.6104480051165
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 16, 8, 8, 4, 2]
# -14.441792020465911

# %%
# Loop control
max_trials = 10
max_E_err = 1e-10

# Stored data
orthogonal_to = []
energy = []

for i in range(max_trials):
#     if i > 1: # there are already 2 or more energies
#         if energy[i-1] - energy[i-2] > max_E_err:
#             break
    
    E, psi, M = fDMRG_KL(Jx=Jx, Jy=Jy, Jz=Jz, L=60, chi=20, orthogonal_to=orthogonal_to, bc='open')
    energy.append(E)
    orthogonal_to.append(psi.copy())
    
    pass

print("Energy list : ", energy)
# Out:
# finite DMRG, Kitaev ladder model
# L = 60, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=60 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 240
# Energy = -76.6287480854507663, S = nan, norm_err = 1.9e-05
# Current memory usage 483.3 MB, time elapsed: 115.0 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.6694e-07, max_E_trunc = 8.0063e-07
# MPS bond dimensions: [2, 4, 8, 11, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 11, 8, 4, 2]
# ================================================================================
# sweep 20, age = 240
# Energy = -76.6287482117203211, S = nan, norm_err = 2.0e-05
# Current memory usage 483.3 MB, time elapsed: 182.6 s
# Delta E = -1.2627e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4840e-07, max_E_trunc = 7.9479e-07
# MPS bond dimensions: [2, 4, 8, 12, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 11, 8, 4, 2]
# ================================================================================
# sweep 30, age = 240
# Energy = -76.6287482050908579, S = nan, norm_err = 2.0e-05
# Current memory usage 483.3 MB, time elapsed: 250.3 s
# Delta E = 6.6295e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4645e-07, max_E_trunc = 7.9491e-07
# MPS bond dimensions: [2, 4, 8, 12, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 13, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 40, age = 240
# Energy = -76.6287482035905043, S = 1.2698273760400547, norm_err = 2.0e-05
# Current memory usage 483.3 MB, time elapsed: 293.9 s
# Delta E = 1.5004e-10, Delta S = nan (per sweep)
# max_trunc_err = 2.2303e-07, max_E_trunc = 7.9493e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 240
# Energy = -76.6287482032673637, S = 1.2698274032322279, norm_err = 2.0e-05
# Current memory usage 483.3 MB, time elapsed: 336.7 s
# Delta E = 3.2314e-11, Delta S = 2.7192e-09 (per sweep)
# max_trunc_err = 2.2303e-07, max_E_trunc = 7.9493e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=1.98e-05
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 240, maximum chi = 20
# ================================================================================
# E = -76.6287482032674
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 60, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=60 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98aa9afd0>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 240
# Energy = -76.6287480854489047, S = nan, norm_err = 1.9e-05
# Current memory usage 483.3 MB, time elapsed: 151.4 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.6694e-07, max_E_trunc = 8.0063e-07
# MPS bond dimensions: [2, 4, 8, 12, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 240
# Energy = -76.6287482096523718, S = nan, norm_err = 2.0e-05
# Current memory usage 483.3 MB, time elapsed: 237.1 s
# Delta E = -1.2420e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4874e-07, max_E_trunc = 7.9505e-07
# MPS bond dimensions: [2, 4, 8, 11, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# ================================================================================
# sweep 30, age = 240
# Energy = -76.6287482008459335, S = nan, norm_err = 2.0e-05
# Current memory usage 483.3 MB, time elapsed: 322.5 s
# Delta E = 8.8064e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4874e-07, max_E_trunc = 7.9608e-07
# MPS bond dimensions: [2, 4, 8, 12, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 14, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 40, age = 240
# Energy = -76.6287482010106089, S = 1.2698275645992307, norm_err = 2.0e-05
# Current memory usage 483.3 MB, time elapsed: 381.6 s
# Delta E = -1.6468e-11, Delta S = nan (per sweep)
# max_trunc_err = 2.2320e-07, max_E_trunc = 7.9519e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 240
# Energy = -76.6287481993593076, S = 1.2698275687525098, norm_err = 2.0e-05
# Current memory usage 483.3 MB, time elapsed: 440.6 s
# Delta E = 1.6513e-10, Delta S = 4.1533e-10 (per sweep)
# max_trunc_err = 2.2557e-07, max_E_trunc = 7.9864e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=1.98e-05
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 240, maximum chi = 20
# ================================================================================
# E = -76.6287481993593
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 60, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=60 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98aa9afd0>, <tenpy.networks.mps.MPS object at 0x7fe99c110a90>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 240
# Energy = -76.5126800753584035, S = nan, norm_err = 4.5e-05
# Current memory usage 483.3 MB, time elapsed: 169.6 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 8.9992e-07, max_E_trunc = 1.8292e-06
# MPS bond dimensions: [2, 4, 8, 14, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 240
# Energy = -76.5126802566646660, S = nan, norm_err = 4.4e-03
# Current memory usage 483.3 MB, time elapsed: 266.1 s
# Delta E = -1.8131e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 8.9720e-07, max_E_trunc = 1.8263e-06
# MPS bond dimensions: [2, 4, 8, 11, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 13, 8, 4, 2]
# ================================================================================
# sweep 30, age = 240
# Energy = -76.5126799703556344, S = nan, norm_err = 3.5e-03
# Current memory usage 483.3 MB, time elapsed: 362.9 s
# Delta E = 2.8631e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 8.9619e-07, max_E_trunc = 1.8255e-06
# MPS bond dimensions: [2, 4, 8, 11, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 13, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 40, age = 240
# Energy = -76.5126802149451066, S = 1.2722223437240125, norm_err = 1.9e-02
# Current memory usage 483.3 MB, time elapsed: 432.6 s
# Delta E = -2.4459e-08, Delta S = nan (per sweep)
# max_trunc_err = 4.4848e-07, max_E_trunc = 1.8262e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 240
# Energy = -76.5126654377627489, S = 1.2722189858144217, norm_err = 3.0e-02
# Current memory usage 483.3 MB, time elapsed: 503.6 s
# Delta E = 1.4777e-06, Delta S = -3.3579e-07 (per sweep)
# max_trunc_err = 4.4838e-07, max_E_trunc = 1.8277e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=3.05e-02
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 240, maximum chi = 20
# ================================================================================
# E = -76.5126654377627
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 60, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=60 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98aa9afd0>, <tenpy.networks.mps.MPS object at 0x7fe99c110a90>, <tenpy.networks.mps.MPS object at 0x7fe99c7c38d0>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 240
# Energy = -76.5130135745831836, S = nan, norm_err = 1.8e-02
# Current memory usage 483.3 MB, time elapsed: 194.4 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 2.0693e-06, max_E_trunc = 2.8874e-06
# MPS bond dimensions: [2, 4, 8, 12, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 13, 8, 4, 2]
# ================================================================================
# sweep 20, age = 240
# Energy = -76.5131233549503236, S = nan, norm_err = 3.1e-04
# Current memory usage 483.3 MB, time elapsed: 303.8 s
# Delta E = -1.0978e-05, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.3964e-06, max_E_trunc = 2.7324e-06
# MPS bond dimensions: [2, 4, 8, 10, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 13, 8, 4, 2]
# ================================================================================
# sweep 30, age = 240
# Energy = -76.5125801350971670, S = nan, norm_err = 1.6e-02
# Current memory usage 483.3 MB, time elapsed: 414.4 s
# Delta E = 5.4322e-05, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 5.1417e-06, max_E_trunc = 2.7078e-06
# MPS bond dimensions: [2, 4, 8, 11, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 10, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 40, age = 240
# Energy = -76.5131235823325966, S = 1.2727336740845336, norm_err = 1.1e-04
# Current memory usage 483.3 MB, time elapsed: 497.1 s
# Delta E = -5.4345e-05, Delta S = nan (per sweep)
# max_trunc_err = 6.9736e-07, max_E_trunc = 2.7333e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 240
# Energy = -76.5131230076303979, S = 1.2727362608178920, norm_err = 2.4e-03
# Current memory usage 483.3 MB, time elapsed: 581.6 s
# Delta E = 5.7470e-08, Delta S = 2.5867e-07 (per sweep)
# max_trunc_err = 6.9781e-07, max_E_trunc = 2.7336e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=2.38e-03
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 240, maximum chi = 20
# ================================================================================
# E = -76.5131230076304
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 60, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=60 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98aa9afd0>, <tenpy.networks.mps.MPS object at 0x7fe99c110a90>, <tenpy.networks.mps.MPS object at 0x7fe99c7c38d0>, <tenpy.networks.mps.MPS object at 0x7fe99c22b0d0>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 240
# Energy = -76.5134196584327668, S = nan, norm_err = 1.8e-04
# Current memory usage 483.3 MB, time elapsed: 216.4 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.6283e-06, max_E_trunc = 3.1147e-06
# MPS bond dimensions: [2, 4, 8, 13, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 13, 8, 4, 2]
# ================================================================================
# sweep 20, age = 240
# Energy = -76.5134197248254395, S = nan, norm_err = 1.8e-04
# Current memory usage 483.3 MB, time elapsed: 335.7 s
# Delta E = -6.6393e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.6129e-06, max_E_trunc = 3.1077e-06
# MPS bond dimensions: [2, 4, 8, 12, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 240
# Energy = -76.5134197838172554, S = 1.2730536062995430, norm_err = 2.7e-05
# Current memory usage 483.3 MB, time elapsed: 427.0 s
# Delta E = -5.8992e-09, Delta S = nan (per sweep)
# max_trunc_err = 8.0615e-07, max_E_trunc = 3.1088e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 240
# Energy = -76.5134196012343182, S = 1.2730526831894808, norm_err = 1.6e-04
# Current memory usage 483.3 MB, time elapsed: 519.8 s
# Delta E = 1.8258e-08, Delta S = -9.2311e-08 (per sweep)
# max_trunc_err = 8.0544e-07, max_E_trunc = 3.1077e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=1.57e-04
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 240, maximum chi = 20
# ================================================================================
# E = -76.5134196012343
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 60, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=60 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98aa9afd0>, <tenpy.networks.mps.MPS object at 0x7fe99c110a90>, <tenpy.networks.mps.MPS object at 0x7fe99c7c38d0>, <tenpy.networks.mps.MPS object at 0x7fe99c22b0d0>, <tenpy.networks.mps.MPS object at 0x7fe99c1a8290>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 240
# Energy = -76.5134193595891077, S = nan, norm_err = 1.5e-02
# Current memory usage 483.3 MB, time elapsed: 178.9 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.6362e-06, max_E_trunc = 3.1174e-06
# MPS bond dimensions: [2, 4, 8, 13, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 240
# Energy = -76.5133844490586057, S = nan, norm_err = 9.3e-04
# Current memory usage 483.3 MB, time elapsed: 308.7 s
# Delta E = 3.4911e-06, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 5.1392e-06, max_E_trunc = 5.1765e-06
# MPS bond dimensions: [2, 4, 8, 12, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 11, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 240
# Energy = -76.5134176108950612, S = 1.2730669985361989, norm_err = 1.3e-03
# Current memory usage 483.3 MB, time elapsed: 412.9 s
# Delta E = -3.3162e-06, Delta S = nan (per sweep)
# max_trunc_err = 8.0511e-07, max_E_trunc = 3.1070e-06
# ...
# Current memory usage 483.3 MB, time elapsed: 1111.8 s
# Delta E = -6.4591e-07, Delta S = 1.1100e-06 (per sweep)
# max_trunc_err = 1.6158e-06, max_E_trunc = 5.0727e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 80, age = 240
# Energy = -76.5134095607927947, S = 1.2729145178833363, norm_err = 7.4e-05
# Current memory usage 483.3 MB, time elapsed: 1250.5 s
# Delta E = -1.3946e-08, Delta S = -8.0581e-08 (per sweep)
# max_trunc_err = 1.6318e-06, max_E_trunc = 5.0623e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 90, age = 240
# Energy = -76.5134097974492278, S = 1.2729124742468136, norm_err = 4.1e-05
# Current memory usage 483.3 MB, time elapsed: 1389.3 s
# Delta E = -2.3666e-08, Delta S = -2.0436e-07 (per sweep)
# max_trunc_err = 1.6090e-06, max_E_trunc = 5.0029e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 100, age = 240
# Energy = -76.5134066704966216, S = 1.2729176262420974, norm_err = 4.6e-04
# Current memory usage 483.3 MB, time elapsed: 1527.3 s
# Delta E = 3.1270e-07, Delta S = 5.1520e-07 (per sweep)
# max_trunc_err = 1.9833e-06, max_E_trunc = 4.8963e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=4.57e-04
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 100 sweeps.
# total size = 240, maximum chi = 20
# ================================================================================
# E = -76.5134066704966
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 60, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=60 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98aa9afd0>, <tenpy.networks.mps.MPS object at 0x7fe99c110a90>, <tenpy.networks.mps.MPS object at 0x7fe99c7c38d0>, <tenpy.networks.mps.MPS object at 0x7fe99c22b0d0>, <tenpy.networks.mps.MPS object at 0x7fe99c1a8290>, <tenpy.networks.mps.MPS object at 0x7fe98a89e790>, <tenpy.networks.mps.MPS object at 0x7fe98a8badd0>, <tenpy.networks.mps.MPS object at 0x7fe98b0d3750>, <tenpy.networks.mps.MPS object at 0x7fe98a913810>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 240
# Energy = -76.3974485975275002, S = nan, norm_err = 3.5e-03
# Current memory usage 483.3 MB, time elapsed: 276.5 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.3427e-05, max_E_trunc = 2.2201e-05
# MPS bond dimensions: [2, 4, 8, 12, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 240
# Energy = -76.3974491783955330, S = nan, norm_err = 6.0e-05
# Current memory usage 483.3 MB, time elapsed: 444.9 s
# Delta E = -5.8087e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.2783e-05, max_E_trunc = 2.1497e-05
# MPS bond dimensions: [2, 4, 8, 14, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 11, 8, 4, 2]
# ================================================================================
# sweep 30, age = 240
# Energy = -76.3974495080445450, S = nan, norm_err = 8.0e-05
# Current memory usage 483.3 MB, time elapsed: 611.2 s
# Delta E = -3.2965e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.2697e-05, max_E_trunc = 2.1982e-05
# MPS bond dimensions: [2, 4, 8, 11, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 11, 8, 4, 2]
# ================================================================================
# sweep 40, age = 240
# Energy = -76.3974497164296764, S = nan, norm_err = 7.4e-05
# Current memory usage 483.3 MB, time elapsed: 776.8 s
# Delta E = -2.0839e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.2633e-05, max_E_trunc = 2.1995e-05
# MPS bond dimensions: [2, 4, 8, 13, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 11, 8, 4, 2]
# disable mixer after 50 sweeps, final amplitude 1.10e-08
# ================================================================================
# sweep 50, age = 240
# Energy = -76.3974118589155182, S = nan, norm_err = 5.1e-03
# Current memory usage 483.3 MB, time elapsed: 942.2 s
# Delta E = 3.7858e-06, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.2565e-05, max_E_trunc = 2.1681e-05
# MPS bond dimensions: [2, 4, 8, 12, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 12, 8, 4, 2]
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# norm_tol=1.00e-05 not reached, norm_err=5.12e-03
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 240, maximum chi = 20
# ================================================================================
# E = -76.3974118589155
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 17, 9, 8, 4, 2]
# Energy list :  [-76.62874820326736, -76.62874819935931, -76.51266543776275, -76.5131230076304, -76.51341960123432, -76.51337805321131, -76.51341896160547, -76.51329347066542, -76.51340667049662, -76.39741185891552]

# %%
[e * 4 for e in energy]
# Out:
# [-306.51499281306945,
#  -306.51499279743723,
#  -306.050661751051,
#  -306.0524920305216,
#  -306.0536784049373,
#  -306.05351221284525,
#  -306.05367584642187,
#  -306.05317388266167,
#  -306.0536266819865,
#  -305.5896474356621]

# %%
# Loop control
max_trials = 10
max_E_err = 1e-10

# Stored data
orthogonal_to = []
energy = []

for i in range(max_trials):
#     if i > 1: # there are already 2 or more energies
#         if energy[i-1] - energy[i-2] > max_E_err:
#             break
    
    E, psi, M = fDMRG_KL(Jx=Jx, Jy=Jy, Jz=Jz, L=20, chi=20, orthogonal_to=orthogonal_to, bc='open')
    energy.append(E)
    orthogonal_to.append(psi.copy())
    
    pass

print("Energy list : ", energy)
print("Multiplied by unit size: ", [e*4 for e in energy])
# Out:
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.3875943102507406, S = nan, norm_err = 1.0e-05
# Current memory usage 483.3 MB, time elapsed: 35.1 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.6533e-07, max_E_trunc = 7.9899e-07
# MPS bond dimensions: [2, 4, 8, 11, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.3875943395015469, S = nan, norm_err = 9.9e-06
# Current memory usage 483.3 MB, time elapsed: 57.2 s
# Delta E = -2.9251e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4691e-07, max_E_trunc = 7.9325e-07
# MPS bond dimensions: [2, 4, 8, 13, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 11, 8, 4, 2]
# ================================================================================
# sweep 30, age = 80
# Energy = -25.3875943380875420, S = nan, norm_err = 9.9e-06
# Current memory usage 483.3 MB, time elapsed: 79.2 s
# Delta E = 1.4140e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4496e-07, max_E_trunc = 7.9337e-07
# MPS bond dimensions: [2, 4, 8, 13, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 14, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 40, age = 80
# Energy = -25.3875943377569122, S = 1.2566513133437491, norm_err = 9.9e-06
# Current memory usage 483.3 MB, time elapsed: 93.7 s
# Delta E = 3.3063e-11, Delta S = nan (per sweep)
# max_trunc_err = 2.2229e-07, max_E_trunc = 7.9340e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.3875943374343045, S = 1.2566513956077965, norm_err = 1.0e-05
# Current memory usage 483.3 MB, time elapsed: 107.1 s
# Delta E = 3.2261e-11, Delta S = 8.2264e-09 (per sweep)
# max_trunc_err = 2.2229e-07, max_E_trunc = 7.9340e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.3875943374343
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.3875943102505062, S = nan, norm_err = 1.0e-05
# Current memory usage 483.3 MB, time elapsed: 46.4 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.6533e-07, max_E_trunc = 7.9899e-07
# MPS bond dimensions: [2, 4, 8, 12, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.3875943368821595, S = nan, norm_err = 1.0e-05
# Current memory usage 483.3 MB, time elapsed: 74.7 s
# Delta E = -2.6632e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4791e-07, max_E_trunc = 7.9393e-07
# MPS bond dimensions: [2, 4, 8, 14, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 13, 8, 4, 2]
# ================================================================================
# sweep 30, age = 80
# Energy = -25.3875943353565319, S = nan, norm_err = 1.0e-05
# Current memory usage 483.3 MB, time elapsed: 102.2 s
# Delta E = 1.5256e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4596e-07, max_E_trunc = 7.9405e-07
# MPS bond dimensions: [2, 4, 8, 13, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 40, age = 80
# Energy = -25.3875943352675435, S = 1.2566515904606150, norm_err = 1.0e-05
# Current memory usage 483.3 MB, time elapsed: 120.8 s
# Delta E = 8.8988e-12, Delta S = nan (per sweep)
# max_trunc_err = 2.2279e-07, max_E_trunc = 7.9407e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.3875943333016068, S = 1.2566517043992358, norm_err = 1.0e-05
# Current memory usage 483.3 MB, time elapsed: 139.6 s
# Delta E = 1.9659e-10, Delta S = 1.1394e-08 (per sweep)
# max_trunc_err = 2.2415e-07, max_E_trunc = 7.9613e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=1.02e-05
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.3875943333016
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>, <tenpy.networks.mps.MPS object at 0x7fe98a049390>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.2722109390062712, S = nan, norm_err = 8.4e-05
# Current memory usage 483.3 MB, time elapsed: 54.6 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.5781e-06, max_E_trunc = 3.0330e-06
# MPS bond dimensions: [2, 4, 8, 13, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 13, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.2722005524429036, S = nan, norm_err = 2.2e-03
# Current memory usage 483.3 MB, time elapsed: 85.9 s
# Delta E = 1.0387e-06, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.5636e-06, max_E_trunc = 3.0267e-06
# MPS bond dimensions: [2, 4, 8, 12, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 80
# Energy = -25.2719836124553332, S = 1.2661311065694691, norm_err = 8.8e-03
# Current memory usage 483.3 MB, time elapsed: 108.3 s
# Delta E = 2.1694e-05, Delta S = nan (per sweep)
# max_trunc_err = 7.8121e-07, max_E_trunc = 3.0265e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 80
# Energy = -25.2721820602948775, S = 1.2660802051573705, norm_err = 3.3e-03
# Current memory usage 483.3 MB, time elapsed: 131.2 s
# Delta E = -1.9845e-05, Delta S = -5.0901e-06 (per sweep)
# max_trunc_err = 7.8164e-07, max_E_trunc = 3.0273e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.2722109729390496, S = 1.2661021244500039, norm_err = 1.0e-04
# Current memory usage 483.3 MB, time elapsed: 154.0 s
# Delta E = -2.8913e-06, Delta S = 2.1919e-06 (per sweep)
# max_trunc_err = 7.8173e-07, max_E_trunc = 3.0276e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 60, age = 80
# Energy = -25.2722052978174929, S = 1.2660931759788749, norm_err = 1.6e-03
# Current memory usage 483.3 MB, time elapsed: 176.8 s
# Delta E = 5.6751e-07, Delta S = -8.9485e-07 (per sweep)
# max_trunc_err = 7.8160e-07, max_E_trunc = 3.0272e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=1.57e-03
# ================================================================================
# DMRG finished after 60 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.2722052978175
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>, <tenpy.networks.mps.MPS object at 0x7fe98a049390>, <tenpy.networks.mps.MPS object at 0x7fe9a7582190>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.2787487424446802, S = nan, norm_err = 1.1e-05
# Current memory usage 483.3 MB, time elapsed: 57.9 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 6.9055e-07, max_E_trunc = 1.0378e-06
# MPS bond dimensions: [2, 4, 8, 13, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.2787360883860295, S = nan, norm_err = 3.4e-03
# Current memory usage 483.3 MB, time elapsed: 94.3 s
# Delta E = 1.2654e-06, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 6.3198e-07, max_E_trunc = 1.0247e-06
# MPS bond dimensions: [2, 4, 8, 12, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 80
# Energy = -25.2780503006358153, S = 1.2620512509650479, norm_err = 2.0e-02
# Current memory usage 483.3 MB, time elapsed: 121.6 s
# Delta E = 6.8579e-05, Delta S = nan (per sweep)
# max_trunc_err = 3.2905e-07, max_E_trunc = 1.0280e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 80
# Energy = -25.2787413787495296, S = 1.2620087092897925, norm_err = 1.8e-03
# Current memory usage 483.3 MB, time elapsed: 149.1 s
# Delta E = -6.9108e-05, Delta S = -4.2542e-06 (per sweep)
# max_trunc_err = 3.3286e-07, max_E_trunc = 1.0333e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.2787467395217682, S = 1.2620126432172742, norm_err = 6.3e-04
# Current memory usage 483.3 MB, time elapsed: 176.3 s
# Delta E = -5.3608e-07, Delta S = 3.9339e-07 (per sweep)
# max_trunc_err = 3.1362e-07, max_E_trunc = 1.0250e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 60, age = 80
# Energy = -25.2787448608185521, S = 1.2620051108933237, norm_err = 1.0e-03
# Current memory usage 483.3 MB, time elapsed: 203.5 s
# Delta E = 1.8787e-07, Delta S = -7.5323e-07 (per sweep)
# max_trunc_err = 3.2043e-07, max_E_trunc = 1.0171e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=1.04e-03
# ================================================================================
# DMRG finished after 60 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.2787448608186
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>, <tenpy.networks.mps.MPS object at 0x7fe98a049390>, <tenpy.networks.mps.MPS object at 0x7fe9a7582190>, <tenpy.networks.mps.MPS object at 0x7fe98a663490>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.2716340903532419, S = nan, norm_err = 7.4e-05
# Current memory usage 483.3 MB, time elapsed: 70.6 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.2009e-06, max_E_trunc = 2.3816e-06
# MPS bond dimensions: [2, 4, 8, 13, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.2716340821136605, S = nan, norm_err = 1.1e-04
# Current memory usage 483.3 MB, time elapsed: 113.7 s
# Delta E = 8.2396e-10, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.1964e-06, max_E_trunc = 2.3774e-06
# MPS bond dimensions: [2, 4, 8, 11, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 11, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 80
# Energy = -25.2716340153353691, S = 1.2648404869375498, norm_err = 2.1e-04
# Current memory usage 483.3 MB, time elapsed: 146.4 s
# Delta E = 6.6778e-09, Delta S = nan (per sweep)
# max_trunc_err = 5.9814e-07, max_E_trunc = 2.3790e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 80
# Energy = -25.2716341187524343, S = 1.2648399272217210, norm_err = 3.4e-05
# Current memory usage 483.3 MB, time elapsed: 179.3 s
# Delta E = -1.0342e-08, Delta S = -5.5972e-08 (per sweep)
# max_trunc_err = 5.9803e-07, max_E_trunc = 2.3785e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.2716339395902629, S = 1.2648150908705802, norm_err = 2.6e-03
# Current memory usage 483.3 MB, time elapsed: 212.6 s
# Delta E = 1.7916e-08, Delta S = -2.4836e-06 (per sweep)
# max_trunc_err = 5.9660e-07, max_E_trunc = 2.3736e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=2.57e-03
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.2716339395903
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>, <tenpy.networks.mps.MPS object at 0x7fe98a049390>, <tenpy.networks.mps.MPS object at 0x7fe9a7582190>, <tenpy.networks.mps.MPS object at 0x7fe98a663490>, <tenpy.networks.mps.MPS object at 0x7fe9d5e64410>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.2722409625823587, S = nan, norm_err = 2.8e-03
# Current memory usage 483.3 MB, time elapsed: 88.0 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 3.1689e-06, max_E_trunc = 3.1017e-06
# MPS bond dimensions: [2, 4, 8, 14, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 13, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.2722413728454924, S = nan, norm_err = 2.3e-04
# Current memory usage 483.3 MB, time elapsed: 133.1 s
# Delta E = -4.1026e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.5817e-06, max_E_trunc = 3.0630e-06
# MPS bond dimensions: [2, 4, 8, 12, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 12, 8, 4, 2]
# ================================================================================
# sweep 30, age = 80
# Energy = -25.2722417769063021, S = nan, norm_err = 3.1e-04
# Current memory usage 483.3 MB, time elapsed: 179.1 s
# Delta E = -4.0406e-08, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.6030e-06, max_E_trunc = 3.0948e-06
# MPS bond dimensions: [2, 4, 8, 11, 17, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 11, 8, 4, 2]
# ================================================================================
# sweep 40, age = 80
# Energy = -25.2722373750256466, S = nan, norm_err = 4.7e-04
# Current memory usage 483.3 MB, time elapsed: 224.9 s
# Delta E = 4.4019e-07, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 3.7834e-06, max_E_trunc = 3.0952e-06
# MPS bond dimensions: [2, 4, 8, 11, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 50, age = 80
# Energy = -25.2722358734775376, S = 1.2662674766760815, norm_err = 2.1e-04
# Current memory usage 483.3 MB, time elapsed: 260.5 s
# Delta E = 1.5015e-07, Delta S = nan (per sweep)
# max_trunc_err = 8.2689e-07, max_E_trunc = 3.0947e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 60, age = 80
# Energy = -25.2722419351331453, S = 1.2662371171218973, norm_err = 1.3e-04
# Current memory usage 483.3 MB, time elapsed: 297.6 s
# Delta E = -6.0617e-07, Delta S = -3.0360e-06 (per sweep)
# max_trunc_err = 8.0109e-07, max_E_trunc = 3.0946e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 70, age = 80
# Energy = -25.2722418307455250, S = 1.2662387315887946, norm_err = 6.6e-05
# Current memory usage 483.3 MB, time elapsed: 334.7 s
# Delta E = 1.0439e-08, Delta S = 1.6145e-07 (per sweep)
# max_trunc_err = 8.0140e-07, max_E_trunc = 3.0950e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=6.57e-05
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 70 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.2722418307455
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>, <tenpy.networks.mps.MPS object at 0x7fe98a049390>, <tenpy.networks.mps.MPS object at 0x7fe9a7582190>, <tenpy.networks.mps.MPS object at 0x7fe98a663490>, <tenpy.networks.mps.MPS object at 0x7fe9d5e64410>, <tenpy.networks.mps.MPS object at 0x7fe98b735e10>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.2716340119539993, S = nan, norm_err = 2.1e-04
# Current memory usage 483.3 MB, time elapsed: 81.9 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.4896e-06, max_E_trunc = 2.9022e-06
# MPS bond dimensions: [2, 4, 8, 12, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 17, 11, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.2716315873721200, S = nan, norm_err = 1.1e-03
# Current memory usage 483.3 MB, time elapsed: 130.6 s
# Delta E = 2.4246e-07, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.4798e-06, max_E_trunc = 2.8942e-06
# MPS bond dimensions: [2, 4, 8, 14, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 80
# Energy = -25.2713097261799255, S = 1.2647177549982589, norm_err = 1.3e-02
# Current memory usage 483.3 MB, time elapsed: 170.4 s
# Delta E = 3.2186e-05, Delta S = nan (per sweep)
# max_trunc_err = 7.4024e-07, max_E_trunc = 2.8992e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 80
# Energy = -25.2714297300001824, S = 1.2647248831696123, norm_err = 1.2e-02
# Current memory usage 483.3 MB, time elapsed: 211.1 s
# Delta E = -1.2000e-05, Delta S = 7.1282e-07 (per sweep)
# max_trunc_err = 7.4020e-07, max_E_trunc = 2.8994e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.2716307313412045, S = 1.2647430013295375, norm_err = 1.1e-03
# Current memory usage 483.3 MB, time elapsed: 252.1 s
# Delta E = -2.0100e-05, Delta S = 1.8118e-06 (per sweep)
# max_trunc_err = 7.4016e-07, max_E_trunc = 2.8992e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 60, age = 80
# Energy = -25.2716311500551001, S = 1.2647416141408081, norm_err = 7.9e-04
# Current memory usage 483.3 MB, time elapsed: 292.4 s
# Delta E = -4.1871e-08, Delta S = -1.3872e-07 (per sweep)
# max_trunc_err = 7.4008e-07, max_E_trunc = 2.8990e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 70, age = 80
# Energy = -25.2704383005883457, S = 1.2647861253577450, norm_err = 2.6e-02
# Current memory usage 483.3 MB, time elapsed: 333.1 s
# Delta E = 1.1928e-04, Delta S = 4.4511e-06 (per sweep)
# max_trunc_err = 8.8723e-07, max_E_trunc = 2.8989e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=2.64e-02
# ================================================================================
# DMRG finished after 70 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.2704383005883
# final bond dimensions:  [2, 4, 8, 8, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>, <tenpy.networks.mps.MPS object at 0x7fe98a049390>, <tenpy.networks.mps.MPS object at 0x7fe9a7582190>, <tenpy.networks.mps.MPS object at 0x7fe98a663490>, <tenpy.networks.mps.MPS object at 0x7fe9d5e64410>, <tenpy.networks.mps.MPS object at 0x7fe98b735e10>, <tenpy.networks.mps.MPS object at 0x7fe99e084310>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.2716339965137848, S = nan, norm_err = 1.1e-04
# Current memory usage 483.3 MB, time elapsed: 97.8 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.2005e-06, max_E_trunc = 2.3809e-06
# MPS bond dimensions: [2, 4, 8, 13, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 11, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.2716326121972408, S = nan, norm_err = 8.4e-04
# Current memory usage 483.3 MB, time elapsed: 154.2 s
# Delta E = 1.3843e-07, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.1956e-06, max_E_trunc = 2.3770e-06
# MPS bond dimensions: [2, 4, 8, 12, 18, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 80
# Energy = -25.2715176522824194, S = 1.2647486230287031, norm_err = 5.6e-03
# Current memory usage 483.3 MB, time elapsed: 201.3 s
# Delta E = 1.1496e-05, Delta S = nan (per sweep)
# max_trunc_err = 1.1556e-06, max_E_trunc = 2.3800e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 80
# Energy = -25.2716316067638438, S = 1.2648085598070382, norm_err = 1.9e-03
# Current memory usage 483.3 MB, time elapsed: 247.7 s
# Delta E = -1.1395e-05, Delta S = 5.9937e-06 (per sweep)
# max_trunc_err = 5.9789e-07, max_E_trunc = 2.3778e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.2629705051097808, S = 1.2647692274206941, norm_err = 6.0e-02
# Current memory usage 483.3 MB, time elapsed: 295.3 s
# Delta E = 8.6611e-04, Delta S = -3.9332e-06 (per sweep)
# max_trunc_err = 6.4291e-07, max_E_trunc = 2.3770e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=6.03e-02
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.2629705051098
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>, <tenpy.networks.mps.MPS object at 0x7fe98a049390>, <tenpy.networks.mps.MPS object at 0x7fe9a7582190>, <tenpy.networks.mps.MPS object at 0x7fe98a663490>, <tenpy.networks.mps.MPS object at 0x7fe9d5e64410>, <tenpy.networks.mps.MPS object at 0x7fe98b735e10>, <tenpy.networks.mps.MPS object at 0x7fe99e084310>, <tenpy.networks.mps.MPS object at 0x7fe98b779890>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.1555461387818760, S = nan, norm_err = 2.1e-02
# Current memory usage 483.3 MB, time elapsed: 114.0 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 8.2213e-06, max_E_trunc = 8.1776e-06
# MPS bond dimensions: [2, 4, 8, 13, 17, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.1543923133558494, S = nan, norm_err = 3.8e-02
# Current memory usage 483.3 MB, time elapsed: 170.4 s
# Delta E = 1.1538e-04, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 1.5682e-06, max_E_trunc = 2.2608e-06
# MPS bond dimensions: [2, 4, 8, 12, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 11, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 80
# Energy = -25.2716178388544961, S = 1.2640950821147019, norm_err = 3.2e-03
# Current memory usage 483.3 MB, time elapsed: 219.2 s
# Delta E = -1.1723e-02, Delta S = nan (per sweep)
# max_trunc_err = 3.3616e-06, max_E_trunc = 9.3705e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 80
# Energy = -25.2716915674428968, S = 1.2641119061142601, norm_err = 1.4e-03
# Current memory usage 483.3 MB, time elapsed: 268.3 s
# Delta E = -7.3729e-06, Delta S = 1.6824e-06 (per sweep)
# max_trunc_err = 7.6709e-07, max_E_trunc = 2.2025e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.2705692411867133, S = 1.2641243462257918, norm_err = 2.3e-02
# Current memory usage 483.3 MB, time elapsed: 317.2 s
# Delta E = 1.1223e-04, Delta S = 1.2440e-06 (per sweep)
# max_trunc_err = 7.6275e-07, max_E_trunc = 2.1927e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=2.28e-02
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.2705692411867
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18, 16, 8, 8, 4, 2]
# finite DMRG, Kitaev ladder model
# L = 20, Jx = 1.00, Jy = 2.00, Jz = 1.50,
# Reading 'L'=20 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'order'='default' for config KitaevLadderModel
# Reading 'bc'='open' for config KitaevLadderModel
# Reading 'bc_MPS'='finite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
# bc_MPS =  finite
# Reading 'combine'=True for config DMRG
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config DMRG
# Reading 'orthogonal_to'=[<tenpy.networks.mps.MPS object at 0x7fe98b5d27d0>, <tenpy.networks.mps.MPS object at 0x7fe98a049390>, <tenpy.networks.mps.MPS object at 0x7fe9a7582190>, <tenpy.networks.mps.MPS object at 0x7fe98a663490>, <tenpy.networks.mps.MPS object at 0x7fe9d5e64410>, <tenpy.networks.mps.MPS object at 0x7fe98b735e10>, <tenpy.networks.mps.MPS object at 0x7fe99e084310>, <tenpy.networks.mps.MPS object at 0x7fe98b779890>, <tenpy.networks.mps.MPS object at 0x7fe9a75c8350>] for config DMRG
# Reading 'max_E_err'=1e-10 for config DMRG
# Reading 'mixer'=True for config DMRG
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config DMRG
# ================================================================================
# sweep 10, age = 80
# Energy = -25.2787485291422946, S = nan, norm_err = 8.9e-05
# Current memory usage 483.3 MB, time elapsed: 102.2 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 6.2419e-07, max_E_trunc = 1.0225e-06
# MPS bond dimensions: [2, 4, 8, 11, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# ================================================================================
# sweep 20, age = 80
# Energy = -25.2786994355843291, S = nan, norm_err = 2.2e-03
# Current memory usage 483.3 MB, time elapsed: 167.7 s
# Delta E = 4.9094e-06, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 5.6727e-06, max_E_trunc = 4.0299e-06
# MPS bond dimensions: [2, 4, 8, 11, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 12, 8, 4, 2]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# ================================================================================
# sweep 30, age = 80
# Energy = -25.2784876623602948, S = 1.2618589654226151, norm_err = 3.1e-03
# Current memory usage 483.3 MB, time elapsed: 222.6 s
# Delta E = 2.1177e-05, Delta S = nan (per sweep)
# max_trunc_err = 2.1641e-06, max_E_trunc = 1.0243e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 40, age = 80
# Energy = -25.2787009780808347, S = 1.2620570389346981, norm_err = 1.0e-03
# Current memory usage 483.3 MB, time elapsed: 277.7 s
# Delta E = -2.1332e-05, Delta S = 1.9807e-05 (per sweep)
# max_trunc_err = 1.7959e-06, max_E_trunc = 1.0551e-06
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# ================================================================================
# sweep 50, age = 80
# Energy = -25.2785735590463823, S = 1.2620169127553345, norm_err = 2.9e-03
# Current memory usage 483.3 MB, time elapsed: 333.8 s
# Delta E = 1.2742e-05, Delta S = -4.0126e-06 (per sweep)
# max_trunc_err = 2.4612e-06, max_E_trunc = 9.9423e-07
# MPS bond dimensions: [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# norm_tol=1.00e-05 not reached, norm_err=2.90e-03
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/algorithms/dmrg.py:408: UserWarning: final DMRG state not in canonical form within `norm_tol` = 1.00e-05
#   warnings.warn(msg.format(nt=norm_tol))
# ================================================================================
# DMRG finished after 50 sweeps.
# total size = 80, maximum chi = 20
# ================================================================================
# E = -25.2785735590464
# final bond dimensions:  [2, 4, 8, 8, 16, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 8, 8, 4, 2]
# Energy list :  [-25.387594337434304, -25.387594333301607, -25.272205297817493, -25.278744860818552, -25.271633939590263, -25.272241830745525, -25.270438300588346, -25.26297050510978, -25.270569241186713, -25.278573559046382]
# Multiplied by unit size:  [-101.55037734973722, -101.55037733320643, -101.08882119126997, -101.11497944327421, -101.08653575836105, -101.0889673229821, -101.08175320235338, -101.05188202043912, -101.08227696474685, -101.11429423618553]

# %% [markdown]
# Measurement of the correlation length

# %%
data = run_atomic(Jx=Jx, Jy=Jy, Jz=Jz, L=3, chi=20)
# Out:
# Reading 'L'=3 for config KitaevLadderModel
# Reading 'conserve'=None for config KitaevLadderModel
# Reading 'bc'='periodic' for config KitaevLadderModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderModel
# Reading 'Jx'=1 for config KitaevLadderModel
# Reading 'Jy'=2 for config KitaevLadderModel
# Reading 'Jz'=1.5 for config KitaevLadderModel
#
#
# ================================================================================
# ==============================START==============================
# ================================================================================
# Chi =  20
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# Reading 'max_sweeps'=200 for config TwoSiteDMRGEngine
# Reading 'max_E_err'=1e-06 for config TwoSiteDMRGEngine
# Reading 'max_S_err'=0.0001 for config TwoSiteDMRGEngine
# Reading 'mixer'=True for config TwoSiteDMRGEngine
# Subconfig 'mixer_params'=Config(<4 options>, 'mixer_params') for config TwoSiteDMRGEngine
# Updating environment
# .....
# ================================================================================
# sweep 10, age = 612
# Energy = -0.3202572002522691, S = nan, norm_err = 2.0e-07
# Current memory usage 483.3 MB, time elapsed: 9.0 s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.7066e-07, max_E_trunc = 8.0061e-07
# MPS bond dimensions: [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Updating environment
# .....
# ================================================================================
# sweep 20, age = 972
# Energy = -0.3202572111031602, S = nan, norm_err = 3.9e-08
# Current memory usage 483.3 MB, time elapsed: 13.7 s
# Delta E = -1.0851e-09, Delta S = 0.0000e+00 (per sweep)
# max_trunc_err = 4.4841e-07, max_E_trunc = 7.9502e-07
# MPS bond dimensions: [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Convergence criterium reached with enabled mixer.
# disable mixer and continue
# Updating environment
# .....
# ================================================================================
# sweep 30, age = 1332
# Energy = -0.3202572113910425, S = 1.2763334365417123, norm_err = 3.4e-13
# Current memory usage 483.3 MB, time elapsed: 16.6 s
# Delta E = -2.8788e-11, Delta S = nan (per sweep)
# max_trunc_err = 2.2304e-07, max_E_trunc = 7.9537e-07
# MPS bond dimensions: [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Updating environment
# .....
# ================================================================================
# sweep 40, age = 1692
# Energy = -0.3202572113909739, S = 1.2763334365418060, norm_err = 3.4e-13
# Current memory usage 483.3 MB, time elapsed: 19.6 s
# Delta E = 6.8667e-15, Delta S = 9.3703e-15 (per sweep)
# max_trunc_err = 2.2304e-07, max_E_trunc = 7.9537e-07
# MPS bond dimensions: [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# ================================================================================
# DMRG finished after 40 sweeps.
# total size = 1692, maximum chi = 20
# ================================================================================
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2119: UserWarning: canonical_form_infinite: project to smaller bond dimension
#   self.canonical_form_infinite(renormalize)
# /home/jerry/anaconda3/lib/python3.7/site-packages/tenpy/networks/mps.py:2269: UserWarning: Although we renormalized the TransferMatrix, the largest eigenvalue is not 1
#   warnings.warn("Although we renormalized the TransferMatrix, "
# Before the canonicalization:
# Bond dim =  [10, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Canonicalizing...
# The norm is:  1.0
# The overlap is:  (1.000000000000004+2.1242908691199008e-16j)
# After the canonicalization:
# Bond dim =  [10, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Computing properties
# Optimizing
# Loop for chi=20 done.
# ================================================================================
# ============================== END ==============================
# ================================================================================

# %%
psi = data['psi']
psi.correlation_length()
# Out:
# 6.839590009249063

# %% [markdown]
# ### Try to break the symmetry
