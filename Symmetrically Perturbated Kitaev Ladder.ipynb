# %% [markdown]
# In this notebook, we will explore two ways of perturbation on our Kitaev ladder,
# $$
#     H = H_0+H^\prime
# $$
# where $H_0$ is the original KL Hamiltonian,
# $$
#     H_0 := \sum_n J_z \sigma^z_{2n - 1} \sigma^z_{2n} + J_x \sigma^x_{2n} \sigma^x_{2n+1} + J_y \sigma^y_{2n-1} \sigma^y_{2n+2}
# $$
# and $H^\prime$ is the perturbative Hamiltonian,
# $$
#     H^\prime := k\sum_n \sigma^z_{2n} \sigma^z_{2n+1} +  \sigma^z_{2n-1} \sigma^z_{2n+2}
# $$

# %% [markdown]
# An advantage of this perturbation is that it not only preserves the original symmetries, but also breaks the local symmetries `Dn` so that the model is no longer exactly solvable.

# %% [markdown]
# # Create the GS at the point `J=(1,1,1)`

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from kitaev_ladder_snake1_perturb2 import load_data, run_atomic, save_after_run
from kitaev_ladder_SPT_detector import detect_SPT_D2_upper_Z, detect_SPT_D2

from utility import linspace

# %%
chi = 128
chi_list = [2, 4, 8, 16, 32, 64, 128]

L=2

Jx = 1.00
Jy = 1.00
Jz = 1.0

k_list = linspace(0.0, 1.0, 101)
k = 0.0

epsilon = 0.01 # epsilon for the smallest space between two neighboring phase points

folder_prefix = f'Spin_half_snake1_Perturbed2_HighRes_L_{L}_chi_{chi}/'
# generate the function for running and storing the data in the folder we want
run_save = save_after_run(run_atomic, folder_prefix=folder_prefix)

# %%
initial_psi = None
for chi in chi_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy,Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
# Out:
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.0 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  2
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# ...

# %%
psi_list = []
for k in k_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy, Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
    psi_list.append(initial_psi.copy())
# Out:
# This file already existed. Pass.
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.01 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# ...

# %%
psi_list = [load_data(Jx=Jx, Jy=Jy, Jz=Jz, g=g, h=h, L=L, chi=chi, prefix=folder_prefix)['psi'] for g in g_list]

# %%
xi_list = [psi.correlation_length() for psi in psi_list]

# %%
plt.plot(k_list, xi_list)
plt.xlabel('Perturbation Strength g')
plt.ylabel('Correlation Length')
# Out:
# Text(0, 0.5, 'Correlation Length')

# %%
chi = 128
chi_list = [2, 4, 8, 16, 32, 64, 128]

L=2

Jx = 2.00
Jy = 2.00
Jz = 1.0

k_list = linspace(0.0, 1.0, 101)
k = 0.0

epsilon = 0.01 # epsilon for the smallest space between two neighboring phase points

folder_prefix = f'Spin_half_snake1_Perturbed2_HighRes_L_{L}_chi_{chi}/'
# generate the function for running and storing the data in the folder we want
run_save = save_after_run(run_atomic, folder_prefix=folder_prefix)

# %%
initial_psi = None
for chi in chi_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy,Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
# Out:
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=2.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=2.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.0 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  2
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# ...

# %%
psi_list = []
for k in k_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy, Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
    psi_list.append(initial_psi.copy())
# Out:
# This file already existed. Pass.
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=2.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=2.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.01 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# ...

# %%
xi_list = [psi.correlation_length() for psi in psi_list]

# %%
plt.plot(k_list, xi_list)
plt.xlabel('Perturbation Strength g')
plt.ylabel('Correlation Length')
# Out:
# Text(0, 0.5, 'Correlation Length')

# %%
spt_detector_list = [detect_SPT_D2_upper_Z(psi) for psi in psi_list]
plt.plot(k_list, spt_detector_list, label=r'SPT Detector')
# plt.plot(g_list, order_list, label=r'Order Parameter')
plt.xlabel('Perturbation Strength g')
# plt.ylabel(r'SPT Detector Value')
plt.legend()
# Out:
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
# ...

# %%
chi = 128
chi_list = [2, 4, 8, 16, 32, 64, 128]

L=2

Jx = 3.00
Jy = 3.00
Jz = 1.0

k_list = linspace(0.0, 1.0, 101)
k = 0.0

epsilon = 0.01 # epsilon for the smallest space between two neighboring phase points

folder_prefix = f'Spin_half_snake1_Perturbed2_HighRes_L_{L}_chi_{chi}/'
# generate the function for running and storing the data in the folder we want
run_save = save_after_run(run_atomic, folder_prefix=folder_prefix)

# %%
initial_psi = None
for chi in chi_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy,Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
# Out:
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=3.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=3.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.0 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  2
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# ...

# %%
psi_list = []
for k in k_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy, Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
    psi_list.append(initial_psi.copy())
# Out:
# This file already existed. Pass.
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=3.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=3.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.01 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# ...

# %%
xi_list = [psi.correlation_length() for psi in psi_list]

# %%
plt.plot(k_list, xi_list)
plt.xlabel('Perturbation Strength g')
plt.ylabel('Correlation Length')
# Out:
# Text(0, 0.5, 'Correlation Length')

# %%
spt_detector_list = [detect_SPT_D2_upper_Z(psi) for psi in psi_list]
plt.plot(k_list, spt_detector_list, label=r'SPT Detector')
# plt.plot(g_list, order_list, label=r'Order Parameter')
plt.xlabel('Perturbation Strength g')
# plt.ylabel(r'SPT Detector Value')
plt.legend()
# Out:
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
# ...

# %%
chi = 128
chi_list = [2, 4, 8, 16, 32, 64, 128]

L=2

Jx = 1.75
Jy = 0.25
Jz = 1.0

k_list = linspace(0.0, 1.0, 101)
k = 0.0

epsilon = 0.01 # epsilon for the smallest space between two neighboring phase points

folder_prefix = f'Spin_half_snake1_Perturbed2_HighRes_L_{L}_chi_{chi}/'
# generate the function for running and storing the data in the folder we want
run_save = save_after_run(run_atomic, folder_prefix=folder_prefix)

# %%
initial_psi = None
for chi in chi_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy,Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
# Out:
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=1.75 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=0.25 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.0 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  2
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# ...

# %%
psi_list = []
for k in k_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy, Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
    psi_list.append(initial_psi.copy())
# Out:
# This file already existed. Pass.
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=1.75 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=0.25 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.01 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# ...

# %%
xi_list = [psi.correlation_length() for psi in psi_list]

# %%
plt.plot(k_list, xi_list)
plt.xlabel('Perturbation Strength g')
plt.ylabel('Correlation Length')
# Out:
# Text(0, 0.5, 'Correlation Length')

# %%
S_list = [psi.entanglement_entropy() for psi in psi_list]
plt.plot(k_list, S_list)
plt.xlabel('Perturbation Strength g')
plt.ylabel('Correlation Length')
# Out:
# Text(0, 0.5, 'Correlation Length')

# %%
spt_detector_list = [detect_SPT_D2_upper_Z(psi) for psi in psi_list]
plt.plot(k_list, spt_detector_list, label=r'SPT Detector')
# plt.plot(g_list, order_list, label=r'Order Parameter')
plt.xlabel('Perturbation Strength g')
# plt.ylabel(r'SPT Detector Value')
plt.legend()
# Out:
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
# ...

# %%
spt_detector_list = [detect_SPT_D2(psi) for psi in psi_list]
plt.plot(k_list, spt_detector_list, label=r'SPT Detector')
# plt.plot(g_list, order_list, label=r'Order Parameter')
plt.xlabel('Perturbation Strength g')
# plt.ylabel(r'SPT Detector Value')
plt.legend()
# Out:
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
# ...

# %%
spt_detector_list
# Out:
# [(-1.0007399533409111+0j),
#  (-1.0000000000022617+1.951563910473908e-17j),
#  (1.0000000135615497+2.7321894746634712e-17j),
#  (0.9999999999999987-5.637851296924623e-18j),
#  (0.9999999999999996-1.734723475976807e-18j),
#  (1.0000000000798182+5.204170427930421e-18j),
#  (0.9999999731677074-3.469446951953614e-17j),
#  (0.9999999999999996+4.683753385137379e-17j),
#  (0.9999999999999999-5.637851296924623e-18j),
#  (1.0000000000000004-5.204170427930421e-18j),
#  (1.000095607949816+1.0408340855860843e-16j),
#  (1.013717811091144-2.1250362580715887e-17j),
#  (1.0000394240418582+2.5045070184415152e-17j),
#  (1.0000418220545317+1.734723475976807e-17j),
#  (1.000034322594793+6.245004513516506e-17j),
#  (1.0000000000002183-5.551115123125783e-17j),
#  (0.9999999999999993+3.469446951953614e-18j),
#  (1.0000000000000002-1.0408340855860843e-17j),
#  (0.9999999999999993+3.903127820947816e-18j),
#  (1.0000000000000009-1.5829351718288365e-17j),
#  (0.9999999999999999+6.938893903907228e-17j),
# ...

# %%
chi = 128
chi_list = [2, 4, 8, 16, 32, 64, 128]

L=2

Jx = 1.85
Jy = 0.15
Jz = 1.0

k_list = linspace(0.0, 1.0, 101)
k = 0.0

epsilon = 0.01 # epsilon for the smallest space between two neighboring phase points

folder_prefix = f'Spin_half_snake1_Perturbed2_HighRes_L_{L}_chi_{chi}/'
# generate the function for running and storing the data in the folder we want
run_save = save_after_run(run_atomic, folder_prefix=folder_prefix)

# %%
initial_psi = None
for chi in chi_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy,Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
# Out:
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=1.85 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=0.15 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.0 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  2
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# Reading 'N_sweeps_check'=10 for config TwoSiteDMRGEngine
# ...

# %%
psi_list = []
for k in k_list:
    result = run_save(Jx=Jx, Jy=Jy, Jz=Jz, k=k, L=L, chi=chi, initial_psi=initial_psi, verbose=1)
    if result==0: # this file already exists
        result = load_data(Jx=Jx,Jy=Jy, Jz=Jz, k=k, L=L,chi=chi,prefix=folder_prefix)
        pass 
    initial_psi=result['psi'].copy()
    psi_list.append(initial_psi.copy())
# Out:
# This file already existed. Pass.
# Reading 'L'=2 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'conserve'=None for config KitaevLadderSnakeCompactPerturbModel
# Reading 'S'=0.5 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc'='periodic' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'bc_MPS'='infinite' for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jx'=1.85 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jy'=0.15 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'Jz'=1.0 for config KitaevLadderSnakeCompactPerturbModel
# Reading 'k'=0.01 for config KitaevLadderSnakeCompactPerturbModel
#
#
# ...
# ==============================START==============================
# ...
# Chi =  128
#
# Subconfig 'trunc_params'=Config(<3 options>, 'trunc_params') for config TwoSiteDMRGEngine
# Initial sweeps...
# Reading 'start_env'=10 for config TwoSiteDMRGEngine
# Updating environment
# ..........
# ...

# %%
xi_list = [psi.correlation_length() for psi in psi_list]

# %%
plt.plot(k_list, xi_list)
plt.xlabel('Perturbation Strength g')
plt.ylabel('Correlation Length')
# Out:
# Text(0, 0.5, 'Correlation Length')

# %%
S_list = [psi.entanglement_entropy() for psi in psi_list]
plt.plot(k_list, S_list)
plt.xlabel('Perturbation Strength g')
plt.ylabel('Correlation Length')
# Out:
# Text(0, 0.5, 'Correlation Length')

# %%
spt_detector_list = [detect_SPT_D2_upper_Z(psi) for psi in psi_list]
plt.plot(k_list, spt_detector_list, label=r'SPT Detector')
# plt.plot(g_list, order_list, label=r'Order Parameter')
plt.xlabel('Perturbation Strength g')
# plt.ylabel(r'SPT Detector Value')
plt.legend()
# Out:
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:172: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
# ...

# %%
spt_detector_list = [detect_SPT_D2(psi) for psi in psi_list]
plt.plot(k_list, spt_detector_list, label=r'SPT Detector')
# plt.plot(g_list, order_list, label=r'Order Parameter')
plt.xlabel('Perturbation Strength g')
# plt.ylabel(r'SPT Detector Value')
plt.legend()
# Out:
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
#   return npc.inner(U12, U21.conj()) / chi
# /home/jerry/Downloads/KitaevLadder/kitaev_ladder_SPT_detector.py:107: FutureWarning: inner(): `axes` currently defaults to 'range', will change to 'labels'
# ...
